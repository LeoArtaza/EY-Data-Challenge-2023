# %% [markdown]
# # Load Libraries

# %%
# Supress Warnings
# import warnings
# warnings.filterwarnings('ignore')

# Visualization
# import ipyleaflet
import matplotlib.pyplot as plt
import seaborn as sns

# Data Science
import numpy as np
import pandas as pd
import statsmodels.api as sm
import sklearn

# Planetary Computer Tools
# import pystac
# import pystac_client
# import odc
# from pystac_client import Client
# from pystac.extensions.eo import EOExtension as eo
# from odc.stac import stac_load
# import planetary_computer as pc
# # Import common GIS tools

# import xarray as xr
# import rasterio.features
# import rioxarray as rio
# import xrspatial.multispectral as ms

# # Import Planetary Computer tools
# import odc
# from odc.stac import stac_load
# from odc.algo import to_rgba

# Please pass your API key here
# pc.settings.set_subscription_key('********************')

# Others
# import requests
# import rich.table
from itertools import cycle
from tqdm.notebook import tqdm as tqdm
tqdm.pandas()

# %% [markdown]
# # Read Data

# %%
crop_yield_data = pd.read_csv("Crop_Yield_Data_challenge_2.csv", parse_dates=['Date of Harvest'], dayfirst=True)
crop_yield_data.columns = ['district', 'latitude', 'longitude', 'season', 'intensity', 'date_of_harvest', 'field_size', 'rice_yield']
crop_yield_data.head()
# Out:
#    district   latitude   longitude season intensity date_of_harvest  \
# 0  Chau_Phu  10.510542  105.248554     SA         T      2022-07-15
# 1  Chau_Phu  10.509150  105.265098     SA         T      2022-07-15
# 2  Chau_Phu  10.467721  105.192464     SA         D      2022-07-15
# 3  Chau_Phu  10.494453  105.241281     SA         T      2022-07-15
# 4  Chau_Phu  10.535058  105.252744     SA         D      2022-07-14
#
#    field_size  rice_yield
# 0        3.40        5500
# 1        2.43        6000
# 2        1.95        6400
# 3        4.30        6000
# 4        3.30        6400

# %%
crop_yield_data[crop_yield_data.duplicated(subset=['latitude', 'longitude'], keep=False)].sort_values(['latitude', 'longitude'])
# Out:
#       district   latitude   longitude season intensity date_of_harvest  \
# 449  Thoai_Son  10.195117  105.200047     SA         T      2022-07-20
# 531  Thoai_Son  10.195117  105.200047     WS         T      2022-04-05
# 445  Thoai_Son  10.208515  105.202809     SA         T      2022-07-20
# 527  Thoai_Son  10.208515  105.202809     WS         T      2022-04-05
# 451  Thoai_Son  10.227394  105.164987     SA         T      2022-07-20
# ..         ...        ...         ...    ...       ...             ...
# 119   Chau_Phu  10.636733  105.155635     WS         T      2022-04-10
# 28    Chau_Phu  10.649258  105.142121     SA         D      2022-08-05
# 120   Chau_Phu  10.649258  105.142121     WS         D      2022-04-10
# 29    Chau_Phu  10.663484  105.168203     SA         D      2022-08-05
# 124   Chau_Phu  10.663484  105.168203     WS         D      2022-04-10
#
#      field_size  rice_yield
# 449        3.20        5600
# 531        3.20        7200
# 445        2.67        6400
# 527        2.67        7200
# 451        3.00        5600
# ..          ...         ...
# 119        3.20        8000
# 28         1.75        6000
# 120        1.75        8000
# 29         3.00        6500
# 124        3.00        7200
#
# [336 rows x 8 columns]

# %%
sub_sample = pd.read_csv("Challenge_2_submission_template.csv", parse_dates=['Date of Harvest'], dayfirst=True)
sub_sample.columns = ['id', 'district', 'latitude', 'longitude', 'season', 'intensity', 'date_of_harvest', 'field_size', 'rice_yield']
sub_sample.head()
# Out:
#    id    district   latitude   longitude season intensity date_of_harvest  \
# 0   1    Chau_Phu  10.542192  105.187920     WS         T      2022-04-10
# 1   2  Chau_Thanh  10.400189  105.331053     SA         T      2022-07-15
# 2   3    Chau_Phu  10.505489  105.203926     SA         D      2022-07-14
# 3   4    Chau_Phu  10.523520  105.138274     WS         D      2022-04-10
# 4   5   Thoai_Son  10.294660  105.248528     SA         T      2022-07-20
#
#    field_size  rice_yield
# 0        1.40         NaN
# 1        1.32         NaN
# 2        1.40         NaN
# 3        1.80         NaN
# 4        2.20         NaN

# %%
sns.scatterplot(data=crop_yield_data, x='longitude', y='latitude', hue='district', s=6)
sns.scatterplot(data=sub_sample, x='longitude', y='latitude', color='white', s=6)

fig = plt.gcf()
ax  = plt.gca()

fig.set_size_inches(8, 8)

ax.set_aspect('equal')
ax.patch.set_alpha(0)
plt.grid(lw=0.15)
plt.legend()
# legend.legendHandles[0]._sizes = [40]
# legend.legendHandles[1]._sizes = [40]
# legend.set_alpha(0)

plt.xlim(104.8, 106)
plt.ylim(9.8, 11)

# [0.06, 0, 0.95, 0.95]

newax = fig.add_axes(ax.get_position(), anchor='SW', zorder=-15)
# newax.set_position(ax.get_position())
newax.imshow(plt.imread('../Full Region no labels.jpg'), aspect='auto')
newax.axis('off')
# ax.set_xlim(105.3338 - 10**-2/2, 105.3338+ 10**-2/2)
# ax.set_ylim(10.4391  - 10**-2/2, 10.4391 + 10**-2/2)
# newax.set_xlim(105.3338 - 10**-2/2, 105.3338+ 10**-2/2)
# newax.set_ylim(10.4391  - 10**-2/2, 10.4391 + 10**-2/2)
plt.grid(False)

# %% [markdown]
# # Process Data

# %% [markdown]
# ## Constant Features

# %%
crop_yield_data['rice_yield'].hist(bins=30)
# Out:
# <AxesSubplot: >

# %%
crop_yield_data['target_class'] = pd.qcut(crop_yield_data['rice_yield'], q=8, labels=False)
crop_yield_data['target_class'].hist(bins=20)
# Out:
# <AxesSubplot: >

# %%
crop_yield_data.head(2)
# Out:
#    district   latitude   longitude season intensity date_of_harvest  \
# 0  Chau_Phu  10.510542  105.248554     SA         T      2022-07-15
# 1  Chau_Phu  10.509150  105.265098     SA         T      2022-07-15
#
#    field_size  rice_yield  target_class
# 0        3.40        5500             0
# 1        2.43        6000             1

# %%
train_const_data = pd.get_dummies(crop_yield_data.drop(['district'], axis=1), drop_first=True).drop(['latitude', 'longitude'], axis=1)
sub_const_data   = pd.get_dummies(sub_sample.drop(['district', 'rice_yield', 'id'], axis=1), drop_first=True).drop(['latitude', 'longitude'], axis=1)
display(train_const_data.head(2), sub_const_data.head(2))
# Out:
#   date_of_harvest  field_size  rice_yield  target_class  season_WS  \
# 0      2022-07-15        3.40        5500             0          0
# 1      2022-07-15        2.43        6000             1          0
#
#    intensity_T
# 0            1
# 1            1
#   date_of_harvest  field_size  season_WS  intensity_T
# 0      2022-04-10        1.40          1            1
# 1      2022-07-15        1.32          0            1

# %%
train_const_data.season_WS.value_counts(normalize=True).plot.bar(alpha=0.5, label='Train')
sub_const_data.season_WS.value_counts(normalize=True).plot.bar(alpha=0.5, color='C1', label='Sub')
plt.title('Season distribution between train and sub')
plt.legend();

# %%
train_const_data['start_of_harvest']     = train_const_data.date_of_harvest - pd.to_timedelta('99d')
sub_const_data  ['start_of_harvest']     = sub_const_data.date_of_harvest -   pd.to_timedelta('99d')
train_const_data['dayofyear_of_harvest'] = train_const_data.date_of_harvest.dt.day_of_year
sub_const_data['dayofyear_of_harvest']   = sub_const_data.date_of_harvest.dt.day_of_year
display(train_const_data.head(2), sub_const_data.head(2))
# Out:
#   date_of_harvest  field_size  rice_yield  target_class  season_WS  \
# 0      2022-07-15        3.40        5500             0          0
# 1      2022-07-15        2.43        6000             1          0
#
#    intensity_T start_of_harvest  dayofyear_of_harvest
# 0            1       2022-04-07                   196
# 1            1       2022-04-07                   196
#   date_of_harvest  field_size  season_WS  intensity_T start_of_harvest  \
# 0      2022-04-10        1.40          1            1       2022-01-01
# 1      2022-07-15        1.32          0            1       2022-04-07
#
#    dayofyear_of_harvest
# 0                   100
# 1                   196

# %%
train_const_data.set_index('date_of_harvest').resample('m').count().apply(lambda x:x/x.max()).iloc[:, 0].plot.bar(alpha=0.5, label='Train')
sub_const_data.set_index('date_of_harvest').resample('m').count().apply(lambda x:x/x.max()).iloc[:, 0].plot.bar(alpha=0.5, color='C1', label='Sub')
plt.legend()
plt.show()
train_const_data.rice_yield.hist(bins=10)
# Out:
# <AxesSubplot: >

# %%
# sns.kdeplot(data=train_const_data, x='date_of_harvest', y='rice_yield', hue='intensity_T', levels=8, fill=True, alpha=0.5)
# plt.title('Yield by date and by intensity')

# %%
# sns.heatmap(train_const_data.corr(), cmap='coolwarm', annot=True)

# %%
# sns.pairplot(train_const_data)

# %%
# sns.pairplot(sub_const_data)

# %% [markdown]
# ## Time Series features

# %%
train_ts_data = pd.read_csv('train_data_level2.csv', index_col=['index', 'datetime'], parse_dates=True, dayfirst=True)
sub_ts_data   = pd.read_csv('sub_data_level2.csv'  , index_col=['index', 'datetime'], parse_dates=True, dayfirst=True)
# train_sent2_data = pd.read_csv('train_sentinel2_level2_fix.csv', index_col=['index', 'datetime'], parse_dates=True).drop('SCL', axis=1).replace(0, np.nan)
# sub_sent2_data = pd.read_csv('sub_sentinel2_level2.csv', index_col=['index', 'datetime'], parse_dates=True).drop('SCL', axis=1).replace(0, np.nan)

train_sent2_data = pd.read_pickle('level2_sent2_train.df')
sub_sent2_data   = pd.read_pickle('level2_sent2_sub.df'  )

train_sent2_data = train_sent2_data.rename_axis(['index', 'datetime'])
sub_sent2_data   = sub_sent2_data.rename_axis(['index', 'datetime'])

display(train_ts_data.head(2), train_sent2_data.head(2), sub_sent2_data.head(2))
# Out:
#                                         vh        vv       rvi
# index datetime
# 0     2021-09-05 22:45:35.619475  0.006411  0.036697  0.229400
#       2021-09-11 22:46:08.311308  0.019033  0.295205  0.059627
#                                        red                        \
#                                       mean  median percentile_20
# index datetime
# 0     2022-02-19 03:17:49.024  1649.775391  1406.5        1251.0
#       2022-02-24 03:17:31.024          NaN     NaN           NaN
#
#                                                                green          \
#                               percentile_80         std         mean  median
# index datetime
# 0     2022-02-19 03:17:49.024        2036.0  543.111408  1933.546509  1693.0
#       2022-02-24 03:17:31.024           NaN         NaN          NaN     NaN
#
#                                                                       ...  \
#                               percentile_20 percentile_80        std  ...
# index datetime                                                        ...
# 0     2022-02-19 03:17:49.024        1556.0   2336.399902  538.90375  ...
#       2022-02-24 03:17:31.024           NaN           NaN        NaN  ...
#
#                                    rededge                        \
#                                       mean  median percentile_20
# index datetime
# 0     2022-02-19 03:17:49.024  2205.781982  1990.5        1798.0
#       2022-02-24 03:17:31.024          NaN     NaN           NaN
#
#                                                               swir16          \
#                               percentile_80         std         mean  median
# index datetime
# 0     2022-02-19 03:17:49.024   2595.600098  581.085265  3068.577881  2948.0
#       2022-02-24 03:17:31.024           NaN         NaN          NaN     NaN
#
#
#                               percentile_20 percentile_80         std
# index datetime
# 0     2022-02-19 03:17:49.024   2656.399902   3432.600098  605.145364
#       2022-02-24 03:17:31.024           NaN           NaN         NaN
#
# [2 rows x 30 columns]
#                                red                                         \
#                               mean median percentile_20 percentile_80 std
# index datetime
# 0     2021-11-11 03:19:49.024  NaN    NaN           NaN           NaN NaN
#       2021-11-16 03:20:11.024  NaN    NaN           NaN           NaN NaN
#
#                               green                                         \
#                                mean median percentile_20 percentile_80 std
# index datetime
# 0     2021-11-11 03:19:49.024   NaN    NaN           NaN           NaN NaN
#       2021-11-16 03:20:11.024   NaN    NaN           NaN           NaN NaN
#
#                                ... rededge                                     \
#                                ...    mean median percentile_20 percentile_80
# index datetime                 ...
# 0     2021-11-11 03:19:49.024  ...     NaN    NaN           NaN           NaN
#       2021-11-16 03:20:11.024  ...     NaN    NaN           NaN           NaN
#
#                                   swir16                                     \
#                               std   mean median percentile_20 percentile_80
# index datetime
# 0     2021-11-11 03:19:49.024 NaN    NaN    NaN           NaN           NaN
#       2021-11-16 03:20:11.024 NaN    NaN    NaN           NaN           NaN
#
#
#                               std
# index datetime
# 0     2021-11-11 03:19:49.024 NaN
#       2021-11-16 03:20:11.024 NaN
#
# [2 rows x 30 columns]

# %%
multicols_names = train_sent2_data.columns.map('_'.join)
train_sent2_data.columns = multicols_names
sub_sent2_data.columns   = multicols_names

aggregations_to_use = 'median' #|percentile_(80|20)
train_sent2_data = train_sent2_data.filter(regex=aggregations_to_use) 
sub_sent2_data = sub_sent2_data.filter(regex=aggregations_to_use)

train_sent2_data.head(2)
# Out:
#                                red_median  green_median  blue_median  \
# index datetime
# 0     2022-02-19 03:17:49.024      1406.5        1693.0       1469.5
#       2022-02-24 03:17:31.024         NaN           NaN          NaN
#
#                                nir_median  rededge_median  swir16_median
# index datetime
# 0     2022-02-19 03:17:49.024      5540.0          1990.5         2948.0
#       2022-02-24 03:17:31.024         NaN             NaN            NaN

# %% [markdown]
# ### Slicing time frame

# %%
train_ts_data = pd.concat([train_ts_data, train_sent2_data], axis=1)
sub_ts_data   = pd.concat([sub_ts_data   , sub_sent2_data] , axis=1)

# %%
train_ts_data.reset_index(level=1).groupby(level=0)\
.apply(lambda x: x.set_index('datetime').resample('1d').median())
# Out:
#                         vh        vv       rvi  red_median  green_median  \
# index datetime
# 0     2021-09-05  0.006411  0.036697  0.229400         NaN           NaN
#       2021-09-06       NaN       NaN       NaN         NaN           NaN
#       2021-09-07       NaN       NaN       NaN         NaN           NaN
#       2021-09-08       NaN       NaN       NaN         NaN           NaN
#       2021-09-09       NaN       NaN       NaN         NaN           NaN
# ...                    ...       ...       ...         ...           ...
# 556   2022-12-20       NaN       NaN       NaN         NaN           NaN
#       2022-12-21       NaN       NaN       NaN         NaN           NaN
#       2022-12-22       NaN       NaN       NaN         NaN           NaN
#       2022-12-23  0.006916  0.113862  0.054806         NaN           NaN
#       2022-12-24  0.006872  0.051070  0.163378         NaN           NaN
#
#                   blue_median  nir_median  rededge_median  swir16_median
# index datetime
# 0     2021-09-05          NaN         NaN             NaN            NaN
#       2021-09-06          NaN         NaN             NaN            NaN
#       2021-09-07          NaN         NaN             NaN            NaN
#       2021-09-08          NaN         NaN             NaN            NaN
#       2021-09-09          NaN         NaN             NaN            NaN
# ...                       ...         ...             ...            ...
# 556   2022-12-20          NaN         NaN             NaN            NaN
#       2022-12-21          NaN         NaN             NaN            NaN
#       2022-12-22          NaN         NaN             NaN            NaN
#       2022-12-23          NaN         NaN             NaN            NaN
#       2022-12-24          NaN         NaN             NaN            NaN
#
# [265132 rows x 9 columns]

# %%
train_ts_data    = train_ts_data.unstack(    level=0).resample('5d').mean().interpolate().bfill().ffill().stack(dropna=False).swaplevel().sort_index(level=0)
sub_ts_data      = sub_ts_data.unstack(      level=0).resample('5d').mean().interpolate().bfill().ffill().stack(dropna=False).swaplevel().sort_index(level=0)

# %%
# Create slices to keep only 100 days prior to harvest for each coordinate

harvest_slices = []
for idx in range(len(train_ts_data.index.levels[0])):
    harvest_slices.append((idx, slice(train_const_data.loc[idx, 'start_of_harvest'], train_const_data.loc[idx, 'date_of_harvest'])))
data_slices = []
for hs in harvest_slices:
    data_slices.append(train_ts_data.loc[hs, :])
    
# Concatenate slices
train_ts_data = pd.concat(data_slices)

# Sub
harvest_slices = []
for idx in range(len(sub_ts_data.index.levels[0])):
    harvest_slices.append((idx, slice(sub_const_data.loc[idx, 'start_of_harvest'], sub_const_data.loc[idx, 'date_of_harvest'])))
data_slices = []
for hs in harvest_slices:
    data_slices.append(sub_ts_data.loc[hs, :])
    
# Concatenate slices
sub_ts_data = pd.concat(data_slices)

# %%
# Add ratio vv/vh
# train_ts_data = train_ts_data.assign(ratio=lambda x:x['vv']/x['vh']/10)
# sub_ts_data = sub_ts_data.assign(ratio=lambda x:x['vv']/x['vh']/10)
# display(train_ts_data.head(2), sub_ts_data.head(2))

# Add Indices to Sentinel 2
def AddBands(sent2_data, multiindex):
    if multiindex:
        sent2_data = sent2_data.stack()
    for agg in aggregations_to_use.split('|'):
        ndvi = 'ndvi_' + agg
        ndwi = 'ndwi_' + agg
        ndbsi = 'ndbsi_' + agg
        ndre = 'ndre_' + agg
        sent2_data = sent2_data.assign(**{ndvi:lambda x:(x['nir_' + agg]-x['red_' + agg])/(x['nir_' + agg]+x['red_' + agg]),
                                            ndwi:lambda x:(x['nir_' + agg]-x['swir16_' + agg])/(x['nir_' + agg]+x['swir16_' + agg]),
                                            ndbsi:lambda x:((x['nir_' + agg]+x['blue_' + agg])-(x['red_' + agg]+x['swir16_' + agg]))/((x['nir_' + agg]+x['blue_' + agg])+(x['red_' + agg]+x['swir16_' + agg])),
                                            ndre:lambda x:(x['nir_' + agg]-x['rededge_' + agg])/(x['nir_' + agg]+x['rededge_' + agg])})
    if multiindex:
        sent2_data = sent2_data.unstack()
    return sent2_data

train_ts_data = AddBands(train_ts_data, False)
sub_ts_data = AddBands(sub_ts_data, False)
display(train_ts_data.head(2), sub_ts_data.head(2))
# Out:
#                         vh        vv       rvi  red_median  green_median  \
# index datetime
# 0     2022-04-08  0.031122  0.122437  0.372534      2343.0        2308.0
#       2022-04-13  0.034312  0.150705  0.308071      2368.0        2636.0
#
#                   blue_median  nir_median  rededge_median  swir16_median  \
# index datetime
# 0     2022-04-08       2324.0      2668.0          2586.0         2521.0
#       2022-04-13       3062.0      1766.0          2330.0         1413.0
#
#                   ndvi_median  ndwi_median  ndbsi_median  ndre_median
# index datetime
# 0     2022-04-08     0.064857     0.028329      0.012987     0.015607
#       2022-04-13    -0.145622     0.111041      0.121617    -0.137695
#                         vh        vv       rvi  red_median  green_median  \
# index datetime
# 0     2022-01-03  0.005278  0.014143  0.620014       894.0         847.0
#       2022-01-08  0.005137  0.017744  0.448863       666.5         755.0
#
#                   blue_median  nir_median  rededge_median  swir16_median  \
# index datetime
# 0     2022-01-03        709.0      1294.0          1189.0         1562.0
#       2022-01-08        583.0      1820.0          1060.0         1235.0
#
#                   ndvi_median  ndwi_median  ndbsi_median  ndre_median
# index datetime
# 0     2022-01-03     0.182815    -0.093838     -0.101592     0.042288
#       2022-01-08     0.463905     0.191489      0.116506     0.263889

# %%
# Drop a column
# train_sent2_data = train_sent2_data.drop(['red', 'green', 'blue'], axis=1)
# sub_sent2_data = sub_sent2_data.drop(['red', 'green', 'blue'], axis=1)

# display(train_sent2_data.head(2), sub_sent2_data.head(2))

# %%
# Check boxplot before transforming
train_ts_data.filter(like='nd').plot.box()
sub_ts_data.plot.box()
# Out:
# <AxesSubplot: >

# %%
columns_to_apply_log10 = 'vv,vh,red,green,blue,nir,rededge,swir16'.split(',')
train_ts_data.loc[:, train_ts_data.columns.str.contains('|'.join(columns_to_apply_log10))] = train_ts_data.loc[:, train_ts_data.columns.str.contains('|'.join(columns_to_apply_log10))].apply(lambda x: np.log10(x))
sub_ts_data.loc[:, sub_ts_data.columns.str.contains('|'.join(columns_to_apply_log10))] = sub_ts_data.loc[:, sub_ts_data.columns.str.contains('|'.join(columns_to_apply_log10))].apply(lambda x: np.log10(x))

train_ts_data['rvi'] = train_ts_data['rvi'].apply(lambda x:x**0.5)
sub_ts_data['rvi'] = sub_ts_data['rvi'].apply(lambda x:x**0.5)

# %%
def is_outlier(series, factor=1, print_range=False):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR*factor
    upper_bound = Q3 + 1.5 * IQR*factor
    if print_range:
        print(upper_bound, lower_bound)
    boolean_filter = (series < lower_bound) | (series > upper_bound)
    return pd.Series(np.where(boolean_filter,
                                       np.nan,
                                       series),
                              index=series.index)

train_ts_data    = train_ts_data.apply(is_outlier, args=[2]).interpolate().bfill().ffill()
sub_ts_data      = sub_ts_data.apply(  is_outlier, args=[2]).interpolate().bfill().ffill()

# %%
# Check boxplot after outlier filters
train_ts_data.plot.box()
sub_ts_data.plot.box()
# Out:
# <AxesSubplot: >

# %%
# Visualize data for one random sample
rand = np.random.randint(0, 556)
print(rand)
train_ts_data.loc[rand].plot(marker='o')
# [plt.axvline(train_const_data.loc[rand, i], c='k', ls='--', alpha=0.5) for i in ['start_of_harvest', 'date_of_harvest']];
plt.show();

# Visualize data for one random sample
rand = np.random.randint(0, 99)
print(rand)
sub_ts_data.loc[rand].plot(marker='o')
# [plt.axvline(sub_const_data.loc[rand, i], c='k', ls='--', alpha=0.5) for i in ['start_of_harvest', 'date_of_harvest']];
plt.show();
# Out:
# 470
# 41

# %% [markdown]
# ### Detect TS Anomalies

# %%
# # import torch
# import torch.nn as nn

# # Define a simple RNN model with one hidden layer
# class RNN(nn.Module):
#     def __init__(self, input_size, hidden_size, output_size):
#         super(RNN, self).__init__()
#         self.hidden_size = hidden_size
#         self.rnn = nn.LSTM(input_size, hidden_size, batch_first=True)
#         self.fc = nn.Linear(hidden_size, output_size)

#     def forward(self, x):
#         # Initialize hidden state
#         h0 = torch.zeros(1, x.size(0), self.hidden_size).to(x.device)
#         c0 = torch.zeros(1, x.size(0), self.hidden_size).to(x.device)

#         # Feed input sequence through the LSTM
#         out, _ = self.rnn(x, (h0, c0))

#         # Pass the output sequence through a fully connected layer
#         out = self.fc(out)

#         return out

# # Define a loss function that penalizes large deviations from the predicted values
# class AnomalyDetectionLoss(nn.Module):
#     def __init__(self, threshold):
#         super(AnomalyDetectionLoss, self).__init__()
#         self.threshold = threshold

#     def forward(self, y_pred, y_true):
#         errors = torch.abs(y_pred - y_true)
#         mask = errors > self.threshold
#         loss = torch.mean(torch.where(mask, errors, torch.zeros_like(errors)))
#         return loss

# # Define a training function that uses an optimizer to minimize the loss
# def train_model(model, train_loader, optimizer, loss_fn, num_epochs):
#     for epoch in range(num_epochs):
#         for i, (inputs) in enumerate(train_loader):
#             optimizer.zero_grad()

#             # Forward pass
#             outputs = model(inputs)
#             loss = loss_fn(outputs, inputs)

#             # Backward pass and optimization
#             loss.backward()
#             optimizer.step()

#             if (i+1) % 10 == 0:
#                 print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
#                       .format(epoch+1, num_epochs, i+1, len(train_loader), loss.item()), end='\r')

# # Define a function to detect anomalies in a time series
# def detect_anomalies(model, data, threshold):
#     inputs = torch.Tensor(data)
#     outputs = model(inputs)
#     print(inputs.shape, outputs.shape)
#     errors = torch.abs(outputs - inputs)
#     mask = errors > threshold
#     return mask.squeeze().detach().cpu().numpy()

# # Example usage:
# threshold = 3
# data = torch.Tensor(np.vstack([train_ts_data.values.reshape(557, 100, -1), sub_ts_data.values.reshape(100, 100, -1)])).to('cuda')
# model = RNN(input_size=data.shape[2], hidden_size=10, output_size=data.shape[2]).to('cuda')
# optimizer = torch.optim.Adam(model.parameters(), lr=10**-4)
# loss_fn = AnomalyDetectionLoss(threshold=threshold)
# train_loader = torch.utils.data.DataLoader(data, batch_size=1, shuffle=False)
# train_model(model, train_loader, optimizer, loss_fn, num_epochs=20)

# %%
# anomaly_mask_train = detect_anomalies(model, data[:557], threshold=threshold*0.35)
# anomaly_mask_sub   = detect_anomalies(model, data[557:], threshold=threshold*0.35)

# %%
# anomaly_mask_train_df = pd.DataFrame(anomaly_mask_train.reshape(train_ts_data.shape), index=train_ts_data.index, columns=train_ts_data.columns)
# anomaly_mask_sub_df   = pd.DataFrame(anomaly_mask_sub.reshape(sub_ts_data.shape)  , index=sub_ts_data.index  , columns=sub_ts_data.columns)

# %%
# # Join red, blue, green masks, and ndbi, etc, masks
# anomaly_mask_train_df[anomaly_mask_train_df.columns[3:8]] = anomaly_mask_train_df.iloc[:, 3:8].apply(np.logical_or.reduce, axis=1).to_frame().reindex(columns=anomaly_mask_train_df.columns[3:8])
# anomaly_mask_train_df[anomaly_mask_train_df.columns[9:]]  = anomaly_mask_train_df.iloc[:, 9: ].apply(np.logical_or.reduce, axis=1).to_frame().reindex(columns=anomaly_mask_train_df.columns[9:])
# anomaly_mask_train_df = anomaly_mask_train_df.ffill(axis=1)

# anomaly_mask_sub_df[anomaly_mask_sub_df.columns[3:8]] = anomaly_mask_sub_df.iloc[:, 3:8].apply(np.logical_or.reduce, axis=1).to_frame().reindex(columns=anomaly_mask_sub_df.columns[3:8])
# anomaly_mask_sub_df[anomaly_mask_sub_df.columns[9:]]  = anomaly_mask_sub_df.iloc[:, 9: ].apply(np.logical_or.reduce, axis=1).to_frame().reindex(columns=anomaly_mask_sub_df.columns[9:])
# anomaly_mask_sub_df = anomaly_mask_sub_df.ffill(axis=1)

# %%
# iterator = iter(range(0, 50))

# %%
# n = next(iterator)
# print(n)
# # n = 18
# # print(pd.DataFrame(anomaly_mask).stack().xs(n))
# for f in range(13):
#     plt.scatter(y=train_ts_data.iloc[:, f].xs(n).values, x=train_ts_data.iloc[:, f].xs(n).index, color=['gold' if x else 'blue' for x in anomaly_mask_train_df.xs(n).iloc[:, f]], zorder=100)
#     train_ts_data.iloc[:, f].xs(n).plot()
#     plt.title(train_ts_data.iloc[:, f].name)
#     plt.show();

# %%
# train_ts_data = train_ts_data.groupby(pd.Grouper(level=0)).apply(lambda x:x.rolling(3).median().bfill())
# sub_ts_data   = sub_ts_data.groupby(pd.Grouper(level=0)).apply(lambda x:x.rolling(3).median().bfill())

# %%
# # Fix and then fill nas
# train_ts_data = train_ts_data.groupby(pd.Grouper(level=0)).apply(lambda x:x.interpolate(limit_area='inside').ffill().bfill().fillna(0).rolling(3).median().bfill())
# sub_ts_data   = sub_ts_data.groupby(  pd.Grouper(level=0)).apply(lambda x:x.interpolate(limit_area='inside').ffill().bfill().fillna(0).rolling(3).median().bfill())

# %%
# n = next(iterator)
# print(n)
# n = 1
# # print(pd.DataFrame(anomaly_mask).stack().xs(n))
# for f in range(13):
#     plt.scatter(y=train_ts_data.iloc[:, f].xs(n).values, x=train_ts_data.iloc[:, f].xs(n).index, color=['gold' if x else 'blue' for x in anomaly_mask_train_df.xs(n).iloc[:, f]], zorder=100)
#     train_ts_data.iloc[:, f].xs(n).plot()
#     plt.title(train_ts_data.iloc[:, f].name)
#     plt.show();

# %% [markdown]
# ### Check

# %%
# Check that all time_series are the same length
display(train_ts_data.groupby(level=0).count().iloc[:, 0].describe(),
        sub_ts_data.groupby(level=0).count().iloc[:, 0].describe())
# Out:
# count    557.0
# mean      20.0
# std        0.0
# min       20.0
# 25%       20.0
# 50%       20.0
# 75%       20.0
# max       20.0
# Name: vh, dtype: float64
# count    100.0
# mean      20.0
# std        0.0
# min       20.0
# 25%       20.0
# 50%       20.0
# 75%       20.0
# max       20.0
# Name: vh, dtype: float64

# %%
assert 0 == train_ts_data.groupby(level=0).count().iloc[:, 0].describe()['std']
time_series_length = int(train_ts_data.groupby(level=0).count().iloc[:, 0].describe()['max'])
n_time_features = train_ts_data.shape[1]

# %%
display(train_ts_data.isna().sum(),
        sub_ts_data.isna().sum())
# Out:
# vh                0
# vv                0
# rvi               0
# red_median        0
# green_median      0
# blue_median       0
# nir_median        0
# rededge_median    0
# swir16_median     0
# ndvi_median       0
# ndwi_median       0
# ndbsi_median      0
# ndre_median       0
# dtype: int64
# vh                0
# vv                0
# rvi               0
# red_median        0
# green_median      0
# blue_median       0
# nir_median        0
# rededge_median    0
# swir16_median     0
# ndvi_median       0
# ndwi_median       0
# ndbsi_median      0
# ndre_median       0
# dtype: int64

# %% [markdown]
# ## Extra constant features (time series descriptors)

# %%
def ordinal_distribution(data, dx=3, dy=1, taux=1, tauy=1, return_missing=False, tie_precision=None):
    '''
    Returns
    -------
     : tuple
       Tuple containing two arrays, one with the ordinal patterns occurring in data 
       and another with their corresponding probabilities.
       
    Attributes
    ---------
    data : array 
           Array object in the format :math:`[x_{1}, x_{2}, x_{3}, \\ldots ,x_{n}]`
           or  :math:`[[x_{11}, x_{12}, x_{13}, \\ldots, x_{1m}],
           \\ldots, [x_{n1}, x_{n2}, x_{n3}, \\ldots, x_{nm}]]`.
    dx : int
         Embedding dimension (horizontal axis) (default: 3).
    dy : int
         Embedding dimension (vertical axis); it must be 1 for time series 
         (default: 1).
    taux : int
           Embedding delay (horizontal axis) (default: 1).
    tauy : int
           Embedding delay (vertical axis) (default: 1).
    return_missing: boolean
                    If `True`, it returns ordinal patterns not appearing in the 
                    symbolic sequence obtained from **data** are shown. If `False`,
                    these missing patterns (permutations) are omitted 
                    (default: `False`).
    tie_precision : int
                    If not `None`, **data** is rounded with `tie_precision`
                    number of decimals (default: `None`).
   
    '''
    def setdiff(a, b):
        '''
        Returns
        -------
        : array
            An array containing the elements in `a` that are not contained in `b`.
            
        Parameters
        ----------    
        a : tuples, lists or arrays
            Array in the format :math:`[[x_{100}, x_{22}, x_{23}, \\ldots, x_{2m}], 
            \\ldots, [x_{n1}, x_{n2}, x_{n3}, ..., x_{nm}]]`.
        b : tuples, lists or arrays
            Array in the format :math:`[[x_{100}, x_{22}, x_{23}, \\ldots, x_{2m}], 
            \\ldots, [x_{n1}, x_{n2}, x_{n3}, ..., x_{nm}]]`.
        '''

        a = np.asarray(a).astype('int64')
        b = np.asarray(b).astype('int64')

        _, ncols = a.shape

        dtype={'names':['f{}'.format(i) for i in range(ncols)],
            'formats':ncols * [a.dtype]}

        C = np.setdiff1d(a.view(dtype), b.view(dtype))
        C = C.view(a.dtype).reshape(-1, ncols)

        return(C)

    try:
        ny, nx = np.shape(data)
        data   = np.array(data)
    except:
        nx     = np.shape(data)[0]
        ny     = 1
        data   = np.array([data])

    if tie_precision is not None:
        data = np.round(data, tie_precision)

    partitions = np.concatenate(
        [
            [np.concatenate(data[j:j+dy*tauy:tauy,i:i+dx*taux:taux]) for i in range(nx-(dx-1)*taux)] 
            for j in range(ny-(dy-1)*tauy)
        ]
    )

    symbols = np.apply_along_axis(np.argsort, 1, partitions)
    symbols, symbols_count = np.unique(symbols, return_counts=True, axis=0)

    probabilities = symbols_count/len(partitions)

    if return_missing==False:
        return symbols, probabilities
    
    else:
        all_symbols   = list(map(list,list(itertools.permutations(np.arange(dx*dy)))))
        miss_symbols  = setdiff(all_symbols, symbols)
        symbols       = np.concatenate((symbols, miss_symbols))
        probabilities = np.concatenate((probabilities, np.zeros(miss_symbols.__len__())))
        
        return symbols, probabilities

# %%
def permutation_entropy(data, dx=3, dy=1, taux=1, tauy=1, base=2, normalized=True, probs=False, tie_precision=None):
    '''
    Returns Permutation Entropy
    Attributes:
    data : array
           Array object in the format :math:`[x_{1}, x_{2}, x_{3}, \\ldots ,x_{n}]`
           or  :math:`[[x_{11}, x_{12}, x_{13}, \\ldots, x_{1m}],
           \\ldots, [x_{n1}, x_{n2}, x_{n3}, \\ldots, x_{nm}]]`
           or an ordinal probability distribution (such as the ones returned by :func:`ordpy.ordinal_distribution`).
    dx :   int
           Embedding dimension (horizontal axis) (default: 3).
    dy :   int
           Embedding dimension (vertical axis); it must be 1 for time series (default: 1).
    taux : int
           Embedding delay (horizontal axis) (default: 1).
    tauy : int
           Embedding delay (vertical axis) (default: 1).
    base : str, int
           Logarithm base in Shannon's entropy. Either 'e' or 2 (default: 2).
    normalized: boolean
                If `True`, permutation entropy is normalized by its maximum value 
                (default: `True`). If `False`, it is not.
    probs : boolean
            If `True`, assumes **data** is an ordinal probability distribution. If 
            `False`, **data** is expected to be a one- or two-dimensional 
            array (default: `False`). 
    tie_precision : int
                    If not `None`, **data** is rounded with `tie_precision`
                    number of decimals (default: `None`).
    '''
    if not probs:
        _, probabilities = ordinal_distribution(data, dx, dy, taux, tauy, return_missing=False, tie_precision=tie_precision)
    else:
        probabilities = np.asarray(data)
        probabilities = probabilities[probabilities>0]

    if normalized==True and base in [2, '2']:        
        smax = np.log2(float(np.math.factorial(dx*dy)))
        s    = -np.sum(probabilities*np.log2(probabilities))
        return s/smax
         
    elif normalized==True and base=='e':        
        smax = np.log(float(np.math.factorial(dx*dy)))
        s    = -np.sum(probabilities*np.log(probabilities))
        return s/smax
    
    elif normalized==False and base in [2, '2']:
        return -np.sum(probabilities*np.log2(probabilities))
    else:
        return -np.sum(probabilities*np.log(probabilities))

# %%
def generate_stastical_features_fix(group):
    '''
    Returns a  list of statistical features such as min,max,range,mean,auto-correlation,permutation entropy for each of the features
    Attributes:
    dataframe - DataFrame consisting of VV,VH and VV/VH for a time period
    '''
    out = group.agg(['min', 'max', 'ptp', 'mean', 'std'])

    for i in [0]:
        out.loc[f'auto_corr_{i+1}', :] = group.apply(lambda x:sm.tsa.acf(x)[i+1])

    out.loc['permut_entropy', :] = group.apply(lambda x:permutation_entropy(x, dx=6, base=2, normalized=True))

    from statsmodels.tsa.stattools import adfuller
    out.loc['adfuller', :] = group.apply(lambda x: adfuller(x)[1] <= 0.05).astype(int)
    
    from scipy.stats import skew, kurtosis
    out.loc['kurtosis', :] = group.apply(kurtosis)

    out.loc['skewness', :] = group.apply(skew)

    # from hurst import compute_Hc
    # out.loc['hurst', :] = group.apply(lambda x: compute_Hc(x)[0])

    from scipy.signal import welch
    out.loc['welch_periodogram', :] = group.apply(lambda x: welch(x, nperseg = 7)[1].mean())

    from antropy import spectral_entropy
    out.loc['spectral_entropy', :] = group.apply(lambda x: spectral_entropy(x, sf=1, method='fft'))

    return out

# %%
descriptors_train = train_ts_data.groupby(level=0).progress_apply(lambda x:generate_stastical_features_fix(x))
descriptors_sub   = sub_ts_data.groupby  (level=0).progress_apply(lambda x:generate_stastical_features_fix(x))
# Out:
#   0%|          | 0/557 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
multicols_names = descriptors_train.unstack().columns.map('_'.join)

descriptors_train = descriptors_train.unstack().droplevel(0, axis=1)
descriptors_train.columns = multicols_names
descriptors_sub   = descriptors_sub.unstack().droplevel(0, axis=1)
descriptors_sub.columns   = multicols_names

display(descriptors_train.head(2), descriptors_sub.head(2))
# Out:
#          vh_min    vh_max    vh_ptp   vh_mean    vh_std  vh_auto_corr_1  \
# index
# 0     -2.227234 -1.461791  0.765443 -1.700036  0.248757        0.746767
# 1     -1.714009 -1.090269  0.623740 -1.390570  0.155056        0.635903
#
#        vh_permut_entropy  vh_adfuller  vh_kurtosis  vh_skewness  ...  \
# index                                                            ...
# 0               0.378208          0.0     0.256126    -1.239160  ...
# 1               0.411605          0.0    -0.564201    -0.137009  ...
#
#        ndre_median_ptp  ndre_median_mean  ndre_median_std  \
# index
# 0             0.625879          0.264481         0.196941
# 1             0.443691          0.275321         0.152664
#
#        ndre_median_auto_corr_1  ndre_median_permut_entropy  \
# index
# 0                     0.896316                    0.211227
# 1                     0.880604                    0.302671
#
#        ndre_median_adfuller  ndre_median_kurtosis  ndre_median_skewness  \
# index
# 0                       0.0             -1.049988             -0.635207
# 1                       0.0             -1.073771             -0.694828
#
#        ndre_median_welch_periodogram  ndre_median_spectral_entropy
# index
# 0                           0.003691                      1.232802
# 1                           0.002713                      1.407610
#
# [2 rows x 156 columns]
#          vh_min    vh_max    vh_ptp   vh_mean    vh_std  vh_auto_corr_1  \
# index
# 0     -2.289285 -1.310438  0.978847 -1.647605  0.306602        0.757823
# 1     -2.278724 -1.239641  1.039083 -1.677527  0.230646        0.615716
#
#        vh_permut_entropy  vh_adfuller  vh_kurtosis  vh_skewness  ...  \
# index                                                            ...
# 0               0.273581          0.0    -0.200842    -1.012147  ...
# 1               0.411605          0.0     1.233447    -0.976471  ...
#
#        ndre_median_ptp  ndre_median_mean  ndre_median_std  \
# index
# 0             0.468540          0.303757         0.125578
# 1             0.462968          0.309389         0.154808
#
#        ndre_median_auto_corr_1  ndre_median_permut_entropy  \
# index
# 0                     0.528394                    0.397557
# 1                     0.762219                    0.411605
#
#        ndre_median_adfuller  ndre_median_kurtosis  ndre_median_skewness  \
# index
# 0                       0.0              0.304603             -0.962316
# 1                       0.0             -0.242953             -1.123766
#
#        ndre_median_welch_periodogram  ndre_median_spectral_entropy
# index
# 0                           0.005512                      1.511666
# 1                           0.009492                      1.899029
#
# [2 rows x 156 columns]

# %%
train_const_data = pd.concat([train_const_data, descriptors_train], axis=1).drop(['start_of_harvest', 'target_class', 'date_of_harvest'], axis=1)
sub_const_data   = pd.concat([sub_const_data  , descriptors_sub], axis=1).drop(['start_of_harvest', 'date_of_harvest'], axis=1)
train_const_data.head(2)
# Out:
#    field_size  rice_yield  season_WS  intensity_T  dayofyear_of_harvest  \
# 0        3.40        5500          0            1                   196
# 1        2.43        6000          0            1                   196
#
#      vh_min    vh_max    vh_ptp   vh_mean    vh_std  ...  ndre_median_ptp  \
# 0 -2.227234 -1.461791  0.765443 -1.700036  0.248757  ...         0.625879
# 1 -1.714009 -1.090269  0.623740 -1.390570  0.155056  ...         0.443691
#
#    ndre_median_mean  ndre_median_std  ndre_median_auto_corr_1  \
# 0          0.264481         0.196941                 0.896316
# 1          0.275321         0.152664                 0.880604
#
#    ndre_median_permut_entropy  ndre_median_adfuller  ndre_median_kurtosis  \
# 0                    0.211227                   0.0             -1.049988
# 1                    0.302671                   0.0             -1.073771
#
#    ndre_median_skewness  ndre_median_welch_periodogram  \
# 0             -0.635207                       0.003691
# 1             -0.694828                       0.002713
#
#    ndre_median_spectral_entropy
# 0                      1.232802
# 1                      1.407610
#
# [2 rows x 161 columns]

# %%
sns.clustermap(train_const_data.corr(), cmap='coolwarm')
# Out:
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
train_const_data.isna().sum().sum(), sub_const_data.isna().sum().sum()
# Out:
# (0, 0)

# %%
train_const_data = train_const_data.fillna(0)
sub_const_data   = sub_const_data.fillna(0)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectPercentile, f_regression
scaler = StandardScaler()
selector = SelectPercentile(f_regression, percentile=80)
selector.fit(scaler.fit_transform(train_const_data.drop('rice_yield', axis=1)), train_const_data.rice_yield)
# Out:
# SelectPercentile(percentile=80,
#                  score_func=<function f_regression at 0x0000016BD8761480>)

# %%
pd.Series(selector.pvalues_[selector.get_support()], index=selector.get_feature_names_out()).plot.barh()
# Out:
# <AxesSubplot: >

# %%
train_const_data_pca = train_const_data.drop('rice_yield', axis=1)
sub_const_data_pca  = sub_const_data

# train_const_data_pca = pd.DataFrame(columns=train_const_data.drop('rice_yield', axis=1).columns[selector.get_support()], data=selector.transform(train_const_data.drop('rice_yield', axis=1)))
# sub_const_data_pca   = pd.DataFrame(columns=sub_const_data.columns[selector.get_support()], data=selector.transform(sub_const_data))

# %% [markdown]
# # Create Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset, TensorDataset

def TrainTorch(xtrain, ytrain, val_data=(None, None), n_epochs=200, model='convnet'):
    
    # Set boolean for validating
    validating = True
    if val_data==(None, None):
        validating = False

    # To CUDA
    xtrain = xtrain.to('cuda')
    ytrain = ytrain.to('cuda')
    if validating:
        val_data = (val_data[0].to('cuda'), val_data[1].to('cuda'))
    
    # From Torch Tensor to Torch Dataset
    dataset_train = TensorDataset(xtrain, ytrain)
    if validating:
        dataset_val   = TensorDataset(*list(val_data))
        
    class TST(nn.Module):
        def __init__(self, seq_len, n_features, n_encoder_layers=1, nhead=4, d_model=4, dim_feedforward=112):
            super(TST, self).__init__()
            self.seq_len = seq_len
            self.n_features = n_features

            self.embedding = nn.Linear(n_features, d_model)

            self.positional_encoding = nn.Parameter(torch.zeros(seq_len, 1, d_model))

            encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward)
            self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_encoder_layers)

            self.flatten = nn.Flatten()

        def forward(self, x):
            # x has shape (batch_size, seq_len, n_features)
            x = self.embedding(x)
            x = x.permute(1, 0, 2)

            # add positional encoding
            x = x + self.positional_encoding[:self.seq_len, :, :]

            # permute input for transformer layer

            # apply transformer encoder
            x = self.encoder(x)

            # permute output to original shape
            x = x.permute(1, 0, 2)

            # flatten output
            # x = self.flatten(x)
        
            return x
        
    # class ConvNet
    class ConvNet(nn.Module):
        def __init__(self, n_features, time_series_length):
            super(ConvNet, self).__init__()
            n_total_features = n_features
            n_features = n_time_features
            feature_map_depth1 = 8
            
            kernel_size = 5
            self.padding_size = kernel_size // 2

            self.transformer = TST(time_series_length, feature_map_depth1)
            self.conv = nn.Conv1d(n_total_features, feature_map_depth1, kernel_size=kernel_size, stride=1, padding=0)
            self.conv2 = nn.Conv1d(feature_map_depth1, feature_map_depth1, kernel_size=kernel_size, stride=1, padding=0)
            self.globalconv = nn.Conv1d(feature_map_depth1, feature_map_depth1, kernel_size=time_series_length, stride=1, padding=0)
            
            self.drop = nn.Dropout(0.25)
            self.relu = nn.ReLU()
            self.pool = nn.MaxPool1d(2)
            
            n_neurons = 512
            self.fc1 = nn.Linear((n_total_features - n_features)*0 + feature_map_depth1*1, n_neurons)
            self.fc2 = nn.Linear(n_neurons, n_neurons)
            
            self.out = nn.Linear(n_neurons, 1)
            
        def forward(self, x, return_encoding=False):
            
            # x_const = torch.mean(x[:, :, :-n_time_features], dim=1)
            # x = x[:, :, -n_time_features:]

            x = x.permute(0, 2, 1) # (Para conv1d tiene que entrar batch size, features, seq_length

            # x = x.permute(0, 2, 1)
            # x = self.transformer(x)
            # x = x.permute(0, 2, 1)
            
            x = F.pad(x, (self.padding_size, self.padding_size), mode='circular')
            x = self.relu(self.conv(x))

            x = F.pad(x, (self.padding_size, self.padding_size), mode='circular')
            x = self.relu(self.conv2(x))
            # x = self.relu(self.conv2(x))
            # x = self.relu(self.conv2(x))
            
            # Max Global Pooling         
            # x = self.globalconv(x).squeeze(axis=2)
            # x = self.relu(x)
            # x = torch.max(x, dim=2)[0]
            # x = torch.mean(x, dim=2)
            # x = torch.flatten(x, 1, 2)

            encoding = x

            # x = torch.concat([x_const, x], dim=1)
            x = self.fc1(x)
            x = self.relu(x)
            x = self.drop(x)
            x = self.fc2(x)
            x = self.relu(x)
            x = self.out(x)
            
            if return_encoding:
                return x, encoding
            else:
                return x
        
    class TransformerNet(nn.Module):
        def __init__(self, input_size, output_size, num_layers, hidden_size, hidden_size_transformer, num_heads, dropout):
            super(TransformerNet, self).__init__()
            input_size = n_time_features
            self.embedding = nn.Linear(input_size, hidden_size)
            self.pos_embedding = nn.Embedding(time_series_length, hidden_size) # positional embedding
            self.transformer_encoder_layer = nn.TransformerEncoderLayer(hidden_size, num_heads, hidden_size_transformer, dropout, batch_first=True, norm_first=True)
            self.transformer_encoder = nn.TransformerEncoder(self.transformer_encoder_layer, num_layers)
            self.fc1 = nn.Linear(hidden_size, hidden_size*2)
            self.fc2 = nn.Linear(hidden_size*2, hidden_size*4)
            self.fc3 = nn.Linear(hidden_size*4, hidden_size*2)
            self.relu = nn.ReLU()
            self.out = nn.Linear(hidden_size*2, output_size)

        def forward(self, x, return_encoding=False):            
            x = x[:, :, -n_time_features:]
            seq_length = x.shape[1]
            pos = torch.arange(seq_length).unsqueeze(0).repeat(x.shape[0], 1).to('cuda') # positional indices
            x = self.embedding(x) + self.pos_embedding(pos)
            x = self.transformer_encoder(x)
            x = F.max_pool1d(x.permute(0, 2, 1), seq_length).squeeze() # global pooling
            encodings = x
            x = self.relu(self.fc1(x))
            x = self.relu(self.fc2(x))
            x = self.relu(self.fc3(x))
            x = self.out(x)
            if return_encoding: return x, encodings
            else: return x
        
    if model =='transformer':
        model = TransformerNet(input_size=n_features, output_size=1, num_layers=1, hidden_size=32, hidden_size_transformer=512, num_heads=4, dropout=0.1).to('cuda')
    elif model == 'convnet':
        model = ConvNet(n_features, time_series_length).to('cuda')
    else:
        raise Exception('Model has to be "convnet" or "transformer".')
    
    # Training parameters
    # optimizer = torch.optim.Adagrad(model.parameters(), lr=10**(-3.0), weight_decay=10**(-3), maximize=True)
    optimizer = torch.optim.AdamW(    model.parameters(), lr=10**(-4.0), weight_decay=10**(-1), maximize=False) # AdamW, 1 wd, 3.7 lr
    # optimizer = torch.optim.Adam(   model.parameters(), lr=10**(-4.0), weight_decay=10**(-2), maximize=False)
    # optimizer = torch.optim.SGD(    model.parameters(), lr=10**(-2.0), weight_decay=10**(-3), maximize=True)
    
    def smooth_r2_loss(y_pred, y_true, smooth_weight=0.3):
        ss_res = torch.sum(torch.square(y_true - y_pred))
        ss_tot = torch.sum(torch.square(y_true - torch.mean(y_true)))
        r2 = 1 - (ss_res + smooth_weight) / (ss_tot + smooth_weight)
        return r2
    criterion = nn.MSELoss()
    # criterion = smooth_r2_loss
    batch_size = 64
    epochs = n_epochs

    
    # Dataset to Dataloader
    dataloader_train = DataLoader(dataset_train    , batch_size=batch_size, shuffle=True)
    n_batches_train = (len(dataset_train) - 1)//batch_size+1
    if validating:
        dataloader_val   = DataLoader(dataset_val      , batch_size=batch_size, shuffle=True)
        n_batches_val   = (len(dataset_val  ) - 1)//batch_size+1
    else:
        n_batches_val = 1


    from sklearn.metrics import r2_score

    # Instantiate validation metrics
    stopping_counter = 0
    best_val_r2 = -np.inf

    # Training
    for epoch_n, epoch in tqdm(enumerate(range(epochs)), total=epochs):

        train_loss = 0.0
        model.train()
        for i, (x_, y_) in enumerate(dataloader_train):

            preds = model(x_)

            # Compute the loss
            loss = criterion(preds, y_)

            # Update the weights
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        model.eval()
        val_r2 = 0.0
        if validating:

            for (x__, y__) in dataloader_val:

                # Forward Pass
                preds = model(x__)

                # Find the R2 score
                r2 = r2_score(y__.detach().cpu().numpy(), preds.detach().cpu().numpy())

                # Calculate R2 score
                val_r2 += r2

            patience = 20
            if val_r2 <= best_val_r2:
                stopping_counter += 1
                if stopping_counter == patience:
                    print(f'{stopping_counter} time(s) has the R2 score not improved. Finishing training...\n',
                        f'best epoch: {epoch_n - patience} "Best" training loss: {round(best_train_loss/n_batches_train, 4)} best val_R2: {np.round(best_val_r2/n_batches_val, 4)}'
                         )
                    break
            else:
                best_val_r2 = val_r2
                best_train_loss = train_loss
                best_model = model
                stopping_counter = 0

        print(f'Training loss: {train_loss/n_batches_train:.4f}', 
        f'Validation R2 score: {val_r2/n_batches_val:.4f}',
        f'Stopping counter: {stopping_counter:02d}    ',
        end='\r')

    if validating:
        return best_model, best_val_r2/n_batches_val
    else:
        return model

# %% [markdown]
# ## Prepare Data for Training

# %%
# Prepare data for training

# concat ts data with constant features
x = pd.concat([train_const_data_pca, train_ts_data.reset_index(level=1)], axis=1)\
.pipe(lambda x:x.set_index([x.index, 'datetime'])).drop(['season_WS'], axis=1)
xsub = pd.concat([sub_const_data_pca, sub_ts_data.reset_index(level=1)], axis=1)\
.pipe(lambda x:x.set_index([x.index, 'datetime'])).drop(['season_WS'], axis=1)

assert (x.columns == xsub.columns).all()

y = train_const_data.rice_yield.groupby(level=0).first().values.reshape(-1, 1)

# Reshape time series
n_samples = len(x)//time_series_length
time_series_length = time_series_length
n_features = x.shape[1]

# Convert to numpy array and reshape (n, length, features)
x    = x.values.reshape(n_samples, time_series_length, n_features)
xsub = xsub.values.reshape(  len(xsub.index.levels[0]), time_series_length, n_features)

display(x.shape, y.shape, xsub.shape)
# Out:
# (557, 20, 172)
# (557, 1)
# (100, 20, 172)

# %%
rand_state = np.random.randint(1, 373737)
rand_state = 190967 # buena correlacion con leaderboard
print(rand_state)

# Split test set
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
splitter = StratifiedShuffleSplit(1, random_state=rand_state, test_size=0.2)
idx_fulltrain, idx_test = list(splitter.split(x, crop_yield_data.target_class))[0]
# Make splits
xfulltrain = x[idx_fulltrain]
yfulltrain = y[idx_fulltrain]
xtest      = x[idx_test]
ytest      = y[idx_test]
target_fulltrain = crop_yield_data.target_class.loc[idx_fulltrain]
target_test      = crop_yield_data.target_class.loc[idx_test]

# Use train set for cross-validation
from sklearn.model_selection import KFold, StratifiedKFold
def KFoldTraining(x_, y_, n_splits=3, is_sklearn=False, model_to_train=None, **kwargs):

    # K folds
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=rand_state+2)
    kfolds = list(kfold.split(x_, y_))
    
    # For each fold, scale data, train and append models
    models = []
    for i, fold in enumerate(kfolds):
        # Splitting
        train_idx, val_idx = fold[0], fold[1]
        xval      = x_[val_idx]
        yval      = y_[val_idx]
        xtrain    = x_[train_idx]
        ytrain    = y_[train_idx]
        
        # Add noise to ytrain
        # ytrain = ytrain + np.random.normal(0, 200, size=ytrain.shape)
        
        if not is_sklearn:
            # Scaling
            # Instantiate scalers
            from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer, RobustScaler
            scaler_x = StandardScaler()
            scaler_y = StandardScaler()
            xtrain = scaler_x.fit_transform(xtrain.reshape(-1, xtrain.shape[2])).reshape(xtrain.shape)
            xval   = scaler_x.transform(xval.reshape(-1, xval.shape[2])).reshape(xval.shape)
            ytrain  = scaler_y.fit_transform(ytrain)
            yval    = scaler_y.transform(yval)
        
        
            # Cast to Tensors
            xtrain = torch.Tensor(xtrain)
            ytrain = torch.Tensor(ytrain)
            xval   = torch.Tensor(xval)
            yval   = torch.Tensor(yval)

            # Train and append model
            models.append(TrainTorch(xtrain, ytrain, (xval, yval), **kwargs))
        else:
            models.append(model_to_train.fit(xtrain, ytrain, eval_set=[(xval, yval)], early_stopping_rounds=10, verbose=100))
        
    return models

def FullDataTraining(x, y, **kwargs):
    # Scaling
    from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer, RobustScaler
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    x    = scaler_x.fit_transform(x.reshape(-1, x.shape[2])).reshape(x.shape)
    y    = scaler_y.fit_transform(y)

    # Cast to Tensors
    x    = torch.Tensor(x)
    y    = torch.Tensor(y)

    # Train and append model
    return TrainTorch(x, y, **kwargs)
# Out:
# 190967

# %% [markdown]
# ## Train on training set

# %%
models_losses = KFoldTraining(xfulltrain, yfulltrain, model='convnet', n_epochs=400)

models = np.array(models_losses)[:, 0]
r2_scores = np.array(models_losses)[:, 1]

print('Average R2 on k-fold:' , r2_scores.mean())
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 22 "Best" training loss: 0.2676 best val_R2: 0.6647
#   0%|          | 0/400 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 23 "Best" training loss: 0.2544 best val_R2: 0.6838
#   0%|          | 0/400 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 28 "Best" training loss: 0.2341 best val_R2: 0.5895
# Average R2 on k-fold: 0.6460210091757599

# %%
model = []
for i in np.linspace(20, 40, 10, dtype=int):
    model.append(FullDataTraining(xfulltrain, yfulltrain, n_epochs=i))
model = np.array(model)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Training loss: 0.3739 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/22 [00:00<?, ?it/s]
# Training loss: 0.3393 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/24 [00:00<?, ?it/s]
# Training loss: 0.3579 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/26 [00:00<?, ?it/s]
# Training loss: 0.3297 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/28 [00:00<?, ?it/s]
# Training loss: 0.3426 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/31 [00:00<?, ?it/s]
# Training loss: 0.3414 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/33 [00:00<?, ?it/s]
# Training loss: 0.3252 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/35 [00:00<?, ?it/s]
# Training loss: 0.3274 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/37 [00:00<?, ?it/s]
# Training loss: 0.3236 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/40 [00:00<?, ?it/s]
# Training loss: 0.3433 Validation R2 score: 0.0000 Stopping counter: 00

# %%
models_losses_transformer = KFoldTraining(xfulltrain, yfulltrain, 10, model='transformer')

models_tr = np.array(models_losses_transformer)[:, 0]
r2_scores = np.array(models_losses_transformer)[:, 1]
print('Average R2 on k-fold:' , r2_scores.mean())
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 30 "Best" training loss: 0.3329 best val_R2: 0.6597
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 49 "Best" training loss: 0.3075 best val_R2: 0.6452
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 24 "Best" training loss: 0.3145 best val_R2: 0.6161
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 70 "Best" training loss: 0.3165 best val_R2: 0.725
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 25 "Best" training loss: 0.3251 best val_R2: 0.7194
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 22 "Best" training loss: 0.3263 best val_R2: 0.5867
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 78 "Best" training loss: 0.2915 best val_R2: 0.7267
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 36 "Best" training loss: 0.3188 best val_R2: 0.6055
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 57 "Best" training loss: 0.3087 best val_R2: 0.5684
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 96 "Best" training loss: 0.2803 best val_R2: 0.7505
# Average R2 on k-fold: 0.6603126234475131

# %%
model_tr = []
for i in np.linspace(30, 70, 10, dtype=int):
    model_tr.append(FullDataTraining(xfulltrain, yfulltrain, n_epochs=i, model='transformer'))
model_tr = np.array(model_tr)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Training loss: 0.3317 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/34 [00:00<?, ?it/s]
# Training loss: 0.3204 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/38 [00:00<?, ?it/s]
# Training loss: 0.3200 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/43 [00:00<?, ?it/s]
# Training loss: 0.3166 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/47 [00:00<?, ?it/s]
# Training loss: 0.3169 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/52 [00:00<?, ?it/s]
# Training loss: 0.3162 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/56 [00:00<?, ?it/s]
# Training loss: 0.3018 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/61 [00:00<?, ?it/s]
# Training loss: 0.2988 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/65 [00:00<?, ?it/s]
# Training loss: 0.3091 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/70 [00:00<?, ?it/s]
# Training loss: 0.3180 Validation R2 score: 0.0000 Stopping counter: 00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18556\260199599.py in <module>
#       1 model_tr = []
#       2 for i in np.linspace(30, 70, 10, dtype=int):
# ----> 3     model_tr.append(FullDataTraining(xfulltrain, yfulltrain, n_epochs=i, model='transformer'))
#       4 model_tr = np.array(model_tr)
#
# ~\AppData\Local\Temp\ipykernel_18556\3228678103.py in FullDataTraining(x, y, **kwargs)
#      74
#      75     # Train and append model
# ---> 76     return TrainTorch(x, y, **kwargs)
#
# ~\AppData\Local\Temp\ipykernel_18556\4015162903.py in TrainTorch(xtrain, ytrain, val_data, n_epochs, model)
#     209             optimizer.zero_grad()
#     210             loss.backward()
# --> 211             optimizer.step()
#     212             train_loss += loss.item()
#     213
#
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#     138                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139                 with torch.autograd.profiler.record_function(profile_name):
# --> 140                     out = func(*args, **kwargs)
#     141                     obj._optimizer_step_code()
#     142                     return out
#
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\torch\optim\adamw.py in step(self, closure)
#     160                 state_steps.append(state['step'])
#     161
# --> 162             adamw(params_with_grad,
#     163                   grads,
#     164                   exp_avgs,
#
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\torch\optim\adamw.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     217         func = _single_tensor_adamw
#     218
# --> 219     func(params,
#     220          grads,
#     221          exp_avgs,
#
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\torch\optim\adamw.py in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     314                 denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     315             else:
# --> 316                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     317
#     318             param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate with test set

# %% [markdown]
# ### Function and Scaling

# %%
def MakePredictions(model, xtest, is_sklearn=False):
    if type(model) is np.ndarray or type(model) is list:
        kfold_preds = []
        for m in model:
            if 'Torch' not in str(type(m)):
                if len(xtest.shape) == 3:
                    xtest_enh = GetEncodings(xtest, model_tr, 'original')
                else:
                    xtest_enh = xtest
                kfold_preds.append(m.predict(xtest_enh).squeeze())
            else:
                if type(xtest) != torch.Tensor:
                    xtest_T = torch.Tensor(xtest)
                kfold_preds.append(m(xtest_T.to('cuda')).cpu().detach().numpy().squeeze())
        preds = np.mean(np.array(kfold_preds), 0)
    else:
        try:
            preds = model.predict(xtest).squeeze()
        except:
            if type(xtest) != torch.Tensor:
                xtest = torch.Tensor(xtest)
                preds = model(xtest.to('cuda')).cpu().detach().numpy().squeeze()

    return preds

def EvaluationPlot(model, xtest, ytest, title='', plot=False, **kwargs):
                   
    preds = MakePredictions(model, xtest, **kwargs)
    
    # comparison preds, real
    from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, r2_score as r2
    
    preds_df = pd.DataFrame(pd.concat([pd.Series(preds),
                                       pd.Series(ytest.squeeze())], axis=1))\
    .assign(error=lambda x:x[1] - x[0],
            mae=lambda x:mae(x[1], x[0]),
            mse=lambda x:np.sqrt(mse(x[1], x[0])),
            r2=lambda x:r2(x[1], x[0]))

    if plot:
        preds_df.pipe(lambda x:sns.regplot(data=x, x=x[1], y=x[0]))
        plt.plot(np.arange(preds_df[1].min(), preds_df[1].max()), np.arange(preds_df[1].min(), preds_df[1].max()), c='k', ls='-', alpha=0.35)
        plt.title(title)
        plt.show()
    print(title)
    display(preds_df.head(1))

# %%
# Scalers for test set
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer, RobustScaler
scaler_x_fulltrain = StandardScaler()
scaler_y_fulltrain = StandardScaler()

xfulltrain = scaler_x_fulltrain.fit_transform(xfulltrain.reshape(-1, xfulltrain.shape[2])).reshape(xfulltrain.shape)
yfulltrain = scaler_y_fulltrain.fit_transform(yfulltrain)
xtest = scaler_x_fulltrain.transform(xtest.reshape(-1, xtest.shape[2])).reshape(xtest.shape)
ytest = scaler_y_fulltrain.transform(ytest)

scaler_x_sub = StandardScaler()
scaler_y_sub = StandardScaler()
scaler_x_sub.fit(x.reshape(-1, x.shape[2]))
scaler_y_sub.fit(y)
xsub = scaler_x_sub.transform(xsub.reshape(-1, xsub.shape[2])).reshape(xsub.shape)

# %%
# Load 0.62 submission
ytrue = scaler_y_sub.transform(pd.read_csv('Version 11.csv').iloc[:, -1].rename('rice_yield').values.round(-1).reshape(-1, 1)).squeeze()

# %% [markdown]
# ### sklearn benchmark

# %%
def GetEncodings(x_basic, models, to_return='both'):
    originals = np.hstack([x_basic.mean(1), x_basic.max(1)])
    if to_return == 'original':
        return originals

    get_preds = lambda m:m(torch.Tensor(x_basic).to('cuda'), return_encoding=True)[1].cpu().detach().numpy()

    if type(models[0]) is not list and type(models[0]) is not np.ndarray: # If the list is a list of the same type of model, like a kfold training
        encodings = []
        for m in models:
            encodings.append(get_preds(m))
        encodings = np.array(encodings).mean(0)

    else: # if the list contains a list of lists of different models, get encodings of each and hstack them
        all_encodings = []
        for list_of_models in models:
            encodings = []
            for m in list_of_models:
                encodings.append(get_preds(m))
            encodings = np.array(encodings).mean(0)
            all_encodings.append(encodings)
        all_encodings = np.hstack(all_encodings)
        encodings = all_encodings
        
    if to_return=='both':
        return np.hstack([originals, encodings])      
    elif to_return=='encodings':
        return encodings
    else:
        raise Exception('to_return must be original, encodings or both')

# %%
x_scaled = scaler_x_sub.transform(x.reshape(-1, x.shape[2])).reshape(x.shape)

# %%
# from skopt import BayesSearchCV
# from skopt.space import Real, Categorical, Integer
# from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor
# from xgboost import XGBRegressor
# from catboost import CatBoostRegressor
# from lightgbm import LGBMRegressor
# # Define the hyperparameter search space
# search_space = dict(
#     l2_leaf_reg = Real(10**-1, 10**2, prior='log-uniform', name='l2_leaf_reg'),
#     depth = Integer(3, 10, name='max_depth'),
#     random_strength = Integer(0, 10),
#     learning_rate = Real(10**-3, 10**0, prior='log-uniform')
# )
# sk_model_cat = CatBoostRegressor(n_estimators=200, verbose=100, task_type='GPU')

# optimizer_cat = BayesSearchCV(sk_model_cat, search_space, n_iter=20, verbose=1, scoring='r2')

# optimizer_cat.fit(xfulltrain_enhanced, yfulltrain)

# print('Optimal parameters:', optimizer_cat.best_params_)

# preds_cat = optimizer_cat.predict(xtest_enhanced)

# from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, r2_score as r2
# EvaluationPlot(optimizer_cat, xtest_enhanced, ytest)

# %%
# sklearn benchmark
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

model_cat = CatBoostRegressor(n_estimators=500, learning_rate=10**-1.5, reg_lambda=10**1.4, verbose=1000, eval_metric='R2')
model_xgb = XGBRegressor(n_estimators=500, learning_rate=10**-1.7, reg_lambda=10**1.4)
model_lgbm = LGBMRegressor(n_estimators=500, learning_rate=10**-1.7, reg_lambda=10**1.4)
model_linear = LinearRegression()
model_gbm = GradientBoostingRegressor(n_estimators=200, learning_rate=10**-1.7)

which = 'original'
x_enhanced = GetEncodings(x_scaled, [model, model_tr], which)
xfulltrain_enhanced = GetEncodings(xfulltrain, [model, model_tr], which)
xtest_enhanced = GetEncodings(xtest, [model, model_tr], which)
xsub_enhanced = GetEncodings(xsub, [model, model_tr], which)

models_cat = KFoldTraining(xfulltrain_enhanced, yfulltrain, 10, is_sklearn=True, model_to_train=model_cat)
# models_2 = model_gbm.fit(xfulltrain_enhanced, yfulltrain)
models_xgb = KFoldTraining(xfulltrain_enhanced, yfulltrain, 5, is_sklearn=True, model_to_train=model_xgb)
models_lgbm = KFoldTraining(xfulltrain_enhanced, yfulltrain, 5, is_sklearn=True, model_to_train=model_lgbm)
# Out:
# 0:	learn: 0.0175236	test: -0.0022314	best: -0.0022314 (0)	total: 183ms	remaining: 1m 31s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.6582526448
# bestIteration = 203
#
# Shrink model to first 204 iterations.
# 0:	learn: 0.0178296	test: -0.0939352	best: -0.0939352 (0)	total: 32.5ms	remaining: 16.2s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.6217071187
# bestIteration = 226
#
# Shrink model to first 227 iterations.
# 0:	learn: 0.0180680	test: -0.0078111	best: -0.0078111 (0)	total: 35.5ms	remaining: 17.7s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.6434672149
# bestIteration = 236
#
# Shrink model to first 237 iterations.
# 0:	learn: 0.0208884	test: -0.0900968	best: -0.0900968 (0)	total: 48.2ms	remaining: 24s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.6942115789
# bestIteration = 319
#
# Shrink model to first 320 iterations.
# 0:	learn: 0.0191155	test: 0.0153814	best: 0.0153814 (0)	total: 79.9ms	remaining: 39.9s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.7075455129
# bestIteration = 325
#
# Shrink model to first 326 iterations.
# 0:	learn: 0.0175547	test: -0.0743655	best: -0.0743655 (0)	total: 31.9ms	remaining: 15.9s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.6321366202
# bestIteration = 153
#
# Shrink model to first 154 iterations.
# 0:	learn: 0.0171019	test: -0.0167576	best: -0.0167576 (0)	total: 34.3ms	remaining: 17.1s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.7207714207
# bestIteration = 449
#
# Shrink model to first 450 iterations.
# 0:	learn: 0.0174267	test: -0.0045860	best: -0.0045860 (0)	total: 54.2ms	remaining: 27s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.5839700129
# bestIteration = 124
#
# Shrink model to first 125 iterations.
# 0:	learn: 0.0174694	test: 0.0137584	best: 0.0137584 (0)	total: 49.4ms	remaining: 24.6s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.5984934577
# bestIteration = 195
#
# Shrink model to first 196 iterations.
# 0:	learn: 0.0169236	test: -0.0086218	best: -0.0086218 (0)	total: 35.7ms	remaining: 17.8s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.6750019671
# bestIteration = 141
#
# Shrink model to first 142 iterations.
# [0]	validation_0-rmse:1.01276
# [1]	validation_0-rmse:1.00097
# [2]	validation_0-rmse:0.98963
# [3]	validation_0-rmse:0.97832
# [4]	validation_0-rmse:0.96707
# [5]	validation_0-rmse:0.95635
# [6]	validation_0-rmse:0.94551
# [7]	validation_0-rmse:0.93534
# [8]	validation_0-rmse:0.92575
# [9]	validation_0-rmse:0.91573
# [10]	validation_0-rmse:0.90629
# [11]	validation_0-rmse:0.89672
# [12]	validation_0-rmse:0.88775
# [13]	validation_0-rmse:0.87886
# [14]	validation_0-rmse:0.87030
# [15]	validation_0-rmse:0.86212
# [16]	validation_0-rmse:0.85397
# [17]	validation_0-rmse:0.84589
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:0.83782
# [19]	validation_0-rmse:0.83052
# [20]	validation_0-rmse:0.82325
# [21]	validation_0-rmse:0.81597
# [22]	validation_0-rmse:0.80938
# [23]	validation_0-rmse:0.80253
# [24]	validation_0-rmse:0.79576
# [25]	validation_0-rmse:0.78910
# [26]	validation_0-rmse:0.78341
# [27]	validation_0-rmse:0.77740
# [28]	validation_0-rmse:0.77132
# [29]	validation_0-rmse:0.76577
# [30]	validation_0-rmse:0.76048
# [31]	validation_0-rmse:0.75523
# [32]	validation_0-rmse:0.74989
# [33]	validation_0-rmse:0.74520
# [34]	validation_0-rmse:0.74022
# [35]	validation_0-rmse:0.73557
# [36]	validation_0-rmse:0.73088
# [37]	validation_0-rmse:0.72638
# [38]	validation_0-rmse:0.72183
# [39]	validation_0-rmse:0.71777
# [40]	validation_0-rmse:0.71340
# [41]	validation_0-rmse:0.70951
# [42]	validation_0-rmse:0.70536
# [43]	validation_0-rmse:0.70160
# [44]	validation_0-rmse:0.69742
# [45]	validation_0-rmse:0.69340
# [46]	validation_0-rmse:0.69001
# [47]	validation_0-rmse:0.68628
# [48]	validation_0-rmse:0.68302
# [49]	validation_0-rmse:0.67975
# [50]	validation_0-rmse:0.67689
# [51]	validation_0-rmse:0.67351
# [52]	validation_0-rmse:0.67066
# [53]	validation_0-rmse:0.66797
# [54]	validation_0-rmse:0.66585
# [55]	validation_0-rmse:0.66305
# [56]	validation_0-rmse:0.66068
# [57]	validation_0-rmse:0.65832
# [58]	validation_0-rmse:0.65637
# [59]	validation_0-rmse:0.65382
# [60]	validation_0-rmse:0.65228
# [61]	validation_0-rmse:0.65049
# [62]	validation_0-rmse:0.64912
# [63]	validation_0-rmse:0.64772
# [64]	validation_0-rmse:0.64588
# [65]	validation_0-rmse:0.64437
# [66]	validation_0-rmse:0.64283
# [67]	validation_0-rmse:0.64103
# [68]	validation_0-rmse:0.63981
# [69]	validation_0-rmse:0.63875
# [70]	validation_0-rmse:0.63731
# [71]	validation_0-rmse:0.63639
# [72]	validation_0-rmse:0.63558
# [73]	validation_0-rmse:0.63477
# [74]	validation_0-rmse:0.63340
# [75]	validation_0-rmse:0.63220
# [76]	validation_0-rmse:0.63109
# [77]	validation_0-rmse:0.63005
# [78]	validation_0-rmse:0.62928
# [79]	validation_0-rmse:0.62855
# [80]	validation_0-rmse:0.62778
# [81]	validation_0-rmse:0.62727
# [82]	validation_0-rmse:0.62623
# [83]	validation_0-rmse:0.62558
# [84]	validation_0-rmse:0.62474
# [85]	validation_0-rmse:0.62434
# [86]	validation_0-rmse:0.62351
# [87]	validation_0-rmse:0.62314
# [88]	validation_0-rmse:0.62260
# [89]	validation_0-rmse:0.62160
# [90]	validation_0-rmse:0.62097
# [91]	validation_0-rmse:0.62031
# [92]	validation_0-rmse:0.61977
# [93]	validation_0-rmse:0.61916
# [94]	validation_0-rmse:0.61865
# [95]	validation_0-rmse:0.61802
# [96]	validation_0-rmse:0.61803
# [97]	validation_0-rmse:0.61769
# [98]	validation_0-rmse:0.61726
# [99]	validation_0-rmse:0.61647
# [100]	validation_0-rmse:0.61609
# [101]	validation_0-rmse:0.61572
# [102]	validation_0-rmse:0.61530
# [103]	validation_0-rmse:0.61483
# [104]	validation_0-rmse:0.61449
# [105]	validation_0-rmse:0.61422
# [106]	validation_0-rmse:0.61376
# [107]	validation_0-rmse:0.61351
# [108]	validation_0-rmse:0.61330
# [109]	validation_0-rmse:0.61299
# [110]	validation_0-rmse:0.61263
# [111]	validation_0-rmse:0.61216
# [112]	validation_0-rmse:0.61204
# [113]	validation_0-rmse:0.61177
# [114]	validation_0-rmse:0.61144
# [115]	validation_0-rmse:0.61118
# [116]	validation_0-rmse:0.61088
# [117]	validation_0-rmse:0.61042
# [118]	validation_0-rmse:0.61056
# [119]	validation_0-rmse:0.61053
# [120]	validation_0-rmse:0.61056
# [121]	validation_0-rmse:0.61079
# [122]	validation_0-rmse:0.61016
# [123]	validation_0-rmse:0.60998
# [124]	validation_0-rmse:0.61006
# [125]	validation_0-rmse:0.60981
# [126]	validation_0-rmse:0.60963
# [127]	validation_0-rmse:0.60968
# [128]	validation_0-rmse:0.60966
# [129]	validation_0-rmse:0.60922
# [130]	validation_0-rmse:0.60938
# [131]	validation_0-rmse:0.60960
# [132]	validation_0-rmse:0.60907
# [133]	validation_0-rmse:0.60870
# [134]	validation_0-rmse:0.60890
# [135]	validation_0-rmse:0.60908
# [136]	validation_0-rmse:0.60891
# [137]	validation_0-rmse:0.60913
# [138]	validation_0-rmse:0.60891
# [139]	validation_0-rmse:0.60870
# [140]	validation_0-rmse:0.60903
# [141]	validation_0-rmse:0.60888
# [142]	validation_0-rmse:0.60908
# [143]	validation_0-rmse:0.60875
# [0]	validation_0-rmse:1.10733
# [1]	validation_0-rmse:1.09185
# [2]	validation_0-rmse:1.07684
# [3]	validation_0-rmse:1.06204
# [4]	validation_0-rmse:1.04824
# [5]	validation_0-rmse:1.03435
# [6]	validation_0-rmse:1.02095
# [7]	validation_0-rmse:1.00693
# [8]	validation_0-rmse:0.99402
# [9]	validation_0-rmse:0.98105
# [10]	validation_0-rmse:0.96867
# [11]	validation_0-rmse:0.95629
# [12]	validation_0-rmse:0.94447
# [13]	validation_0-rmse:0.93267
# [14]	validation_0-rmse:0.92134
# [15]	validation_0-rmse:0.91012
# [16]	validation_0-rmse:0.89959
# [17]	validation_0-rmse:0.88892
# [18]	validation_0-rmse:0.87831
# [19]	validation_0-rmse:0.86840
# [20]	validation_0-rmse:0.85897
# [21]	validation_0-rmse:0.84960
# [22]	validation_0-rmse:0.84022
# [23]	validation_0-rmse:0.83143
# [24]	validation_0-rmse:0.82272
# [25]	validation_0-rmse:0.81439
# [26]	validation_0-rmse:0.80623
# [27]	validation_0-rmse:0.79838
# [28]	validation_0-rmse:0.79063
# [29]	validation_0-rmse:0.78296
# [30]	validation_0-rmse:0.77592
# [31]	validation_0-rmse:0.76884
# [32]	validation_0-rmse:0.76192
# [33]	validation_0-rmse:0.75507
# [34]	validation_0-rmse:0.74844
# [35]	validation_0-rmse:0.74180
# [36]	validation_0-rmse:0.73579
# [37]	validation_0-rmse:0.72972
# [38]	validation_0-rmse:0.72405
# [39]	validation_0-rmse:0.71837
# [40]	validation_0-rmse:0.71306
# [41]	validation_0-rmse:0.70852
# [42]	validation_0-rmse:0.70351
# [43]	validation_0-rmse:0.69817
# [44]	validation_0-rmse:0.69264
# [45]	validation_0-rmse:0.68827
# [46]	validation_0-rmse:0.68337
# [47]	validation_0-rmse:0.67852
# [48]	validation_0-rmse:0.67409
# [49]	validation_0-rmse:0.67038
# [50]	validation_0-rmse:0.66612
# [51]	validation_0-rmse:0.66175
# [52]	validation_0-rmse:0.65798
# [53]	validation_0-rmse:0.65479
# [54]	validation_0-rmse:0.65174
# [55]	validation_0-rmse:0.64851
# [56]	validation_0-rmse:0.64553
# [57]	validation_0-rmse:0.64202
# [58]	validation_0-rmse:0.63898
# [59]	validation_0-rmse:0.63594
# [60]	validation_0-rmse:0.63358
# [61]	validation_0-rmse:0.63082
# [62]	validation_0-rmse:0.62846
# [63]	validation_0-rmse:0.62563
# [64]	validation_0-rmse:0.62376
# [65]	validation_0-rmse:0.62121
# [66]	validation_0-rmse:0.61873
# [67]	validation_0-rmse:0.61632
# [68]	validation_0-rmse:0.61412
# [69]	validation_0-rmse:0.61198
# [70]	validation_0-rmse:0.61045
# [71]	validation_0-rmse:0.60910
# [72]	validation_0-rmse:0.60722
# [73]	validation_0-rmse:0.60567
# [74]	validation_0-rmse:0.60440
# [75]	validation_0-rmse:0.60269
# [76]	validation_0-rmse:0.60134
# [77]	validation_0-rmse:0.60052
# [78]	validation_0-rmse:0.59939
# [79]	validation_0-rmse:0.59784
# [80]	validation_0-rmse:0.59658
# [81]	validation_0-rmse:0.59587
# [82]	validation_0-rmse:0.59449
# [83]	validation_0-rmse:0.59360
# [84]	validation_0-rmse:0.59236
# [85]	validation_0-rmse:0.59142
# [86]	validation_0-rmse:0.59031
# [87]	validation_0-rmse:0.58971
# [88]	validation_0-rmse:0.58856
# [89]	validation_0-rmse:0.58777
# [90]	validation_0-rmse:0.58710
# [91]	validation_0-rmse:0.58646
# [92]	validation_0-rmse:0.58579
# [93]	validation_0-rmse:0.58501
# [94]	validation_0-rmse:0.58468
# [95]	validation_0-rmse:0.58455
# [96]	validation_0-rmse:0.58419
# [97]	validation_0-rmse:0.58330
# [98]	validation_0-rmse:0.58295
# [99]	validation_0-rmse:0.58265
# [100]	validation_0-rmse:0.58204
# [101]	validation_0-rmse:0.58122
# [102]	validation_0-rmse:0.58086
# [103]	validation_0-rmse:0.58066
# [104]	validation_0-rmse:0.58045
# [105]	validation_0-rmse:0.57998
# [106]	validation_0-rmse:0.57970
# [107]	validation_0-rmse:0.57949
# [108]	validation_0-rmse:0.57919
# [109]	validation_0-rmse:0.57894
# [110]	validation_0-rmse:0.57876
# [111]	validation_0-rmse:0.57883
# [112]	validation_0-rmse:0.57885
# [113]	validation_0-rmse:0.57850
# [114]	validation_0-rmse:0.57856
# [115]	validation_0-rmse:0.57859
# [116]	validation_0-rmse:0.57886
# [117]	validation_0-rmse:0.57908
# [118]	validation_0-rmse:0.57941
# [119]	validation_0-rmse:0.57931
# [120]	validation_0-rmse:0.57957
# [121]	validation_0-rmse:0.57976
# [122]	validation_0-rmse:0.57999
# [0]	validation_0-rmse:1.10278
# [1]	validation_0-rmse:1.08922
# [2]	validation_0-rmse:1.07595
# [3]	validation_0-rmse:1.06331
# [4]	validation_0-rmse:1.05067
# [5]	validation_0-rmse:1.03827
# [6]	validation_0-rmse:1.02608
# [7]	validation_0-rmse:1.01438
# [8]	validation_0-rmse:1.00229
# [9]	validation_0-rmse:0.99079
# [10]	validation_0-rmse:0.98072
# [11]	validation_0-rmse:0.97020
# [12]	validation_0-rmse:0.95966
# [13]	validation_0-rmse:0.94902
# [14]	validation_0-rmse:0.93970
# [15]	validation_0-rmse:0.92992
# [16]	validation_0-rmse:0.92084
# [17]	validation_0-rmse:0.91198
# [18]	validation_0-rmse:0.90264
# [19]	validation_0-rmse:0.89471
# [20]	validation_0-rmse:0.88592
# [21]	validation_0-rmse:0.87743
# [22]	validation_0-rmse:0.87032
# [23]	validation_0-rmse:0.86196
# [24]	validation_0-rmse:0.85437
# [25]	validation_0-rmse:0.84710
# [26]	validation_0-rmse:0.83972
# [27]	validation_0-rmse:0.83248
# [28]	validation_0-rmse:0.82599
# [29]	validation_0-rmse:0.81919
# [30]	validation_0-rmse:0.81308
# [31]	validation_0-rmse:0.80640
# [32]	validation_0-rmse:0.80016
# [33]	validation_0-rmse:0.79498
# [34]	validation_0-rmse:0.78909
# [35]	validation_0-rmse:0.78358
# [36]	validation_0-rmse:0.77798
# [37]	validation_0-rmse:0.77276
# [38]	validation_0-rmse:0.76744
# [39]	validation_0-rmse:0.76218
# [40]	validation_0-rmse:0.75738
# [41]	validation_0-rmse:0.75189
# [42]	validation_0-rmse:0.74729
# [43]	validation_0-rmse:0.74210
# [44]	validation_0-rmse:0.73771
# [45]	validation_0-rmse:0.73361
# [46]	validation_0-rmse:0.72949
# [47]	validation_0-rmse:0.72526
# [48]	validation_0-rmse:0.72138
# [49]	validation_0-rmse:0.71735
# [50]	validation_0-rmse:0.71395
# [51]	validation_0-rmse:0.70991
# [52]	validation_0-rmse:0.70635
# [53]	validation_0-rmse:0.70358
# [54]	validation_0-rmse:0.70028
# [55]	validation_0-rmse:0.69696
# [56]	validation_0-rmse:0.69463
# [57]	validation_0-rmse:0.69139
# [58]	validation_0-rmse:0.68849
# [59]	validation_0-rmse:0.68588
# [60]	validation_0-rmse:0.68340
# [61]	validation_0-rmse:0.68069
# [62]	validation_0-rmse:0.67822
# [63]	validation_0-rmse:0.67536
# [64]	validation_0-rmse:0.67331
# [65]	validation_0-rmse:0.67107
# [66]	validation_0-rmse:0.66888
# [67]	validation_0-rmse:0.66678
# [68]	validation_0-rmse:0.66480
# [69]	validation_0-rmse:0.66315
# [70]	validation_0-rmse:0.66129
# [71]	validation_0-rmse:0.65993
# [72]	validation_0-rmse:0.65830
# [73]	validation_0-rmse:0.65651
# [74]	validation_0-rmse:0.65530
# [75]	validation_0-rmse:0.65380
# [76]	validation_0-rmse:0.65229
# [77]	validation_0-rmse:0.65081
# [78]	validation_0-rmse:0.64925
# [79]	validation_0-rmse:0.64786
# [80]	validation_0-rmse:0.64654
# [81]	validation_0-rmse:0.64546
# [82]	validation_0-rmse:0.64411
# [83]	validation_0-rmse:0.64330
# [84]	validation_0-rmse:0.64201
# [85]	validation_0-rmse:0.64070
# [86]	validation_0-rmse:0.63968
# [87]	validation_0-rmse:0.63877
# [88]	validation_0-rmse:0.63765
# [89]	validation_0-rmse:0.63698
# [90]	validation_0-rmse:0.63614
# [91]	validation_0-rmse:0.63566
# [92]	validation_0-rmse:0.63487
# [93]	validation_0-rmse:0.63431
# [94]	validation_0-rmse:0.63350
# [95]	validation_0-rmse:0.63268
# [96]	validation_0-rmse:0.63196
# [97]	validation_0-rmse:0.63104
# [98]	validation_0-rmse:0.63051
# [99]	validation_0-rmse:0.62993
# [100]	validation_0-rmse:0.62908
# [101]	validation_0-rmse:0.62849
# [102]	validation_0-rmse:0.62815
# [103]	validation_0-rmse:0.62759
# [104]	validation_0-rmse:0.62683
# [105]	validation_0-rmse:0.62629
# [106]	validation_0-rmse:0.62529
# [107]	validation_0-rmse:0.62487
# [108]	validation_0-rmse:0.62406
# [109]	validation_0-rmse:0.62306
# [110]	validation_0-rmse:0.62267
# [111]	validation_0-rmse:0.62225
# [112]	validation_0-rmse:0.62142
# [113]	validation_0-rmse:0.62108
# [114]	validation_0-rmse:0.62074
# [115]	validation_0-rmse:0.61995
# [116]	validation_0-rmse:0.61933
# [117]	validation_0-rmse:0.61897
# [118]	validation_0-rmse:0.61837
# [119]	validation_0-rmse:0.61800
# [120]	validation_0-rmse:0.61746
# [121]	validation_0-rmse:0.61713
# [122]	validation_0-rmse:0.61713
# [123]	validation_0-rmse:0.61648
# [124]	validation_0-rmse:0.61601
# [125]	validation_0-rmse:0.61558
# [126]	validation_0-rmse:0.61537
# [127]	validation_0-rmse:0.61505
# [128]	validation_0-rmse:0.61472
# [129]	validation_0-rmse:0.61446
# [130]	validation_0-rmse:0.61470
# [131]	validation_0-rmse:0.61456
# [132]	validation_0-rmse:0.61463
# [133]	validation_0-rmse:0.61447
# [134]	validation_0-rmse:0.61456
# [135]	validation_0-rmse:0.61437
# [136]	validation_0-rmse:0.61400
# [137]	validation_0-rmse:0.61388
# [138]	validation_0-rmse:0.61391
# [139]	validation_0-rmse:0.61334
# [140]	validation_0-rmse:0.61293
# [141]	validation_0-rmse:0.61298
# [142]	validation_0-rmse:0.61289
# [143]	validation_0-rmse:0.61241
# [144]	validation_0-rmse:0.61223
# [145]	validation_0-rmse:0.61221
# [146]	validation_0-rmse:0.61196
# [147]	validation_0-rmse:0.61196
# [148]	validation_0-rmse:0.61201
# [149]	validation_0-rmse:0.61183
# [150]	validation_0-rmse:0.61161
# [151]	validation_0-rmse:0.61138
# [152]	validation_0-rmse:0.61132
# [153]	validation_0-rmse:0.61105
# [154]	validation_0-rmse:0.61104
# [155]	validation_0-rmse:0.61130
# [156]	validation_0-rmse:0.61089
# [157]	validation_0-rmse:0.61106
# [158]	validation_0-rmse:0.61115
# [159]	validation_0-rmse:0.61091
# [160]	validation_0-rmse:0.61103
# [161]	validation_0-rmse:0.61077
# [162]	validation_0-rmse:0.61084
# [163]	validation_0-rmse:0.61105
# [164]	validation_0-rmse:0.61117
# [165]	validation_0-rmse:0.61091
# [166]	validation_0-rmse:0.61109
# [167]	validation_0-rmse:0.61126
# [168]	validation_0-rmse:0.61110
# [169]	validation_0-rmse:0.61088
# [170]	validation_0-rmse:0.61065
# [171]	validation_0-rmse:0.61041
# [172]	validation_0-rmse:0.61010
# [173]	validation_0-rmse:0.61008
# [174]	validation_0-rmse:0.60993
# [175]	validation_0-rmse:0.60950
# [176]	validation_0-rmse:0.60945
# [177]	validation_0-rmse:0.60912
# [178]	validation_0-rmse:0.60912
# [179]	validation_0-rmse:0.60890
# [180]	validation_0-rmse:0.60878
# [181]	validation_0-rmse:0.60809
# [182]	validation_0-rmse:0.60793
# [183]	validation_0-rmse:0.60730
# [184]	validation_0-rmse:0.60729
# [185]	validation_0-rmse:0.60710
# [186]	validation_0-rmse:0.60685
# [187]	validation_0-rmse:0.60676
# [188]	validation_0-rmse:0.60660
# [189]	validation_0-rmse:0.60642
# [190]	validation_0-rmse:0.60653
# [191]	validation_0-rmse:0.60665
# [192]	validation_0-rmse:0.60678
# [193]	validation_0-rmse:0.60655
# [194]	validation_0-rmse:0.60669
# [195]	validation_0-rmse:0.60672
# [196]	validation_0-rmse:0.60648
# [197]	validation_0-rmse:0.60661
# [198]	validation_0-rmse:0.60639
# [199]	validation_0-rmse:0.60644
# [200]	validation_0-rmse:0.60651
# [201]	validation_0-rmse:0.60632
# [202]	validation_0-rmse:0.60635
# [203]	validation_0-rmse:0.60664
# [204]	validation_0-rmse:0.60649
# [205]	validation_0-rmse:0.60636
# [206]	validation_0-rmse:0.60647
# [207]	validation_0-rmse:0.60664
# [208]	validation_0-rmse:0.60695
# [209]	validation_0-rmse:0.60724
# [210]	validation_0-rmse:0.60727
# [211]	validation_0-rmse:0.60734
# [0]	validation_0-rmse:1.14752
# [1]	validation_0-rmse:1.13263
# [2]	validation_0-rmse:1.11806
# [3]	validation_0-rmse:1.10335
# [4]	validation_0-rmse:1.08935
# [5]	validation_0-rmse:1.07559
# [6]	validation_0-rmse:1.06215
# [7]	validation_0-rmse:1.04890
# [8]	validation_0-rmse:1.03593
# [9]	validation_0-rmse:1.02363
# [10]	validation_0-rmse:1.01167
# [11]	validation_0-rmse:0.99933
# [12]	validation_0-rmse:0.98766
# [13]	validation_0-rmse:0.97618
# [14]	validation_0-rmse:0.96502
# [15]	validation_0-rmse:0.95467
# [16]	validation_0-rmse:0.94397
# [17]	validation_0-rmse:0.93374
# [18]	validation_0-rmse:0.92376
# [19]	validation_0-rmse:0.91362
# [20]	validation_0-rmse:0.90405
# [21]	validation_0-rmse:0.89516
# [22]	validation_0-rmse:0.88666
# [23]	validation_0-rmse:0.87880
# [24]	validation_0-rmse:0.86973
# [25]	validation_0-rmse:0.86167
# [26]	validation_0-rmse:0.85392
# [27]	validation_0-rmse:0.84651
# [28]	validation_0-rmse:0.83870
# [29]	validation_0-rmse:0.83217
# [30]	validation_0-rmse:0.82492
# [31]	validation_0-rmse:0.81823
# [32]	validation_0-rmse:0.81170
# [33]	validation_0-rmse:0.80499
# [34]	validation_0-rmse:0.79839
# [35]	validation_0-rmse:0.79189
# [36]	validation_0-rmse:0.78610
# [37]	validation_0-rmse:0.78008
# [38]	validation_0-rmse:0.77452
# [39]	validation_0-rmse:0.76847
# [40]	validation_0-rmse:0.76359
# [41]	validation_0-rmse:0.75746
# [42]	validation_0-rmse:0.75229
# [43]	validation_0-rmse:0.74794
# [44]	validation_0-rmse:0.74302
# [45]	validation_0-rmse:0.73804
# [46]	validation_0-rmse:0.73320
# [47]	validation_0-rmse:0.72904
# [48]	validation_0-rmse:0.72428
# [49]	validation_0-rmse:0.72035
# [50]	validation_0-rmse:0.71616
# [51]	validation_0-rmse:0.71284
# [52]	validation_0-rmse:0.70836
# [53]	validation_0-rmse:0.70432
# [54]	validation_0-rmse:0.70053
# [55]	validation_0-rmse:0.69760
# [56]	validation_0-rmse:0.69424
# [57]	validation_0-rmse:0.69163
# [58]	validation_0-rmse:0.68928
# [59]	validation_0-rmse:0.68638
# [60]	validation_0-rmse:0.68403
# [61]	validation_0-rmse:0.68097
# [62]	validation_0-rmse:0.67863
# [63]	validation_0-rmse:0.67563
# [64]	validation_0-rmse:0.67370
# [65]	validation_0-rmse:0.67066
# [66]	validation_0-rmse:0.66817
# [67]	validation_0-rmse:0.66616
# [68]	validation_0-rmse:0.66369
# [69]	validation_0-rmse:0.66151
# [70]	validation_0-rmse:0.65912
# [71]	validation_0-rmse:0.65719
# [72]	validation_0-rmse:0.65513
# [73]	validation_0-rmse:0.65301
# [74]	validation_0-rmse:0.65157
# [75]	validation_0-rmse:0.65003
# [76]	validation_0-rmse:0.64821
# [77]	validation_0-rmse:0.64632
# [78]	validation_0-rmse:0.64491
# [79]	validation_0-rmse:0.64282
# [80]	validation_0-rmse:0.64155
# [81]	validation_0-rmse:0.64001
# [82]	validation_0-rmse:0.63834
# [83]	validation_0-rmse:0.63650
# [84]	validation_0-rmse:0.63557
# [85]	validation_0-rmse:0.63440
# [86]	validation_0-rmse:0.63327
# [87]	validation_0-rmse:0.63179
# [88]	validation_0-rmse:0.63044
# [89]	validation_0-rmse:0.62931
# [90]	validation_0-rmse:0.62846
# [91]	validation_0-rmse:0.62746
# [92]	validation_0-rmse:0.62637
# [93]	validation_0-rmse:0.62633
# [94]	validation_0-rmse:0.62524
# [95]	validation_0-rmse:0.62417
# [96]	validation_0-rmse:0.62308
# [97]	validation_0-rmse:0.62266
# [98]	validation_0-rmse:0.62165
# [99]	validation_0-rmse:0.62087
# [100]	validation_0-rmse:0.62019
# [101]	validation_0-rmse:0.61931
# [102]	validation_0-rmse:0.61882
# [103]	validation_0-rmse:0.61821
# [104]	validation_0-rmse:0.61762
# [105]	validation_0-rmse:0.61672
# [106]	validation_0-rmse:0.61623
# [107]	validation_0-rmse:0.61548
# [108]	validation_0-rmse:0.61471
# [109]	validation_0-rmse:0.61407
# [110]	validation_0-rmse:0.61346
# [111]	validation_0-rmse:0.61295
# [112]	validation_0-rmse:0.61219
# [113]	validation_0-rmse:0.61203
# [114]	validation_0-rmse:0.61140
# [115]	validation_0-rmse:0.61126
# [116]	validation_0-rmse:0.61082
# [117]	validation_0-rmse:0.60999
# [118]	validation_0-rmse:0.60933
# [119]	validation_0-rmse:0.60880
# [120]	validation_0-rmse:0.60862
# [121]	validation_0-rmse:0.60797
# [122]	validation_0-rmse:0.60751
# [123]	validation_0-rmse:0.60754
# [124]	validation_0-rmse:0.60681
# [125]	validation_0-rmse:0.60688
# [126]	validation_0-rmse:0.60650
# [127]	validation_0-rmse:0.60599
# [128]	validation_0-rmse:0.60592
# [129]	validation_0-rmse:0.60553
# [130]	validation_0-rmse:0.60530
# [131]	validation_0-rmse:0.60509
# [132]	validation_0-rmse:0.60438
# [133]	validation_0-rmse:0.60455
# [134]	validation_0-rmse:0.60407
# [135]	validation_0-rmse:0.60340
# [136]	validation_0-rmse:0.60269
# [137]	validation_0-rmse:0.60317
# [138]	validation_0-rmse:0.60228
# [139]	validation_0-rmse:0.60291
# [140]	validation_0-rmse:0.60257
# [141]	validation_0-rmse:0.60228
# [142]	validation_0-rmse:0.60146
# [143]	validation_0-rmse:0.60109
# [144]	validation_0-rmse:0.60142
# [145]	validation_0-rmse:0.60129
# [146]	validation_0-rmse:0.60129
# [147]	validation_0-rmse:0.60134
# [148]	validation_0-rmse:0.60187
# [149]	validation_0-rmse:0.60122
# [150]	validation_0-rmse:0.60141
# [151]	validation_0-rmse:0.60126
# [152]	validation_0-rmse:0.60067
# [153]	validation_0-rmse:0.60071
# [154]	validation_0-rmse:0.60018
# [155]	validation_0-rmse:0.60029
# [156]	validation_0-rmse:0.60010
# [157]	validation_0-rmse:0.60004
# [158]	validation_0-rmse:0.59973
# [159]	validation_0-rmse:0.59999
# [160]	validation_0-rmse:0.60021
# [161]	validation_0-rmse:0.60000
# [162]	validation_0-rmse:0.59935
# [163]	validation_0-rmse:0.59960
# [164]	validation_0-rmse:0.59940
# [165]	validation_0-rmse:0.59936
# [166]	validation_0-rmse:0.59884
# [167]	validation_0-rmse:0.59913
# [168]	validation_0-rmse:0.59903
# [169]	validation_0-rmse:0.59899
# [170]	validation_0-rmse:0.59908
# [171]	validation_0-rmse:0.59873
# [172]	validation_0-rmse:0.59839
# [173]	validation_0-rmse:0.59815
# [174]	validation_0-rmse:0.59786
# [175]	validation_0-rmse:0.59785
# [176]	validation_0-rmse:0.59754
# [177]	validation_0-rmse:0.59768
# [178]	validation_0-rmse:0.59746
# [179]	validation_0-rmse:0.59741
# [180]	validation_0-rmse:0.59754
# [181]	validation_0-rmse:0.59740
# [182]	validation_0-rmse:0.59718
# [183]	validation_0-rmse:0.59701
# [184]	validation_0-rmse:0.59676
# [185]	validation_0-rmse:0.59651
# [186]	validation_0-rmse:0.59654
# [187]	validation_0-rmse:0.59635
# [188]	validation_0-rmse:0.59625
# [189]	validation_0-rmse:0.59639
# [190]	validation_0-rmse:0.59618
# [191]	validation_0-rmse:0.59590
# [192]	validation_0-rmse:0.59576
# [193]	validation_0-rmse:0.59552
# [194]	validation_0-rmse:0.59552
# [195]	validation_0-rmse:0.59567
# [196]	validation_0-rmse:0.59562
# [197]	validation_0-rmse:0.59567
# [198]	validation_0-rmse:0.59568
# [199]	validation_0-rmse:0.59588
# [200]	validation_0-rmse:0.59613
# [201]	validation_0-rmse:0.59612
# [202]	validation_0-rmse:0.59590
# [0]	validation_0-rmse:1.14357
# [1]	validation_0-rmse:1.12983
# [2]	validation_0-rmse:1.11643
# [3]	validation_0-rmse:1.10339
# [4]	validation_0-rmse:1.09053
# [5]	validation_0-rmse:1.07864
# [6]	validation_0-rmse:1.06641
# [7]	validation_0-rmse:1.05488
# [8]	validation_0-rmse:1.04312
# [9]	validation_0-rmse:1.03201
# [10]	validation_0-rmse:1.02148
# [11]	validation_0-rmse:1.01044
# [12]	validation_0-rmse:0.99984
# [13]	validation_0-rmse:0.98934
# [14]	validation_0-rmse:0.97918
# [15]	validation_0-rmse:0.96926
# [16]	validation_0-rmse:0.96020
# [17]	validation_0-rmse:0.95121
# [18]	validation_0-rmse:0.94174
# [19]	validation_0-rmse:0.93346
# [20]	validation_0-rmse:0.92525
# [21]	validation_0-rmse:0.91717
# [22]	validation_0-rmse:0.90868
# [23]	validation_0-rmse:0.90094
# [24]	validation_0-rmse:0.89352
# [25]	validation_0-rmse:0.88614
# [26]	validation_0-rmse:0.87976
# [27]	validation_0-rmse:0.87240
# [28]	validation_0-rmse:0.86553
# [29]	validation_0-rmse:0.85914
# [30]	validation_0-rmse:0.85270
# [31]	validation_0-rmse:0.84637
# [32]	validation_0-rmse:0.83980
# [33]	validation_0-rmse:0.83457
# [34]	validation_0-rmse:0.82802
# [35]	validation_0-rmse:0.82197
# [36]	validation_0-rmse:0.81709
# [37]	validation_0-rmse:0.81153
# [38]	validation_0-rmse:0.80675
# [39]	validation_0-rmse:0.80090
# [40]	validation_0-rmse:0.79605
# [41]	validation_0-rmse:0.79144
# [42]	validation_0-rmse:0.78653
# [43]	validation_0-rmse:0.78196
# [44]	validation_0-rmse:0.77740
# [45]	validation_0-rmse:0.77333
# [46]	validation_0-rmse:0.76907
# [47]	validation_0-rmse:0.76524
# [48]	validation_0-rmse:0.76122
# [49]	validation_0-rmse:0.75713
# [50]	validation_0-rmse:0.75308
# [51]	validation_0-rmse:0.74999
# [52]	validation_0-rmse:0.74633
# [53]	validation_0-rmse:0.74331
# [54]	validation_0-rmse:0.73999
# [55]	validation_0-rmse:0.73601
# [56]	validation_0-rmse:0.73309
# [57]	validation_0-rmse:0.72973
# [58]	validation_0-rmse:0.72674
# [59]	validation_0-rmse:0.72469
# [60]	validation_0-rmse:0.72098
# [61]	validation_0-rmse:0.71878
# [62]	validation_0-rmse:0.71603
# [63]	validation_0-rmse:0.71337
# [64]	validation_0-rmse:0.71141
# [65]	validation_0-rmse:0.70888
# [66]	validation_0-rmse:0.70694
# [67]	validation_0-rmse:0.70483
# [68]	validation_0-rmse:0.70214
# [69]	validation_0-rmse:0.70009
# [70]	validation_0-rmse:0.69849
# [71]	validation_0-rmse:0.69644
# [72]	validation_0-rmse:0.69509
# [73]	validation_0-rmse:0.69326
# [74]	validation_0-rmse:0.69162
# [75]	validation_0-rmse:0.69003
# [76]	validation_0-rmse:0.68854
# [77]	validation_0-rmse:0.68716
# [78]	validation_0-rmse:0.68581
# [79]	validation_0-rmse:0.68427
# [80]	validation_0-rmse:0.68285
# [81]	validation_0-rmse:0.68140
# [82]	validation_0-rmse:0.68063
# [83]	validation_0-rmse:0.67961
# [84]	validation_0-rmse:0.67853
# [85]	validation_0-rmse:0.67719
# [86]	validation_0-rmse:0.67618
# [87]	validation_0-rmse:0.67483
# [88]	validation_0-rmse:0.67411
# [89]	validation_0-rmse:0.67333
# [90]	validation_0-rmse:0.67213
# [91]	validation_0-rmse:0.67148
# [92]	validation_0-rmse:0.67063
# [93]	validation_0-rmse:0.66966
# [94]	validation_0-rmse:0.66881
# [95]	validation_0-rmse:0.66847
# [96]	validation_0-rmse:0.66773
# [97]	validation_0-rmse:0.66700
# [98]	validation_0-rmse:0.66629
# [99]	validation_0-rmse:0.66552
# [100]	validation_0-rmse:0.66447
# [101]	validation_0-rmse:0.66401
# [102]	validation_0-rmse:0.66374
# [103]	validation_0-rmse:0.66283
# [104]	validation_0-rmse:0.66247
# [105]	validation_0-rmse:0.66225
# [106]	validation_0-rmse:0.66177
# [107]	validation_0-rmse:0.66135
# [108]	validation_0-rmse:0.66081
# [109]	validation_0-rmse:0.66084
# [110]	validation_0-rmse:0.66007
# [111]	validation_0-rmse:0.65992
# [112]	validation_0-rmse:0.65893
# [113]	validation_0-rmse:0.65834
# [114]	validation_0-rmse:0.65770
# [115]	validation_0-rmse:0.65700
# [116]	validation_0-rmse:0.65670
# [117]	validation_0-rmse:0.65643
# [118]	validation_0-rmse:0.65606
# [119]	validation_0-rmse:0.65540
# [120]	validation_0-rmse:0.65505
# [121]	validation_0-rmse:0.65426
# [122]	validation_0-rmse:0.65395
# [123]	validation_0-rmse:0.65319
# [124]	validation_0-rmse:0.65317
# [125]	validation_0-rmse:0.65246
# [126]	validation_0-rmse:0.65166
# [127]	validation_0-rmse:0.65133
# [128]	validation_0-rmse:0.65067
# [129]	validation_0-rmse:0.65049
# [130]	validation_0-rmse:0.64975
# [131]	validation_0-rmse:0.64941
# [132]	validation_0-rmse:0.64898
# [133]	validation_0-rmse:0.64827
# [134]	validation_0-rmse:0.64777
# [135]	validation_0-rmse:0.64792
# [136]	validation_0-rmse:0.64744
# [137]	validation_0-rmse:0.64706
# [138]	validation_0-rmse:0.64663
# [139]	validation_0-rmse:0.64663
# [140]	validation_0-rmse:0.64637
# [141]	validation_0-rmse:0.64585
# [142]	validation_0-rmse:0.64535
# [143]	validation_0-rmse:0.64513
# [144]	validation_0-rmse:0.64498
# [145]	validation_0-rmse:0.64485
# [146]	validation_0-rmse:0.64450
# [147]	validation_0-rmse:0.64451
# [148]	validation_0-rmse:0.64413
# [149]	validation_0-rmse:0.64400
# [150]	validation_0-rmse:0.64402
# [151]	validation_0-rmse:0.64378
# [152]	validation_0-rmse:0.64410
# [153]	validation_0-rmse:0.64400
# [154]	validation_0-rmse:0.64393
# [155]	validation_0-rmse:0.64354
# [156]	validation_0-rmse:0.64359
# [157]	validation_0-rmse:0.64305
# [158]	validation_0-rmse:0.64278
# [159]	validation_0-rmse:0.64301
# [160]	validation_0-rmse:0.64312
# [161]	validation_0-rmse:0.64318
# [162]	validation_0-rmse:0.64288
# [163]	validation_0-rmse:0.64322
# [164]	validation_0-rmse:0.64298
# [165]	validation_0-rmse:0.64307
# [166]	validation_0-rmse:0.64281
# [167]	validation_0-rmse:0.64303
# [1]	valid_0's l2: 1.01752
# [2]	valid_0's l2: 0.994106
# [3]	valid_0's l2: 0.9715
# [4]	valid_0's l2: 0.949674
# [5]	valid_0's l2: 0.928599
# [6]	valid_0's l2: 0.90825
# [7]	valid_0's l2: 0.888602
# [8]	valid_0's l2: 0.870298
# [9]	valid_0's l2: 0.851952
# [10]	valid_0's l2: 0.834866
# [11]	valid_0's l2: 0.818361
# [12]	valid_0's l2: 0.801795
# [13]	valid_0's l2: 0.786389
# [14]	valid_0's l2: 0.770922
# [15]	valid_0's l2: 0.756542
# [16]	valid_0's l2: 0.741942
# [17]	valid_0's l2: 0.728519
# [18]	valid_0's l2: 0.714878
# [19]	valid_0's l2: 0.702348
# [20]	valid_0's l2: 0.689604
# [21]	valid_0's l2: 0.679004
# [22]	valid_0's l2: 0.668767
# [23]	valid_0's l2: 0.657216
# [24]	valid_0's l2: 0.647672
# [25]	valid_0's l2: 0.638374
# [26]	valid_0's l2: 0.627897
# [27]	valid_0's l2: 0.619221
# [28]	valid_0's l2: 0.610842
# [29]	valid_0's l2: 0.601265
# [30]	valid_0's l2: 0.593518
# [31]	valid_0's l2: 0.585969
# [32]	valid_0's l2: 0.577472
# [33]	valid_0's l2: 0.570638
# [34]	valid_0's l2: 0.564616
# [35]	valid_0's l2: 0.557378
# [36]	valid_0's l2: 0.550852
# [37]	valid_0's l2: 0.544809
# [38]	valid_0's l2: 0.538705
# [39]	valid_0's l2: 0.532355
# [40]	valid_0's l2: 0.527063
# [41]	valid_0's l2: 0.521301
# [42]	valid_0's l2: 0.515827
# [43]	valid_0's l2: 0.511377
# [44]	valid_0's l2: 0.50624
# [45]	valid_0's l2: 0.50118
# [46]	valid_0's l2: 0.497191
# [47]	valid_0's l2: 0.492756
# [48]	valid_0's l2: 0.488146
# [49]	valid_0's l2: 0.483701
# [50]	valid_0's l2: 0.479229
# [51]	valid_0's l2: 0.475139
# [52]	valid_0's l2: 0.47209
# [53]	valid_0's l2: 0.469158
# [54]	valid_0's l2: 0.465305
# [55]	valid_0's l2: 0.462138
# [56]	valid_0's l2: 0.45951
# [57]	valid_0's l2: 0.456401
# [58]	valid_0's l2: 0.452562
# [59]	valid_0's l2: 0.44983
# [60]	valid_0's l2: 0.447198
# [61]	valid_0's l2: 0.444677
# [62]	valid_0's l2: 0.441603
# [63]	valid_0's l2: 0.438686
# [64]	valid_0's l2: 0.436367
# [65]	valid_0's l2: 0.434269
# [66]	valid_0's l2: 0.432059
# [67]	valid_0's l2: 0.429847
# [68]	valid_0's l2: 0.428225
# [69]	valid_0's l2: 0.426682
# [70]	valid_0's l2: 0.424429
# [71]	valid_0's l2: 0.422574
# [72]	valid_0's l2: 0.421484
# [73]	valid_0's l2: 0.419372
# [74]	valid_0's l2: 0.417813
# [75]	valid_0's l2: 0.416741
# [76]	valid_0's l2: 0.415018
# [77]	valid_0's l2: 0.413926
# [78]	valid_0's l2: 0.412021
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [79]	valid_0's l2: 0.411332
# [80]	valid_0's l2: 0.410372
# [81]	valid_0's l2: 0.409448
# [82]	valid_0's l2: 0.40794
# [83]	valid_0's l2: 0.406196
# [84]	valid_0's l2: 0.405151
# [85]	valid_0's l2: 0.403756
# [86]	valid_0's l2: 0.403043
# [87]	valid_0's l2: 0.401614
# [88]	valid_0's l2: 0.400787
# [89]	valid_0's l2: 0.399415
# [90]	valid_0's l2: 0.398019
# [91]	valid_0's l2: 0.397019
# [92]	valid_0's l2: 0.39594
# [93]	valid_0's l2: 0.394427
# [94]	valid_0's l2: 0.393147
# [95]	valid_0's l2: 0.392262
# [96]	valid_0's l2: 0.391028
# [97]	valid_0's l2: 0.389844
# [98]	valid_0's l2: 0.389013
# [99]	valid_0's l2: 0.387877
# [100]	valid_0's l2: 0.386875
# [101]	valid_0's l2: 0.386378
# [102]	valid_0's l2: 0.385434
# [103]	valid_0's l2: 0.384709
# [104]	valid_0's l2: 0.383885
# [105]	valid_0's l2: 0.382562
# [106]	valid_0's l2: 0.382176
# [107]	valid_0's l2: 0.381328
# [108]	valid_0's l2: 0.380412
# [109]	valid_0's l2: 0.380136
# [110]	valid_0's l2: 0.379802
# [111]	valid_0's l2: 0.379158
# [112]	valid_0's l2: 0.378512
# [113]	valid_0's l2: 0.378213
# [114]	valid_0's l2: 0.377936
# [115]	valid_0's l2: 0.377803
# [116]	valid_0's l2: 0.377282
# [117]	valid_0's l2: 0.377013
# [118]	valid_0's l2: 0.376653
# [119]	valid_0's l2: 0.375984
# [120]	valid_0's l2: 0.37605
# [121]	valid_0's l2: 0.375586
# [122]	valid_0's l2: 0.375254
# [123]	valid_0's l2: 0.375141
# [124]	valid_0's l2: 0.374641
# [125]	valid_0's l2: 0.374183
# [126]	valid_0's l2: 0.373824
# [127]	valid_0's l2: 0.373752
# [128]	valid_0's l2: 0.373422
# [129]	valid_0's l2: 0.373065
# [130]	valid_0's l2: 0.373188
# [131]	valid_0's l2: 0.373235
# [132]	valid_0's l2: 0.372948
# [133]	valid_0's l2: 0.372675
# [134]	valid_0's l2: 0.372414
# [135]	valid_0's l2: 0.371764
# [136]	valid_0's l2: 0.371949
# [137]	valid_0's l2: 0.371327
# [138]	valid_0's l2: 0.371107
# [139]	valid_0's l2: 0.370332
# [140]	valid_0's l2: 0.369622
# [141]	valid_0's l2: 0.369837
# [142]	valid_0's l2: 0.369504
# [143]	valid_0's l2: 0.369217
# [144]	valid_0's l2: 0.369317
# [145]	valid_0's l2: 0.369237
# [146]	valid_0's l2: 0.368501
# [147]	valid_0's l2: 0.368412
# [148]	valid_0's l2: 0.367814
# [149]	valid_0's l2: 0.367546
# [150]	valid_0's l2: 0.367442
# [151]	valid_0's l2: 0.366719
# [152]	valid_0's l2: 0.366652
# [153]	valid_0's l2: 0.366232
# [154]	valid_0's l2: 0.366324
# [155]	valid_0's l2: 0.36622
# [156]	valid_0's l2: 0.366001
# [157]	valid_0's l2: 0.366462
# [158]	valid_0's l2: 0.367013
# [159]	valid_0's l2: 0.367045
# [160]	valid_0's l2: 0.366758
# [161]	valid_0's l2: 0.367325
# [162]	valid_0's l2: 0.367246
# [163]	valid_0's l2: 0.366676
# [164]	valid_0's l2: 0.36656
# [165]	valid_0's l2: 0.366194
# [166]	valid_0's l2: 0.366782
# [1]	valid_0's l2: 0.928938
# [2]	valid_0's l2: 0.906077
# [3]	valid_0's l2: 0.884025
# [4]	valid_0's l2: 0.862754
# [5]	valid_0's l2: 0.842237
# [6]	valid_0's l2: 0.823755
# [7]	valid_0's l2: 0.80511
# [8]	valid_0's l2: 0.786645
# [9]	valid_0's l2: 0.77006
# [10]	valid_0's l2: 0.753067
# [11]	valid_0's l2: 0.737631
# [12]	valid_0's l2: 0.721796
# [13]	valid_0's l2: 0.707433
# [14]	valid_0's l2: 0.693582
# [15]	valid_0's l2: 0.679326
# [16]	valid_0's l2: 0.666393
# [17]	valid_0's l2: 0.653111
# [18]	valid_0's l2: 0.641082
# [19]	valid_0's l2: 0.629484
# [20]	valid_0's l2: 0.61753
# [21]	valid_0's l2: 0.606745
# [22]	valid_0's l2: 0.595612
# [23]	valid_0's l2: 0.585584
# [24]	valid_0's l2: 0.576255
# [25]	valid_0's l2: 0.566233
# [26]	valid_0's l2: 0.557568
# [27]	valid_0's l2: 0.549349
# [28]	valid_0's l2: 0.541354
# [29]	valid_0's l2: 0.533525
# [30]	valid_0's l2: 0.526095
# [31]	valid_0's l2: 0.51882
# [32]	valid_0's l2: 0.511444
# [33]	valid_0's l2: 0.504792
# [34]	valid_0's l2: 0.49896
# [35]	valid_0's l2: 0.492764
# [36]	valid_0's l2: 0.487349
# [37]	valid_0's l2: 0.481618
# [38]	valid_0's l2: 0.475933
# [39]	valid_0's l2: 0.470454
# [40]	valid_0's l2: 0.464433
# [41]	valid_0's l2: 0.459391
# [42]	valid_0's l2: 0.455217
# [43]	valid_0's l2: 0.450406
# [44]	valid_0's l2: 0.445066
# [45]	valid_0's l2: 0.441215
# [46]	valid_0's l2: 0.437954
# [47]	valid_0's l2: 0.433854
# [48]	valid_0's l2: 0.43051
# [49]	valid_0's l2: 0.426362
# [50]	valid_0's l2: 0.423275
# [51]	valid_0's l2: 0.420159
# [52]	valid_0's l2: 0.416591
# [53]	valid_0's l2: 0.413434
# [54]	valid_0's l2: 0.410307
# [55]	valid_0's l2: 0.407764
# [56]	valid_0's l2: 0.405507
# [57]	valid_0's l2: 0.403345
# [58]	valid_0's l2: 0.400235
# [59]	valid_0's l2: 0.397844
# [60]	valid_0's l2: 0.395131
# [61]	valid_0's l2: 0.392942
# [62]	valid_0's l2: 0.39134
# [63]	valid_0's l2: 0.389076
# [64]	valid_0's l2: 0.386888
# [65]	valid_0's l2: 0.385411
# [66]	valid_0's l2: 0.383723
# [67]	valid_0's l2: 0.382063
# [68]	valid_0's l2: 0.380521
# [69]	valid_0's l2: 0.37861
# [70]	valid_0's l2: 0.377156
# [71]	valid_0's l2: 0.375985
# [72]	valid_0's l2: 0.374699
# [73]	valid_0's l2: 0.373395
# [74]	valid_0's l2: 0.372192
# [75]	valid_0's l2: 0.370772
# [76]	valid_0's l2: 0.369722
# [77]	valid_0's l2: 0.368794
# [78]	valid_0's l2: 0.367601
# [79]	valid_0's l2: 0.366821
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [80]	valid_0's l2: 0.365206
# [81]	valid_0's l2: 0.364055
# [82]	valid_0's l2: 0.36296
# [83]	valid_0's l2: 0.362103
# [84]	valid_0's l2: 0.361039
# [85]	valid_0's l2: 0.360099
# [86]	valid_0's l2: 0.359178
# [87]	valid_0's l2: 0.358153
# [88]	valid_0's l2: 0.357398
# [89]	valid_0's l2: 0.356568
# [90]	valid_0's l2: 0.355775
# [91]	valid_0's l2: 0.355165
# [92]	valid_0's l2: 0.354696
# [93]	valid_0's l2: 0.353726
# [94]	valid_0's l2: 0.352963
# [95]	valid_0's l2: 0.352176
# [96]	valid_0's l2: 0.351298
# [97]	valid_0's l2: 0.350731
# [98]	valid_0's l2: 0.350198
# [99]	valid_0's l2: 0.350108
# [100]	valid_0's l2: 0.349762
# [101]	valid_0's l2: 0.349009
# [102]	valid_0's l2: 0.348008
# [103]	valid_0's l2: 0.347158
# [104]	valid_0's l2: 0.346896
# [105]	valid_0's l2: 0.346637
# [106]	valid_0's l2: 0.346021
# [107]	valid_0's l2: 0.345525
# [108]	valid_0's l2: 0.34444
# [109]	valid_0's l2: 0.343873
# [110]	valid_0's l2: 0.342923
# [111]	valid_0's l2: 0.342586
# [112]	valid_0's l2: 0.342401
# [113]	valid_0's l2: 0.342233
# [114]	valid_0's l2: 0.341652
# [115]	valid_0's l2: 0.341184
# [116]	valid_0's l2: 0.340789
# [117]	valid_0's l2: 0.340359
# [118]	valid_0's l2: 0.34003
# [119]	valid_0's l2: 0.339772
# [120]	valid_0's l2: 0.33934
# [121]	valid_0's l2: 0.338967
# [122]	valid_0's l2: 0.338926
# [123]	valid_0's l2: 0.337944
# [124]	valid_0's l2: 0.337417
# [125]	valid_0's l2: 0.337569
# [126]	valid_0's l2: 0.336984
# [127]	valid_0's l2: 0.33691
# [128]	valid_0's l2: 0.337408
# [129]	valid_0's l2: 0.336663
# [130]	valid_0's l2: 0.336139
# [131]	valid_0's l2: 0.335704
# [132]	valid_0's l2: 0.335774
# [133]	valid_0's l2: 0.335344
# [134]	valid_0's l2: 0.335505
# [135]	valid_0's l2: 0.335218
# [136]	valid_0's l2: 0.334693
# [137]	valid_0's l2: 0.334618
# [138]	valid_0's l2: 0.334891
# [139]	valid_0's l2: 0.33503
# [140]	valid_0's l2: 0.334608
# [141]	valid_0's l2: 0.335024
# [142]	valid_0's l2: 0.334415
# [143]	valid_0's l2: 0.334643
# [144]	valid_0's l2: 0.334498
# [145]	valid_0's l2: 0.334128
# [146]	valid_0's l2: 0.333777
# [147]	valid_0's l2: 0.334305
# [148]	valid_0's l2: 0.334241
# [149]	valid_0's l2: 0.334229
# [150]	valid_0's l2: 0.334578
# [151]	valid_0's l2: 0.33471
# [152]	valid_0's l2: 0.334848
# [153]	valid_0's l2: 0.335041
# [154]	valid_0's l2: 0.33539
# [155]	valid_0's l2: 0.335046
# [156]	valid_0's l2: 0.334868
# [1]	valid_0's l2: 1.03299
# [2]	valid_0's l2: 1.00986
# [3]	valid_0's l2: 0.987515
# [4]	valid_0's l2: 0.965932
# [5]	valid_0's l2: 0.945085
# [6]	valid_0's l2: 0.924948
# [7]	valid_0's l2: 0.905497
# [8]	valid_0's l2: 0.886709
# [9]	valid_0's l2: 0.868561
# [10]	valid_0's l2: 0.85103
# [11]	valid_0's l2: 0.834097
# [12]	valid_0's l2: 0.81774
# [13]	valid_0's l2: 0.80194
# [14]	valid_0's l2: 0.786677
# [15]	valid_0's l2: 0.773013
# [16]	valid_0's l2: 0.759821
# [17]	valid_0's l2: 0.747084
# [18]	valid_0's l2: 0.733752
# [19]	valid_0's l2: 0.721885
# [20]	valid_0's l2: 0.710429
# [21]	valid_0's l2: 0.699369
# [22]	valid_0's l2: 0.687753
# [23]	valid_0's l2: 0.677448
# [24]	valid_0's l2: 0.667402
# [25]	valid_0's l2: 0.656901
# [26]	valid_0's l2: 0.647526
# [27]	valid_0's l2: 0.638471
# [28]	valid_0's l2: 0.628968
# [29]	valid_0's l2: 0.620519
# [30]	valid_0's l2: 0.612694
# [31]	valid_0's l2: 0.60537
# [32]	valid_0's l2: 0.598034
# [33]	valid_0's l2: 0.590385
# [34]	valid_0's l2: 0.583753
# [35]	valid_0's l2: 0.577899
# [36]	valid_0's l2: 0.571689
# [37]	valid_0's l2: 0.566151
# [38]	valid_0's l2: 0.560088
# [39]	valid_0's l2: 0.554381
# [40]	valid_0's l2: 0.549442
# [41]	valid_0's l2: 0.543943
# [42]	valid_0's l2: 0.538138
# [43]	valid_0's l2: 0.533281
# [44]	valid_0's l2: 0.528472
# [45]	valid_0's l2: 0.523676
# [46]	valid_0's l2: 0.519579
# [47]	valid_0's l2: 0.515153
# [48]	valid_0's l2: 0.511199
# [49]	valid_0's l2: 0.506631
# [50]	valid_0's l2: 0.502912
# [51]	valid_0's l2: 0.498541
# [52]	valid_0's l2: 0.494495
# [53]	valid_0's l2: 0.490319
# [54]	valid_0's l2: 0.487646
# [55]	valid_0's l2: 0.484349
# [56]	valid_0's l2: 0.481508
# [57]	valid_0's l2: 0.477858
# [58]	valid_0's l2: 0.474325
# [59]	valid_0's l2: 0.470556
# [60]	valid_0's l2: 0.467806
# [61]	valid_0's l2: 0.464503
# [62]	valid_0's l2: 0.461654
# [63]	valid_0's l2: 0.459177
# [64]	valid_0's l2: 0.456127
# [65]	valid_0's l2: 0.453101
# [66]	valid_0's l2: 0.450552
# [67]	valid_0's l2: 0.448421
# [68]	valid_0's l2: 0.44564
# [69]	valid_0's l2: 0.443403
# [70]	valid_0's l2: 0.441399
# [71]	valid_0's l2: 0.439165
# [72]	valid_0's l2: 0.436932
# [73]	valid_0's l2: 0.435018
# [74]	valid_0's l2: 0.432683
# [75]	valid_0's l2: 0.430521
# [76]	valid_0's l2: 0.428433
# [77]	valid_0's l2: 0.426618
# [78]	valid_0's l2: 0.424941
# [79]	valid_0's l2: 0.423005
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [80]	valid_0's l2: 0.42121
# [81]	valid_0's l2: 0.419903
# [82]	valid_0's l2: 0.418469
# [83]	valid_0's l2: 0.41696
# [84]	valid_0's l2: 0.415235
# [85]	valid_0's l2: 0.41343
# [86]	valid_0's l2: 0.412113
# [87]	valid_0's l2: 0.411077
# [88]	valid_0's l2: 0.40955
# [89]	valid_0's l2: 0.408082
# [90]	valid_0's l2: 0.407407
# [91]	valid_0's l2: 0.405769
# [92]	valid_0's l2: 0.40472
# [93]	valid_0's l2: 0.404142
# [94]	valid_0's l2: 0.403119
# [95]	valid_0's l2: 0.402606
# [96]	valid_0's l2: 0.401691
# [97]	valid_0's l2: 0.401238
# [98]	valid_0's l2: 0.400818
# [99]	valid_0's l2: 0.399883
# [100]	valid_0's l2: 0.399514
# [101]	valid_0's l2: 0.398825
# [102]	valid_0's l2: 0.39822
# [103]	valid_0's l2: 0.397596
# [104]	valid_0's l2: 0.396811
# [105]	valid_0's l2: 0.396093
# [106]	valid_0's l2: 0.395751
# [107]	valid_0's l2: 0.394921
# [108]	valid_0's l2: 0.394724
# [109]	valid_0's l2: 0.394172
# [110]	valid_0's l2: 0.393553
# [111]	valid_0's l2: 0.392776
# [112]	valid_0's l2: 0.391648
# [113]	valid_0's l2: 0.391253
# [114]	valid_0's l2: 0.390515
# [115]	valid_0's l2: 0.390325
# [116]	valid_0's l2: 0.390547
# [117]	valid_0's l2: 0.389816
# [118]	valid_0's l2: 0.389567
# [119]	valid_0's l2: 0.389759
# [120]	valid_0's l2: 0.389271
# [121]	valid_0's l2: 0.389028
# [122]	valid_0's l2: 0.388733
# [123]	valid_0's l2: 0.387992
# [124]	valid_0's l2: 0.387983
# [125]	valid_0's l2: 0.388247
# [126]	valid_0's l2: 0.387711
# [127]	valid_0's l2: 0.388039
# [128]	valid_0's l2: 0.387562
# [129]	valid_0's l2: 0.387606
# [130]	valid_0's l2: 0.387362
# [131]	valid_0's l2: 0.387181
# [132]	valid_0's l2: 0.386789
# [133]	valid_0's l2: 0.386978
# [134]	valid_0's l2: 0.386799
# [135]	valid_0's l2: 0.386632
# [136]	valid_0's l2: 0.386482
# [137]	valid_0's l2: 0.386035
# [138]	valid_0's l2: 0.386189
# [139]	valid_0's l2: 0.385947
# [140]	valid_0's l2: 0.386119
# [141]	valid_0's l2: 0.385918
# [142]	valid_0's l2: 0.384937
# [143]	valid_0's l2: 0.384857
# [144]	valid_0's l2: 0.384656
# [145]	valid_0's l2: 0.384754
# [146]	valid_0's l2: 0.384303
# [147]	valid_0's l2: 0.384287
# [148]	valid_0's l2: 0.38415
# [149]	valid_0's l2: 0.383936
# [150]	valid_0's l2: 0.383985
# [151]	valid_0's l2: 0.384039
# [152]	valid_0's l2: 0.384301
# [153]	valid_0's l2: 0.384578
# [154]	valid_0's l2: 0.384652
# [155]	valid_0's l2: 0.384662
# [156]	valid_0's l2: 0.384768
# [157]	valid_0's l2: 0.384859
# [158]	valid_0's l2: 0.385118
# [159]	valid_0's l2: 0.384954
# [1]	valid_0's l2: 0.959407
# [2]	valid_0's l2: 0.937659
# [3]	valid_0's l2: 0.916643
# [4]	valid_0's l2: 0.896334
# [5]	valid_0's l2: 0.876709
# [6]	valid_0's l2: 0.857743
# [7]	valid_0's l2: 0.839415
# [8]	valid_0's l2: 0.821703
# [9]	valid_0's l2: 0.804586
# [10]	valid_0's l2: 0.788043
# [11]	valid_0's l2: 0.772057
# [12]	valid_0's l2: 0.756606
# [13]	valid_0's l2: 0.741674
# [14]	valid_0's l2: 0.727243
# [15]	valid_0's l2: 0.713295
# [16]	valid_0's l2: 0.699271
# [17]	valid_0's l2: 0.686245
# [18]	valid_0's l2: 0.673655
# [19]	valid_0's l2: 0.661486
# [20]	valid_0's l2: 0.649219
# [21]	valid_0's l2: 0.637974
# [22]	valid_0's l2: 0.626519
# [23]	valid_0's l2: 0.616064
# [24]	valid_0's l2: 0.60535
# [25]	valid_0's l2: 0.595559
# [26]	valid_0's l2: 0.586105
# [27]	valid_0's l2: 0.57646
# [28]	valid_0's l2: 0.567668
# [29]	valid_0's l2: 0.558775
# [30]	valid_0's l2: 0.550566
# [31]	valid_0's l2: 0.542601
# [32]	valid_0's l2: 0.534918
# [33]	valid_0's l2: 0.527974
# [34]	valid_0's l2: 0.521008
# [35]	valid_0's l2: 0.514044
# [36]	valid_0's l2: 0.508159
# [37]	valid_0's l2: 0.501624
# [38]	valid_0's l2: 0.496557
# [39]	valid_0's l2: 0.49119
# [40]	valid_0's l2: 0.486383
# [41]	valid_0's l2: 0.48175
# [42]	valid_0's l2: 0.476387
# [43]	valid_0's l2: 0.472058
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [44]	valid_0's l2: 0.467904
# [45]	valid_0's l2: 0.464233
# [46]	valid_0's l2: 0.459247
# [47]	valid_0's l2: 0.455806
# [48]	valid_0's l2: 0.45198
# [49]	valid_0's l2: 0.448757
# [50]	valid_0's l2: 0.445091
# [51]	valid_0's l2: 0.442257
# [52]	valid_0's l2: 0.438834
# [53]	valid_0's l2: 0.436841
# [54]	valid_0's l2: 0.433405
# [55]	valid_0's l2: 0.430254
# [56]	valid_0's l2: 0.428007
# [57]	valid_0's l2: 0.425469
# [58]	valid_0's l2: 0.423216
# [59]	valid_0's l2: 0.420883
# [60]	valid_0's l2: 0.418922
# [61]	valid_0's l2: 0.416412
# [62]	valid_0's l2: 0.414756
# [63]	valid_0's l2: 0.412712
# [64]	valid_0's l2: 0.411281
# [65]	valid_0's l2: 0.409141
# [66]	valid_0's l2: 0.407746
# [67]	valid_0's l2: 0.40631
# [68]	valid_0's l2: 0.404415
# [69]	valid_0's l2: 0.402578
# [70]	valid_0's l2: 0.400718
# [71]	valid_0's l2: 0.398671
# [72]	valid_0's l2: 0.397954
# [73]	valid_0's l2: 0.396482
# [74]	valid_0's l2: 0.394531
# [75]	valid_0's l2: 0.393162
# [76]	valid_0's l2: 0.391481
# [77]	valid_0's l2: 0.39021
# [78]	valid_0's l2: 0.38866
# [79]	valid_0's l2: 0.387074
# [80]	valid_0's l2: 0.385335
# [81]	valid_0's l2: 0.383913
# [82]	valid_0's l2: 0.382509
# [83]	valid_0's l2: 0.381214
# [84]	valid_0's l2: 0.379559
# [85]	valid_0's l2: 0.377975
# [86]	valid_0's l2: 0.377151
# [87]	valid_0's l2: 0.375759
# [88]	valid_0's l2: 0.374574
# [89]	valid_0's l2: 0.373856
# [90]	valid_0's l2: 0.372462
# [91]	valid_0's l2: 0.371242
# [92]	valid_0's l2: 0.369987
# [93]	valid_0's l2: 0.368685
# [94]	valid_0's l2: 0.367542
# [95]	valid_0's l2: 0.367175
# [96]	valid_0's l2: 0.36607
# [97]	valid_0's l2: 0.364803
# [98]	valid_0's l2: 0.363649
# [99]	valid_0's l2: 0.36287
# [100]	valid_0's l2: 0.362171
# [101]	valid_0's l2: 0.360991
# [102]	valid_0's l2: 0.360075
# [103]	valid_0's l2: 0.359659
# [104]	valid_0's l2: 0.359139
# [105]	valid_0's l2: 0.358527
# [106]	valid_0's l2: 0.358168
# [107]	valid_0's l2: 0.357437
# [108]	valid_0's l2: 0.356227
# [109]	valid_0's l2: 0.355845
# [110]	valid_0's l2: 0.354804
# [111]	valid_0's l2: 0.354808
# [112]	valid_0's l2: 0.354015
# [113]	valid_0's l2: 0.3529
# [114]	valid_0's l2: 0.352415
# [115]	valid_0's l2: 0.35184
# [116]	valid_0's l2: 0.351141
# [117]	valid_0's l2: 0.350851
# [118]	valid_0's l2: 0.350371
# [119]	valid_0's l2: 0.349504
# [120]	valid_0's l2: 0.349163
# [121]	valid_0's l2: 0.348484
# [122]	valid_0's l2: 0.347904
# [123]	valid_0's l2: 0.347172
# [124]	valid_0's l2: 0.346783
# [125]	valid_0's l2: 0.345728
# [126]	valid_0's l2: 0.344773
# [127]	valid_0's l2: 0.344656
# [128]	valid_0's l2: 0.343822
# [129]	valid_0's l2: 0.343983
# [130]	valid_0's l2: 0.343643
# [131]	valid_0's l2: 0.342763
# [132]	valid_0's l2: 0.341886
# [133]	valid_0's l2: 0.341462
# [134]	valid_0's l2: 0.341198
# [135]	valid_0's l2: 0.341038
# [136]	valid_0's l2: 0.340552
# [137]	valid_0's l2: 0.340187
# [138]	valid_0's l2: 0.339843
# [139]	valid_0's l2: 0.339701
# [140]	valid_0's l2: 0.339301
# [141]	valid_0's l2: 0.339009
# [142]	valid_0's l2: 0.338233
# [143]	valid_0's l2: 0.338128
# [144]	valid_0's l2: 0.337696
# [145]	valid_0's l2: 0.33726
# [146]	valid_0's l2: 0.3371
# [147]	valid_0's l2: 0.336929
# [148]	valid_0's l2: 0.336524
# [149]	valid_0's l2: 0.336243
# [150]	valid_0's l2: 0.335929
# [151]	valid_0's l2: 0.336119
# [152]	valid_0's l2: 0.335819
# [153]	valid_0's l2: 0.335728
# [154]	valid_0's l2: 0.335855
# [155]	valid_0's l2: 0.335517
# [156]	valid_0's l2: 0.335611
# [157]	valid_0's l2: 0.335427
# [158]	valid_0's l2: 0.335224
# [159]	valid_0's l2: 0.335267
# [160]	valid_0's l2: 0.335199
# [161]	valid_0's l2: 0.335295
# [162]	valid_0's l2: 0.335372
# [163]	valid_0's l2: 0.335285
# [164]	valid_0's l2: 0.335509
# [165]	valid_0's l2: 0.335557
# [166]	valid_0's l2: 0.335363
# [167]	valid_0's l2: 0.335406
# [168]	valid_0's l2: 0.335617
# [169]	valid_0's l2: 0.33595
# [170]	valid_0's l2: 0.336018
# [1]	valid_0's l2: 0.987067
# [2]	valid_0's l2: 0.965128
# [3]	valid_0's l2: 0.943564
# [4]	valid_0's l2: 0.922743
# [5]	valid_0's l2: 0.903007
# [6]	valid_0's l2: 0.883586
# [7]	valid_0's l2: 0.864834
# [8]	valid_0's l2: 0.847083
# [9]	valid_0's l2: 0.829591
# [10]	valid_0's l2: 0.812702
# [11]	valid_0's l2: 0.798276
# [12]	valid_0's l2: 0.782887
# [13]	valid_0's l2: 0.769026
# [14]	valid_0's l2: 0.756015
# [15]	valid_0's l2: 0.742102
# [16]	valid_0's l2: 0.729551
# [17]	valid_0's l2: 0.717819
# [18]	valid_0's l2: 0.706467
# [19]	valid_0's l2: 0.694592
# [20]	valid_0's l2: 0.683693
# [21]	valid_0's l2: 0.673835
# [22]	valid_0's l2: 0.663163
# [23]	valid_0's l2: 0.653316
# [24]	valid_0's l2: 0.644446
# [25]	valid_0's l2: 0.635864
# [26]	valid_0's l2: 0.625921
# [27]	valid_0's l2: 0.617944
# [28]	valid_0's l2: 0.610461
# [29]	valid_0's l2: 0.601433
# [30]	valid_0's l2: 0.594768
# [31]	valid_0's l2: 0.587802
# [32]	valid_0's l2: 0.580503
# [33]	valid_0's l2: 0.573614
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\leo_a\anaconda3\envs\ey-challenge\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [34]	valid_0's l2: 0.567344
# [35]	valid_0's l2: 0.56073
# [36]	valid_0's l2: 0.554398
# [37]	valid_0's l2: 0.54821
# [38]	valid_0's l2: 0.542097
# [39]	valid_0's l2: 0.536697
# [40]	valid_0's l2: 0.530989
# [41]	valid_0's l2: 0.525616
# [42]	valid_0's l2: 0.520248
# [43]	valid_0's l2: 0.515552
# [44]	valid_0's l2: 0.510893
# [45]	valid_0's l2: 0.506194
# [46]	valid_0's l2: 0.501431
# [47]	valid_0's l2: 0.497218
# [48]	valid_0's l2: 0.492921
# [49]	valid_0's l2: 0.489134
# [50]	valid_0's l2: 0.485357
# [51]	valid_0's l2: 0.482199
# [52]	valid_0's l2: 0.479168
# [53]	valid_0's l2: 0.476095
# [54]	valid_0's l2: 0.4726
# [55]	valid_0's l2: 0.469746
# [56]	valid_0's l2: 0.466851
# [57]	valid_0's l2: 0.46393
# [58]	valid_0's l2: 0.461262
# [59]	valid_0's l2: 0.45899
# [60]	valid_0's l2: 0.456244
# [61]	valid_0's l2: 0.453418
# [62]	valid_0's l2: 0.451994
# [63]	valid_0's l2: 0.450073
# [64]	valid_0's l2: 0.448452
# [65]	valid_0's l2: 0.446503
# [66]	valid_0's l2: 0.445174
# [67]	valid_0's l2: 0.443234
# [68]	valid_0's l2: 0.441765
# [69]	valid_0's l2: 0.440137
# [70]	valid_0's l2: 0.438769
# [71]	valid_0's l2: 0.43709
# [72]	valid_0's l2: 0.435789
# [73]	valid_0's l2: 0.434728
# [74]	valid_0's l2: 0.433555
# [75]	valid_0's l2: 0.432044
# [76]	valid_0's l2: 0.430784
# [77]	valid_0's l2: 0.42924
# [78]	valid_0's l2: 0.428097
# [79]	valid_0's l2: 0.426855
# [80]	valid_0's l2: 0.425399
# [81]	valid_0's l2: 0.424478
# [82]	valid_0's l2: 0.423939
# [83]	valid_0's l2: 0.42308
# [84]	valid_0's l2: 0.422597
# [85]	valid_0's l2: 0.421804
# [86]	valid_0's l2: 0.420955
# [87]	valid_0's l2: 0.420498
# [88]	valid_0's l2: 0.419878
# [89]	valid_0's l2: 0.419165
# [90]	valid_0's l2: 0.418335
# [91]	valid_0's l2: 0.41807
# [92]	valid_0's l2: 0.417202
# [93]	valid_0's l2: 0.41673
# [94]	valid_0's l2: 0.415904
# [95]	valid_0's l2: 0.4158
# [96]	valid_0's l2: 0.414977
# [97]	valid_0's l2: 0.414459
# [98]	valid_0's l2: 0.414169
# [99]	valid_0's l2: 0.413458
# [100]	valid_0's l2: 0.412521
# [101]	valid_0's l2: 0.412225
# [102]	valid_0's l2: 0.411508
# [103]	valid_0's l2: 0.411314
# [104]	valid_0's l2: 0.410879
# [105]	valid_0's l2: 0.410874
# [106]	valid_0's l2: 0.41007
# [107]	valid_0's l2: 0.409722
# [108]	valid_0's l2: 0.40956
# [109]	valid_0's l2: 0.409373
# [110]	valid_0's l2: 0.409436
# [111]	valid_0's l2: 0.408587
# [112]	valid_0's l2: 0.408209
# [113]	valid_0's l2: 0.408213
# [114]	valid_0's l2: 0.407279
# [115]	valid_0's l2: 0.407711
# [116]	valid_0's l2: 0.406822
# [117]	valid_0's l2: 0.407023
# [118]	valid_0's l2: 0.406995
# [119]	valid_0's l2: 0.406392
# [120]	valid_0's l2: 0.405367
# [121]	valid_0's l2: 0.405498
# [122]	valid_0's l2: 0.406015
# [123]	valid_0's l2: 0.405635
# [124]	valid_0's l2: 0.405709
# [125]	valid_0's l2: 0.40608
# [126]	valid_0's l2: 0.406224
# [127]	valid_0's l2: 0.406325
# [128]	valid_0's l2: 0.405715
# [129]	valid_0's l2: 0.405088
# [130]	valid_0's l2: 0.40542
# [131]	valid_0's l2: 0.404831
# [132]	valid_0's l2: 0.405333
# [133]	valid_0's l2: 0.405042
# [134]	valid_0's l2: 0.404991
# [135]	valid_0's l2: 0.404605
# [136]	valid_0's l2: 0.405029
# [137]	valid_0's l2: 0.405013
# [138]	valid_0's l2: 0.404505
# [139]	valid_0's l2: 0.404357
# [140]	valid_0's l2: 0.404012
# [141]	valid_0's l2: 0.404555
# [142]	valid_0's l2: 0.404063
# [143]	valid_0's l2: 0.403598
# [144]	valid_0's l2: 0.403135
# [145]	valid_0's l2: 0.402914
# [146]	valid_0's l2: 0.402373
# [147]	valid_0's l2: 0.402424
# [148]	valid_0's l2: 0.402008
# [149]	valid_0's l2: 0.402483
# [150]	valid_0's l2: 0.402067
# [151]	valid_0's l2: 0.401692
# [152]	valid_0's l2: 0.401755
# [153]	valid_0's l2: 0.401496
# [154]	valid_0's l2: 0.401597
# [155]	valid_0's l2: 0.401129
# [156]	valid_0's l2: 0.401213
# [157]	valid_0's l2: 0.401201
# [158]	valid_0's l2: 0.401176
# [159]	valid_0's l2: 0.401258
# [160]	valid_0's l2: 0.401336
# [161]	valid_0's l2: 0.401059
# [162]	valid_0's l2: 0.400857
# [163]	valid_0's l2: 0.40079
# [164]	valid_0's l2: 0.401245
# [165]	valid_0's l2: 0.401333
# [166]	valid_0's l2: 0.401682
# [167]	valid_0's l2: 0.401512
# [168]	valid_0's l2: 0.401315
# [169]	valid_0's l2: 0.401359
# [170]	valid_0's l2: 0.400942
# [171]	valid_0's l2: 0.400726
# [172]	valid_0's l2: 0.400918
# [173]	valid_0's l2: 0.401314
# [174]	valid_0's l2: 0.400931
# [175]	valid_0's l2: 0.400892
# [176]	valid_0's l2: 0.400496
# [177]	valid_0's l2: 0.400636
# [178]	valid_0's l2: 0.40027
# [179]	valid_0's l2: 0.399955
# [180]	valid_0's l2: 0.399592
# [181]	valid_0's l2: 0.39969
# [182]	valid_0's l2: 0.399365
# [183]	valid_0's l2: 0.398887
# [184]	valid_0's l2: 0.398441
# [185]	valid_0's l2: 0.398183
# [186]	valid_0's l2: 0.397725
# [187]	valid_0's l2: 0.397424
# [188]	valid_0's l2: 0.396981
# [189]	valid_0's l2: 0.396704
# [190]	valid_0's l2: 0.396278
# [191]	valid_0's l2: 0.395883
# [192]	valid_0's l2: 0.395476
# [193]	valid_0's l2: 0.395529
# [194]	valid_0's l2: 0.395102
# [195]	valid_0's l2: 0.395084
# [196]	valid_0's l2: 0.395139
# [197]	valid_0's l2: 0.394591
# [198]	valid_0's l2: 0.3946
# [199]	valid_0's l2: 0.394584
# [200]	valid_0's l2: 0.394609
# [201]	valid_0's l2: 0.394797
# [202]	valid_0's l2: 0.394783
# [203]	valid_0's l2: 0.394684
# [204]	valid_0's l2: 0.394226
# [205]	valid_0's l2: 0.394223
# [206]	valid_0's l2: 0.394245
# [207]	valid_0's l2: 0.394126
# [208]	valid_0's l2: 0.39369
# [209]	valid_0's l2: 0.393565
# [210]	valid_0's l2: 0.393135
# [211]	valid_0's l2: 0.392752
# [212]	valid_0's l2: 0.392661
# [213]	valid_0's l2: 0.392289
# [214]	valid_0's l2: 0.391946
# [215]	valid_0's l2: 0.391866
# [216]	valid_0's l2: 0.391465
# [217]	valid_0's l2: 0.39135
# [218]	valid_0's l2: 0.391182
# [219]	valid_0's l2: 0.391128
# [220]	valid_0's l2: 0.391049
# [221]	valid_0's l2: 0.390813
# [222]	valid_0's l2: 0.390595
# [223]	valid_0's l2: 0.390372
# [224]	valid_0's l2: 0.390377
# [225]	valid_0's l2: 0.390268
# [226]	valid_0's l2: 0.390167
# [227]	valid_0's l2: 0.389839
# [228]	valid_0's l2: 0.389499
# [229]	valid_0's l2: 0.389294
# [230]	valid_0's l2: 0.389145
# [231]	valid_0's l2: 0.389116
# [232]	valid_0's l2: 0.389034
# [233]	valid_0's l2: 0.388803
# [234]	valid_0's l2: 0.388701
# [235]	valid_0's l2: 0.388513
# [236]	valid_0's l2: 0.388448
# [237]	valid_0's l2: 0.388413
# [238]	valid_0's l2: 0.388453
# [239]	valid_0's l2: 0.388362
# [240]	valid_0's l2: 0.388232
# [241]	valid_0's l2: 0.38813
# [242]	valid_0's l2: 0.387961
# [243]	valid_0's l2: 0.387899
# [244]	valid_0's l2: 0.38782
# [245]	valid_0's l2: 0.387654
# [246]	valid_0's l2: 0.387564
# [247]	valid_0's l2: 0.387822
# [248]	valid_0's l2: 0.387777
# [249]	valid_0's l2: 0.387897
# [250]	valid_0's l2: 0.387594
# [251]	valid_0's l2: 0.387526
# [252]	valid_0's l2: 0.387552
# [253]	valid_0's l2: 0.387807
# [254]	valid_0's l2: 0.387449
# [255]	valid_0's l2: 0.387515
# [256]	valid_0's l2: 0.387691
# [257]	valid_0's l2: 0.387435
# [258]	valid_0's l2: 0.387519
# [259]	valid_0's l2: 0.387369
# [260]	valid_0's l2: 0.387442
# [261]	valid_0's l2: 0.387356
# [262]	valid_0's l2: 0.387599
# [263]	valid_0's l2: 0.387686
# [264]	valid_0's l2: 0.387766
# [265]	valid_0's l2: 0.387435
# [266]	valid_0's l2: 0.387527
# [267]	valid_0's l2: 0.38738
# [268]	valid_0's l2: 0.387561
# [269]	valid_0's l2: 0.387643
# [270]	valid_0's l2: 0.387679
# [271]	valid_0's l2: 0.387738

# %%
plot = True
EvaluationPlot(models_cat, xtest_enhanced, ytest, 'CatBoost vs test set', is_sklearn=True, plot=plot)
EvaluationPlot(models_cat, xsub_enhanced, ytrue, 'CatBoost model vs 0.62 sub', is_sklearn=True, plot=plot)

EvaluationPlot(models_xgb, xtest_enhanced , ytest, 'XGB model vs test set', is_sklearn=True, plot=plot)
EvaluationPlot(models_xgb, xsub_enhanced , ytrue, 'XGB model vs 0.62 sub', is_sklearn=True, plot=plot)

EvaluationPlot(models_lgbm, xtest_enhanced , ytest, 'LGBM model vs test set', is_sklearn=True, plot=plot)
EvaluationPlot(models_lgbm, xsub_enhanced , ytrue, 'LGBM model vs 0.62 sub', is_sklearn=True, plot=plot)

EvaluationPlot([*models_xgb, *models_cat, *models_lgbm], xtest_enhanced , ytest, 'Mixed model vs test set', is_sklearn=True, plot=plot)
EvaluationPlot([*models_xgb, *models_cat, *models_lgbm], xsub_enhanced , ytrue, 'Mixed model vs 0.62 sub', is_sklearn=True, plot=plot)
# Out:
# CatBoost vs test set
#           0         1     error       mae       mse       r2
# 0 -0.842705 -0.289563  0.553142  0.472789  0.587428  0.65007
# CatBoost model vs 0.62 sub
#           0         1     error       mae       mse        r2
# 0  0.782737  0.665169 -0.117568  0.101665  0.128003  0.964342
# XGB model vs test set
#           0         1     error       mae       mse        r2
# 0 -0.965349 -0.289563  0.675786  0.515221  0.628635  0.599253
# XGB model vs 0.62 sub
#           0         1     error       mae       mse        r2
# 0  0.732561  0.665169 -0.067392  0.156099  0.195848  0.916525
# LGBM model vs test set
#           0         1     error       mae       mse        r2
# 0 -1.080424 -0.289563  0.790861  0.511322  0.623603  0.605644
# LGBM model vs 0.62 sub
#          0         1    error      mae       mse        r2
# 0  0.63548  0.665169  0.02969  0.16239  0.192154  0.919644
# Mixed model vs test set
#           0         1     error       mae       mse        r2
# 0 -0.932796 -0.289563  0.643233  0.486013  0.598575  0.636663
# Mixed model vs 0.62 sub
#           0         1     error       mae       mse       r2
# 0  0.733379  0.665169 -0.068209  0.111853  0.137741  0.95871

# %% [markdown]
# ### NN Models

# %%
EvaluationPlot(models, xtest, ytest, 'KFold ConvNet vs Test Set')
EvaluationPlot(model, xtest, ytest, '1 ConvNet vs Test Set')
EvaluationPlot(models_tr, xtest, ytest, 'KFold Transformers vs Test Set')
EvaluationPlot(model_tr, xtest, ytest, '1 Transformer vs Test Set')
EvaluationPlot(np.append(model, model_tr), xtest, ytest, 'Mix vs test submission')

EvaluationPlot(models, xsub , ytrue, 'KFold ConvNet vs 0.62 submission')

EvaluationPlot(model, xsub , ytrue, '1 ConvNet vs 0.62 submission')

EvaluationPlot(models_tr, xsub , ytrue, 'KFold Transformers vs 0.62 submission')

EvaluationPlot(model_tr, xsub , ytrue, '1 Transformer vs 0.62 submission')

EvaluationPlot(np.append(model, model_tr), xsub , ytrue, 'Mix vs 0.62 submission')
# Out:
# KFold ConvNet vs Test Set
#           0         1   error       mae       mse        r2
# 0 -1.093364 -0.289563  0.8038  0.482271  0.596391  0.639309
# 1 ConvNet vs Test Set
#           0         1     error       mae       mse        r2
# 0 -1.019938 -0.289563  0.730375  0.472299  0.579839  0.659052
# KFold Transformers vs Test Set
#           0         1     error       mae       mse        r2
# 0 -1.015725 -0.289563  0.726162  0.463607  0.573367  0.666621
# 1 Transformer vs Test Set
#           0         1     error     mae       mse        r2
# 0 -0.967319 -0.289563  0.677756  0.4627  0.570608  0.669822
# Mix vs test submission
#           0         1     error       mae       mse        r2
# 0 -0.993629 -0.289563  0.704066  0.467453  0.574686  0.665085
# KFold ConvNet vs 0.62 submission
#           0         1    error       mae       mse        r2
# 0  0.988239  0.665169 -0.32307  0.231771  0.266127  0.845867
# 1 ConvNet vs 0.62 submission
#          0         1     error       mae       mse        r2
# 0  0.88182  0.665169 -0.216651  0.201633  0.228725  0.886147
# KFold Transformers vs 0.62 submission
#          0         1     error       mae       mse        r2
# 0  0.81011  0.665169 -0.144941  0.175949  0.209072  0.904872
# 1 Transformer vs 0.62 submission
#           0         1     error       mae       mse        r2
# 0  0.817615  0.665169 -0.152445  0.168979  0.200127  0.912837
# Mix vs 0.62 submission
#           0         1     error       mae       mse       r2
# 0  0.849717  0.665169 -0.184548  0.184429  0.212691  0.90155

# %%
EvaluationPlot([*model, *models_cat], xtest, ytest, 'Mix vs test submission')
EvaluationPlot([*model, *models_cat], xsub , ytrue, 'Mix vs 0.62 submission')
# Out:
# Mix vs test submission
#           0         1     error      mae       mse        r2
# 0 -0.931322 -0.289563  0.641759  0.46208  0.575924  0.663641
# Mix vs 0.62 submission
#           0         1     error       mae       mse        r2
# 0  0.832278  0.665169 -0.167109  0.131537  0.155707  0.947237

# %%
from sklearn.base import BaseEstimator, RegressorMixin

class ListOfRegressors(BaseEstimator, RegressorMixin):
    def __init__(self, estimators):
        self.estimators = estimators
        self.fitted=True

    def fit(self, X, y=None):
        pass

    def is_fitted(self):
        return True


    def predict(self, X):
        predictions = []
        for model in self.estimators:
            predictions.append(model.predict(X))
        return np.mean(predictions, axis=0)
    
models_cat_estimator = ListOfRegressors(models_cat)
models_xgb_estimator = ListOfRegressors(models_xgb)
models_lgbm_estimator = ListOfRegressors(models_lgbm)

# %%
from sklearn.ensemble import StackingRegressor, VotingRegressor
# from sklearn.model_selection import 

# sk_models_cat_vote = VotingRegressor(estimators=[('cat0', sk_model_cat)]).fit(xfulltrain_enhanced, yfulltrain)

# sk_models_xgb_vote = VotingRegressor(estimators=[('xgb0', sk_models_xgb[0]), ('xgb1', sk_models_xgb[1]), ('xgb2', sk_models_xgb[2]), ('xgb3', sk_models_xgb[3]),
#                                                   ('xgb4', sk_models_xgb[4])]).fit(xfulltrain_enhanced, yfulltrain)

# sk_models_lgbm_vote = VotingRegressor(estimators=[('lgbm0', sk_models_lgbm[0]), ('lgbm1', sk_models_lgbm[1]), ('lgbm2', sk_models_lgbm[2]), ('lgbm3', sk_models_lgbm[3]),
#                                                    ('lgbm4', sk_models_lgbm[4])]).fit(xfulltrain_enhanced, yfulltrain)


stack = StackingRegressor(estimators=[('cat', model_gbm), ('xgb', models_xgb[0]), ('lgbm', models_lgbm[0])],
                           final_estimator=models_cat[0], passthrough=True, verbose=1, n_jobs=-1)

# %%
stack.fit(x_enhanced, scaler_y_sub.transform(y))
# Out:
# 0:	learn: 0.0240353	total: 33.2ms	remaining: 16.6s
# 499:	learn: 0.8264042	total: 17.5s	remaining: 0us
# StackingRegressor(estimators=[('cat',
#                                GradientBoostingRegressor(learning_rate=0.0199526231496888,
#                                                          n_estimators=200)),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             gpu_i...
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=500, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...)),
#                               ('lgbm',
#                                LGBMRegressor(learning_rate=0.0199526231496888,
#                                              n_estimators=500,
#                                              reg_lambda=25.118864315095795))],
#                   final_estimator=<catboost.core.CatBoostRegressor object at 0x000001DEDDA76A40>,
#                   n_jobs=-1, passthrough=True, verbose=1)

# %%
stack.score(xsub_enhanced, ytrue)
# Out:
# 0.919190711331077

# %%
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, r2_score as r2
r2(ytest, stack.predict(xtest_enhanced))
r2(ytrue, stack.predict(xsub_enhanced))
# Out:
# 0.906386916081391

# %%
# Distribution of target variables
pd.Series(yfulltrain.squeeze()).hist(density=True, bins=30, label='ytrain', alpha=0.5)
pd.Series(ytest.squeeze()).hist(density=True, bins=30, label='ytest', alpha=0.5)
pd.Series(ytrue).hist(density=True, bins=30, label='ytrue', alpha=0.5)
plt.legend()

# %% [markdown]
# ## Retrain with full data

# %%
# Train KFolds with validation data
models = KFoldTraining(x, y, model='convnet')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 35 "Best" training loss: 0.3498 best val_R2: 0.6209
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 14 "Best" training loss: 0.4382 best val_R2: 0.6421
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 12 "Best" training loss: 0.4383 best val_R2: 0.634
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 5 "Best" training loss: 0.515 best val_R2: 0.6353
#   0%|          | 0/200 [00:00<?, ?it/s]
# 20 time(s) has the R2 score not improved. Finishing training...ter: 19
#  best epoch: 11 "Best" training loss: 0.4544 best val_R2: 0.6574

# %%
# Average validation loss
r2_scores = np.array(models)[:, 1]
models = np.array(models)[:, 0]

print('Average R2 on k-fold:' , r2_scores.mean())
# Out:
# Average R2 on k-fold: 0.6379372656987042

# %%
# Train once on all data
model_full = []
for i in np.linspace(30, 50, 5, dtype=int):
    model_full.append(FullDataTraining(x, y, n_epochs=i, model='transformer'))
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Training loss: 0.4925 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/35 [00:00<?, ?it/s]
# Training loss: 0.4937 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/40 [00:00<?, ?it/s]
# Training loss: 0.4750 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/45 [00:00<?, ?it/s]
# Training loss: 0.4633 Validation R2 score: 0.0000 Stopping counter: 00
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training loss: 0.4827 Validation R2 score: 0.0000 Stopping counter: 00

# %%
EvaluationPlot(models, xsub, ytrue)
EvaluationPlot(model_full, xsub, ytrue)
EvaluationPlot([*models, *model_full], xsub, ytrue, is_sklearn=False)
# Out:
#           0         1     error       mae       mse        r2
# 0  0.703483  0.694731 -0.008752  0.242715  0.297145  0.807594
#           0         1     error       mae       mse        r2
# 0  0.754357  0.694731 -0.059626  0.224748  0.285576  0.822284
#          0         1     error       mae       mse        r2
# 0  0.72892  0.694731 -0.034189  0.202187  0.258756  0.854097

# %%
# Enhancear con el modelo recién entrenado full
x_enhanced = GetEncodings(x_scaled, [models, model_full], to_return='original')
xsub_enhanced = GetEncodings(xsub, [models, model_full], to_return='original')

# %%
# sk_model_cat.fit(x_enhanced, scaler_y_sub.transform(y))
# sk_model_xgb.fit(x_enhanced, scaler_y_sub.transform(y))
sk_models_cat = KFoldTraining(x_enhanced, scaler_y_sub.transform(y), 5, True, sk_model_cat)
sk_models_xgb = KFoldTraining(x_enhanced, scaler_y_sub.transform(y), 5, True, sk_model_xgb)
EvaluationPlot(sk_models_cat, xsub_enhanced, ytrue, is_sklearn=True, plot=True)
EvaluationPlot(sk_models_xgb, xsub_enhanced, ytrue, is_sklearn=True, plot=True)
EvaluationPlot([*sk_models_cat, *sk_models_xgb], xsub_enhanced, ytrue, is_sklearn=True, plot=True)
# Out:
# Default metric period is 5 because R2 is/are not implemented for GPU
# Metric R2 is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	learn: 0.0216334	test: 0.0140280	best: 0.0140280 (0)	total: 50.2ms	remaining: 50.1s
# 100:	learn: 0.6479669	test: 0.5171884	best: 0.5171884 (100)	total: 2.7s	remaining: 24.1s
# 200:	learn: 0.7174642	test: 0.5590513	best: 0.5590513 (200)	total: 5.26s	remaining: 20.9s
# 300:	learn: 0.7484298	test: 0.5671231	best: 0.5672224 (294)	total: 7.86s	remaining: 18.3s
# bestTest = 0.569539014
# bestIteration = 330
# Shrink model to first 331 iterations.
# Default metric period is 5 because R2 is/are not implemented for GPU
# Metric R2 is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	learn: 0.0195932	test: 0.0156070	best: 0.0156070 (0)	total: 30.4ms	remaining: 30.4s
# 100:	learn: 0.6412831	test: 0.5772065	best: 0.5772065 (100)	total: 2.56s	remaining: 22.8s
# 200:	learn: 0.7108829	test: 0.6328804	best: 0.6328804 (200)	total: 5.11s	remaining: 20.3s
# 300:	learn: 0.7431816	test: 0.6431462	best: 0.6434331 (297)	total: 7.69s	remaining: 17.9s
# 400:	learn: 0.7728517	test: 0.6478675	best: 0.6481767 (392)	total: 10.3s	remaining: 15.3s
# bestTest = 0.6481767107
# bestIteration = 392
# Shrink model to first 393 iterations.
# Default metric period is 5 because R2 is/are not implemented for GPU
# Metric R2 is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	learn: 0.0197267	test: 0.0115372	best: 0.0115372 (0)	total: 25.9ms	remaining: 25.9s
# 100:	learn: 0.6342879	test: 0.6141792	best: 0.6141792 (100)	total: 2.59s	remaining: 23.1s
# 200:	learn: 0.7104891	test: 0.6556043	best: 0.6556043 (200)	total: 5.14s	remaining: 20.4s
# bestTest = 0.6579784589
# bestIteration = 240
# Shrink model to first 241 iterations.
# Default metric period is 5 because R2 is/are not implemented for GPU
# Metric R2 is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	learn: 0.0206702	test: 0.0210520	best: 0.0210520 (0)	total: 25.7ms	remaining: 25.6s
# 100:	learn: 0.6335669	test: 0.6311309	best: 0.6311309 (100)	total: 2.53s	remaining: 22.5s
# bestTest = 0.6588448259
# bestIteration = 173
# Shrink model to first 174 iterations.
# Default metric period is 5 because R2 is/are not implemented for GPU
# Metric R2 is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	learn: 0.0199007	test: 0.0214049	best: 0.0214049 (0)	total: 26.2ms	remaining: 26.2s
# 100:	learn: 0.6333149	test: 0.6048009	best: 0.6048009 (100)	total: 2.51s	remaining: 22.4s
# 200:	learn: 0.7084686	test: 0.6394231	best: 0.6395906 (198)	total: 5.06s	remaining: 20.1s
# bestTest = 0.6410655995
# bestIteration = 227
# Shrink model to first 228 iterations.
# [18:25:25] WARNING: ../src/learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [0]	validation_0-rmse:1.12081
# [1]	validation_0-rmse:1.10983
# [2]	validation_0-rmse:1.09927
# [3]	validation_0-rmse:1.08887
# [4]	validation_0-rmse:1.07776
# [5]	validation_0-rmse:1.06680
# [6]	validation_0-rmse:1.05627
# [7]	validation_0-rmse:1.04593
# [8]	validation_0-rmse:1.03701
# [9]	validation_0-rmse:1.02822
# [10]	validation_0-rmse:1.01889
# [11]	validation_0-rmse:1.00952
# [12]	validation_0-rmse:1.00059
# [13]	validation_0-rmse:0.99229
# [14]	validation_0-rmse:0.98380
# [15]	validation_0-rmse:0.97578
# [16]	validation_0-rmse:0.96754
# [17]	validation_0-rmse:0.95928
# [18]	validation_0-rmse:0.95129
# [19]	validation_0-rmse:0.94354
# [20]	validation_0-rmse:0.93661
# [21]	validation_0-rmse:0.92942
# [22]	validation_0-rmse:0.92203
# [23]	validation_0-rmse:0.91583
# [24]	validation_0-rmse:0.90884
# [25]	validation_0-rmse:0.90211
# [26]	validation_0-rmse:0.89687
# [27]	validation_0-rmse:0.89219
# [28]	validation_0-rmse:0.88572
# [29]	validation_0-rmse:0.88114
# [30]	validation_0-rmse:0.87551
# [31]	validation_0-rmse:0.87119
# [32]	validation_0-rmse:0.86634
# [33]	validation_0-rmse:0.86188
# [34]	validation_0-rmse:0.85708
# [35]	validation_0-rmse:0.85233
# [36]	validation_0-rmse:0.84826
# [37]	validation_0-rmse:0.84389
# [38]	validation_0-rmse:0.84022
# [39]	validation_0-rmse:0.83618
# [40]	validation_0-rmse:0.83301
# [41]	validation_0-rmse:0.82952
# [42]	validation_0-rmse:0.82644
# [43]	validation_0-rmse:0.82325
# [44]	validation_0-rmse:0.82021
# [45]	validation_0-rmse:0.81685
# [46]	validation_0-rmse:0.81398
# [47]	validation_0-rmse:0.81045
# [48]	validation_0-rmse:0.80787
# [49]	validation_0-rmse:0.80506
# [50]	validation_0-rmse:0.80224
# [51]	validation_0-rmse:0.80004
# [52]	validation_0-rmse:0.79729
# [53]	validation_0-rmse:0.79506
# [54]	validation_0-rmse:0.79263
# [55]	validation_0-rmse:0.79021
# [56]	validation_0-rmse:0.78781
# [57]	validation_0-rmse:0.78527
# [58]	validation_0-rmse:0.78319
# [59]	validation_0-rmse:0.78054
# [60]	validation_0-rmse:0.77834
# [61]	validation_0-rmse:0.77654
# [62]	validation_0-rmse:0.77411
# [63]	validation_0-rmse:0.77234
# [64]	validation_0-rmse:0.77058
# [65]	validation_0-rmse:0.76862
# [66]	validation_0-rmse:0.76685
# [67]	validation_0-rmse:0.76483
# [68]	validation_0-rmse:0.76345
# [69]	validation_0-rmse:0.76188
# [70]	validation_0-rmse:0.76046
# [71]	validation_0-rmse:0.75875
# [72]	validation_0-rmse:0.75759
# [73]	validation_0-rmse:0.75601
# [74]	validation_0-rmse:0.75400
# [75]	validation_0-rmse:0.75250
# [76]	validation_0-rmse:0.75147
# [77]	validation_0-rmse:0.75007
# [78]	validation_0-rmse:0.74830
# [79]	validation_0-rmse:0.74742
# [80]	validation_0-rmse:0.74600
# [81]	validation_0-rmse:0.74469
# [82]	validation_0-rmse:0.74419
# [83]	validation_0-rmse:0.74314
# [84]	validation_0-rmse:0.74239
# [85]	validation_0-rmse:0.74129
# [86]	validation_0-rmse:0.74047
# [87]	validation_0-rmse:0.73985
# [88]	validation_0-rmse:0.73905
# [89]	validation_0-rmse:0.73836
# [90]	validation_0-rmse:0.73781
# [91]	validation_0-rmse:0.73699
# [92]	validation_0-rmse:0.73593
# [93]	validation_0-rmse:0.73533
# [94]	validation_0-rmse:0.73415
# [95]	validation_0-rmse:0.73331
# [96]	validation_0-rmse:0.73264
# [97]	validation_0-rmse:0.73152
# [98]	validation_0-rmse:0.73095
# [99]	validation_0-rmse:0.73014
# [100]	validation_0-rmse:0.72987
# [101]	validation_0-rmse:0.72870
# [102]	validation_0-rmse:0.72802
# [103]	validation_0-rmse:0.72731
# [104]	validation_0-rmse:0.72717
# [105]	validation_0-rmse:0.72671
# [106]	validation_0-rmse:0.72625
# [107]	validation_0-rmse:0.72613
# [108]	validation_0-rmse:0.72528
# [109]	validation_0-rmse:0.72472
# [110]	validation_0-rmse:0.72452
# [111]	validation_0-rmse:0.72373
# [112]	validation_0-rmse:0.72270
# [113]	validation_0-rmse:0.72223
# [114]	validation_0-rmse:0.72181
# [115]	validation_0-rmse:0.72157
# [116]	validation_0-rmse:0.72071
# [117]	validation_0-rmse:0.72005
# [118]	validation_0-rmse:0.71957
# [119]	validation_0-rmse:0.71888
# [120]	validation_0-rmse:0.71871
# [121]	validation_0-rmse:0.71816
# [122]	validation_0-rmse:0.71799
# [123]	validation_0-rmse:0.71786
# [124]	validation_0-rmse:0.71738
# [125]	validation_0-rmse:0.71690
# [126]	validation_0-rmse:0.71684
# [127]	validation_0-rmse:0.71651
# [128]	validation_0-rmse:0.71611
# [129]	validation_0-rmse:0.71603
# [130]	validation_0-rmse:0.71567
# [131]	validation_0-rmse:0.71521
# [132]	validation_0-rmse:0.71483
# [133]	validation_0-rmse:0.71436
# [134]	validation_0-rmse:0.71399
# [135]	validation_0-rmse:0.71350
# [136]	validation_0-rmse:0.71329
# [137]	validation_0-rmse:0.71296
# [138]	validation_0-rmse:0.71310
# [139]	validation_0-rmse:0.71260
# [140]	validation_0-rmse:0.71232
# [141]	validation_0-rmse:0.71196
# [142]	validation_0-rmse:0.71149
# [143]	validation_0-rmse:0.71124
# [144]	validation_0-rmse:0.71089
# [145]	validation_0-rmse:0.71043
# [146]	validation_0-rmse:0.71035
# [147]	validation_0-rmse:0.71009
# [148]	validation_0-rmse:0.71008
# [149]	validation_0-rmse:0.70997
# [150]	validation_0-rmse:0.70970
# [151]	validation_0-rmse:0.70965
# [152]	validation_0-rmse:0.70946
# [153]	validation_0-rmse:0.70905
# [154]	validation_0-rmse:0.70870
# [155]	validation_0-rmse:0.70831
# [156]	validation_0-rmse:0.70821
# [157]	validation_0-rmse:0.70814
# [158]	validation_0-rmse:0.70777
# [159]	validation_0-rmse:0.70799
# [160]	validation_0-rmse:0.70765
# [161]	validation_0-rmse:0.70760
# [162]	validation_0-rmse:0.70734
# [163]	validation_0-rmse:0.70712
# [164]	validation_0-rmse:0.70698
# [165]	validation_0-rmse:0.70653
# [166]	validation_0-rmse:0.70696
# [167]	validation_0-rmse:0.70691
# [168]	validation_0-rmse:0.70670
# [169]	validation_0-rmse:0.70647
# [170]	validation_0-rmse:0.70614
# [171]	validation_0-rmse:0.70586
# [172]	validation_0-rmse:0.70574
# [173]	validation_0-rmse:0.70529
# [174]	validation_0-rmse:0.70532
# [175]	validation_0-rmse:0.70520
# [176]	validation_0-rmse:0.70501
# [177]	validation_0-rmse:0.70516
# [178]	validation_0-rmse:0.70492
# [179]	validation_0-rmse:0.70476
# [180]	validation_0-rmse:0.70485
# [181]	validation_0-rmse:0.70476
# [182]	validation_0-rmse:0.70454
# [183]	validation_0-rmse:0.70447
# [184]	validation_0-rmse:0.70403
# [185]	validation_0-rmse:0.70424
# [186]	validation_0-rmse:0.70444
# [187]	validation_0-rmse:0.70434
# [188]	validation_0-rmse:0.70431
# [189]	validation_0-rmse:0.70419
# [190]	validation_0-rmse:0.70410
# [191]	validation_0-rmse:0.70392
# [192]	validation_0-rmse:0.70414
# [193]	validation_0-rmse:0.70413
# [194]	validation_0-rmse:0.70404
# [195]	validation_0-rmse:0.70380
# [196]	validation_0-rmse:0.70381
# [197]	validation_0-rmse:0.70370
# [198]	validation_0-rmse:0.70369
# [199]	validation_0-rmse:0.70338
# [200]	validation_0-rmse:0.70327
# [201]	validation_0-rmse:0.70338
# [202]	validation_0-rmse:0.70325
# [203]	validation_0-rmse:0.70317
# [204]	validation_0-rmse:0.70320
# [205]	validation_0-rmse:0.70293
# [206]	validation_0-rmse:0.70293
# [207]	validation_0-rmse:0.70320
# [208]	validation_0-rmse:0.70294
# [209]	validation_0-rmse:0.70272
# [210]	validation_0-rmse:0.70254
# [211]	validation_0-rmse:0.70241
# [212]	validation_0-rmse:0.70245
# [213]	validation_0-rmse:0.70238
# [214]	validation_0-rmse:0.70241
# [215]	validation_0-rmse:0.70238
# [216]	validation_0-rmse:0.70240
# [217]	validation_0-rmse:0.70231
# [218]	validation_0-rmse:0.70218
# [219]	validation_0-rmse:0.70238
# [220]	validation_0-rmse:0.70256
# [221]	validation_0-rmse:0.70283
# [222]	validation_0-rmse:0.70281
# [223]	validation_0-rmse:0.70262
# [224]	validation_0-rmse:0.70251
# [225]	validation_0-rmse:0.70245
# [226]	validation_0-rmse:0.70249
# [227]	validation_0-rmse:0.70247
# [228]	validation_0-rmse:0.70257
# [18:25:27] WARNING: ../src/learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [0]	validation_0-rmse:1.14176
# [1]	validation_0-rmse:1.12769
# [2]	validation_0-rmse:1.11474
# [3]	validation_0-rmse:1.10171
# [4]	validation_0-rmse:1.08936
# [5]	validation_0-rmse:1.07709
# [6]	validation_0-rmse:1.06548
# [7]	validation_0-rmse:1.05362
# [8]	validation_0-rmse:1.04308
# [9]	validation_0-rmse:1.03200
# [10]	validation_0-rmse:1.02199
# [11]	validation_0-rmse:1.01284
# [12]	validation_0-rmse:1.00329
# [13]	validation_0-rmse:0.99386
# [14]	validation_0-rmse:0.98338
# [15]	validation_0-rmse:0.97428
# [16]	validation_0-rmse:0.96489
# [17]	validation_0-rmse:0.95593
# [18]	validation_0-rmse:0.94725
# [19]	validation_0-rmse:0.93842
# [20]	validation_0-rmse:0.93005
# [21]	validation_0-rmse:0.92223
# [22]	validation_0-rmse:0.91419
# [23]	validation_0-rmse:0.90657
# [24]	validation_0-rmse:0.89901
# [25]	validation_0-rmse:0.89170
# [26]	validation_0-rmse:0.88442
# [27]	validation_0-rmse:0.87783
# [28]	validation_0-rmse:0.87122
# [29]	validation_0-rmse:0.86457
# [30]	validation_0-rmse:0.85778
# [31]	validation_0-rmse:0.85099
# [32]	validation_0-rmse:0.84477
# [33]	validation_0-rmse:0.83933
# [34]	validation_0-rmse:0.83360
# [35]	validation_0-rmse:0.82782
# [36]	validation_0-rmse:0.82248
# [37]	validation_0-rmse:0.81742
# [38]	validation_0-rmse:0.81234
# [39]	validation_0-rmse:0.80717
# [40]	validation_0-rmse:0.80188
# [41]	validation_0-rmse:0.79715
# [42]	validation_0-rmse:0.79229
# [43]	validation_0-rmse:0.78754
# [44]	validation_0-rmse:0.78375
# [45]	validation_0-rmse:0.77929
# [46]	validation_0-rmse:0.77549
# [47]	validation_0-rmse:0.77096
# [48]	validation_0-rmse:0.76658
# [49]	validation_0-rmse:0.76316
# [50]	validation_0-rmse:0.75992
# [51]	validation_0-rmse:0.75604
# [52]	validation_0-rmse:0.75246
# [53]	validation_0-rmse:0.74892
# [54]	validation_0-rmse:0.74590
# [55]	validation_0-rmse:0.74268
# [56]	validation_0-rmse:0.73954
# [57]	validation_0-rmse:0.73658
# [58]	validation_0-rmse:0.73370
# [59]	validation_0-rmse:0.73146
# [60]	validation_0-rmse:0.72852
# [61]	validation_0-rmse:0.72642
# [62]	validation_0-rmse:0.72399
# [63]	validation_0-rmse:0.72167
# [64]	validation_0-rmse:0.71935
# [65]	validation_0-rmse:0.71754
# [66]	validation_0-rmse:0.71538
# [67]	validation_0-rmse:0.71382
# [68]	validation_0-rmse:0.71165
# [69]	validation_0-rmse:0.71003
# [70]	validation_0-rmse:0.70791
# [71]	validation_0-rmse:0.70613
# [72]	validation_0-rmse:0.70422
# [73]	validation_0-rmse:0.70236
# [74]	validation_0-rmse:0.70048
# [75]	validation_0-rmse:0.69918
# [76]	validation_0-rmse:0.69794
# [77]	validation_0-rmse:0.69614
# [78]	validation_0-rmse:0.69472
# [79]	validation_0-rmse:0.69338
# [80]	validation_0-rmse:0.69168
# [81]	validation_0-rmse:0.69061
# [82]	validation_0-rmse:0.68909
# [83]	validation_0-rmse:0.68774
# [84]	validation_0-rmse:0.68638
# [85]	validation_0-rmse:0.68558
# [86]	validation_0-rmse:0.68477
# [87]	validation_0-rmse:0.68373
# [88]	validation_0-rmse:0.68262
# [89]	validation_0-rmse:0.68166
# [90]	validation_0-rmse:0.68075
# [91]	validation_0-rmse:0.67961
# [92]	validation_0-rmse:0.67876
# [93]	validation_0-rmse:0.67770
# [94]	validation_0-rmse:0.67667
# [95]	validation_0-rmse:0.67578
# [96]	validation_0-rmse:0.67493
# [97]	validation_0-rmse:0.67411
# [98]	validation_0-rmse:0.67331
# [99]	validation_0-rmse:0.67285
# [100]	validation_0-rmse:0.67228
# [101]	validation_0-rmse:0.67161
# [102]	validation_0-rmse:0.67116
# [103]	validation_0-rmse:0.67074
# [104]	validation_0-rmse:0.67034
# [105]	validation_0-rmse:0.66981
# [106]	validation_0-rmse:0.66909
# [107]	validation_0-rmse:0.66873
# [108]	validation_0-rmse:0.66824
# [109]	validation_0-rmse:0.66788
# [110]	validation_0-rmse:0.66756
# [111]	validation_0-rmse:0.66717
# [112]	validation_0-rmse:0.66674
# [113]	validation_0-rmse:0.66645
# [114]	validation_0-rmse:0.66611
# [115]	validation_0-rmse:0.66579
# [116]	validation_0-rmse:0.66561
# [117]	validation_0-rmse:0.66549
# [118]	validation_0-rmse:0.66533
# [119]	validation_0-rmse:0.66496
# [120]	validation_0-rmse:0.66477
# [121]	validation_0-rmse:0.66459
# [122]	validation_0-rmse:0.66436
# [123]	validation_0-rmse:0.66446
# [124]	validation_0-rmse:0.66410
# [125]	validation_0-rmse:0.66395
# [126]	validation_0-rmse:0.66376
# [127]	validation_0-rmse:0.66354
# [128]	validation_0-rmse:0.66345
# [129]	validation_0-rmse:0.66341
# [130]	validation_0-rmse:0.66289
# [131]	validation_0-rmse:0.66264
# [132]	validation_0-rmse:0.66210
# [133]	validation_0-rmse:0.66196
# [134]	validation_0-rmse:0.66187
# [135]	validation_0-rmse:0.66147
# [136]	validation_0-rmse:0.66149
# [137]	validation_0-rmse:0.66127
# [138]	validation_0-rmse:0.66087
# [139]	validation_0-rmse:0.66060
# [140]	validation_0-rmse:0.66068
# [141]	validation_0-rmse:0.66070
# [142]	validation_0-rmse:0.66044
# [143]	validation_0-rmse:0.66025
# [144]	validation_0-rmse:0.66013
# [145]	validation_0-rmse:0.66011
# [146]	validation_0-rmse:0.66007
# [147]	validation_0-rmse:0.66003
# [148]	validation_0-rmse:0.65995
# [149]	validation_0-rmse:0.65999
# [150]	validation_0-rmse:0.65992
# [151]	validation_0-rmse:0.65990
# [152]	validation_0-rmse:0.65979
# [153]	validation_0-rmse:0.65967
# [154]	validation_0-rmse:0.65958
# [155]	validation_0-rmse:0.65945
# [156]	validation_0-rmse:0.65941
# [157]	validation_0-rmse:0.65941
# [158]	validation_0-rmse:0.65942
# [159]	validation_0-rmse:0.65929
# [160]	validation_0-rmse:0.65931
# [161]	validation_0-rmse:0.65943
# [162]	validation_0-rmse:0.65952
# [163]	validation_0-rmse:0.65971
# [164]	validation_0-rmse:0.65974
# [165]	validation_0-rmse:0.65981
# [166]	validation_0-rmse:0.65978
# [167]	validation_0-rmse:0.66000
# [168]	validation_0-rmse:0.66007
# [169]	validation_0-rmse:0.66009
# [18:25:28] WARNING: ../src/learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [0]	validation_0-rmse:1.13464
# [1]	validation_0-rmse:1.12127
# [2]	validation_0-rmse:1.10880
# [3]	validation_0-rmse:1.09605
# [4]	validation_0-rmse:1.08418
# [5]	validation_0-rmse:1.07168
# [6]	validation_0-rmse:1.05989
# [7]	validation_0-rmse:1.04852
# [8]	validation_0-rmse:1.03726
# [9]	validation_0-rmse:1.02592
# [10]	validation_0-rmse:1.01499
# [11]	validation_0-rmse:1.00394
# [12]	validation_0-rmse:0.99287
# [13]	validation_0-rmse:0.98255
# [14]	validation_0-rmse:0.97238
# [15]	validation_0-rmse:0.96254
# [16]	validation_0-rmse:0.95237
# [17]	validation_0-rmse:0.94297
# [18]	validation_0-rmse:0.93394
# [19]	validation_0-rmse:0.92435
# [20]	validation_0-rmse:0.91542
# [21]	validation_0-rmse:0.90636
# [22]	validation_0-rmse:0.89759
# [23]	validation_0-rmse:0.88917
# [24]	validation_0-rmse:0.88067
# [25]	validation_0-rmse:0.87283
# [26]	validation_0-rmse:0.86527
# [27]	validation_0-rmse:0.85766
# [28]	validation_0-rmse:0.85009
# [29]	validation_0-rmse:0.84267
# [30]	validation_0-rmse:0.83538
# [31]	validation_0-rmse:0.82860
# [32]	validation_0-rmse:0.82259
# [33]	validation_0-rmse:0.81640
# [34]	validation_0-rmse:0.80987
# [35]	validation_0-rmse:0.80389
# [36]	validation_0-rmse:0.79824
# [37]	validation_0-rmse:0.79262
# [38]	validation_0-rmse:0.78679
# [39]	validation_0-rmse:0.78145
# [40]	validation_0-rmse:0.77647
# [41]	validation_0-rmse:0.77166
# [42]	validation_0-rmse:0.76691
# [43]	validation_0-rmse:0.76183
# [44]	validation_0-rmse:0.75732
# [45]	validation_0-rmse:0.75255
# [46]	validation_0-rmse:0.74828
# [47]	validation_0-rmse:0.74399
# [48]	validation_0-rmse:0.73982
# [49]	validation_0-rmse:0.73537
# [50]	validation_0-rmse:0.73113
# [51]	validation_0-rmse:0.72719
# [52]	validation_0-rmse:0.72358
# [53]	validation_0-rmse:0.71986
# [54]	validation_0-rmse:0.71626
# [55]	validation_0-rmse:0.71273
# [56]	validation_0-rmse:0.70925
# [57]	validation_0-rmse:0.70611
# [58]	validation_0-rmse:0.70291
# [59]	validation_0-rmse:0.69929
# [60]	validation_0-rmse:0.69617
# [61]	validation_0-rmse:0.69305
# [62]	validation_0-rmse:0.68987
# [63]	validation_0-rmse:0.68705
# [64]	validation_0-rmse:0.68420
# [65]	validation_0-rmse:0.68171
# [66]	validation_0-rmse:0.67844
# [67]	validation_0-rmse:0.67609
# [68]	validation_0-rmse:0.67335
# [69]	validation_0-rmse:0.67111
# [70]	validation_0-rmse:0.66927
# [71]	validation_0-rmse:0.66675
# [72]	validation_0-rmse:0.66515
# [73]	validation_0-rmse:0.66279
# [74]	validation_0-rmse:0.66044
# [75]	validation_0-rmse:0.65848
# [76]	validation_0-rmse:0.65677
# [77]	validation_0-rmse:0.65463
# [78]	validation_0-rmse:0.65305
# [79]	validation_0-rmse:0.65154
# [80]	validation_0-rmse:0.64987
# [81]	validation_0-rmse:0.64792
# [82]	validation_0-rmse:0.64676
# [83]	validation_0-rmse:0.64530
# [84]	validation_0-rmse:0.64388
# [85]	validation_0-rmse:0.64222
# [86]	validation_0-rmse:0.64083
# [87]	validation_0-rmse:0.63963
# [88]	validation_0-rmse:0.63829
# [89]	validation_0-rmse:0.63679
# [90]	validation_0-rmse:0.63560
# [91]	validation_0-rmse:0.63425
# [92]	validation_0-rmse:0.63294
# [93]	validation_0-rmse:0.63168
# [94]	validation_0-rmse:0.63039
# [95]	validation_0-rmse:0.62936
# [96]	validation_0-rmse:0.62847
# [97]	validation_0-rmse:0.62736
# [98]	validation_0-rmse:0.62629
# [99]	validation_0-rmse:0.62511
# [100]	validation_0-rmse:0.62407
# [101]	validation_0-rmse:0.62280
# [102]	validation_0-rmse:0.62191
# [103]	validation_0-rmse:0.62085
# [104]	validation_0-rmse:0.61995
# [105]	validation_0-rmse:0.61939
# [106]	validation_0-rmse:0.61848
# [107]	validation_0-rmse:0.61821
# [108]	validation_0-rmse:0.61772
# [109]	validation_0-rmse:0.61757
# [110]	validation_0-rmse:0.61683
# [111]	validation_0-rmse:0.61636
# [112]	validation_0-rmse:0.61583
# [113]	validation_0-rmse:0.61509
# [114]	validation_0-rmse:0.61443
# [115]	validation_0-rmse:0.61377
# [116]	validation_0-rmse:0.61292
# [117]	validation_0-rmse:0.61236
# [118]	validation_0-rmse:0.61188
# [119]	validation_0-rmse:0.61159
# [120]	validation_0-rmse:0.61088
# [121]	validation_0-rmse:0.61069
# [122]	validation_0-rmse:0.61030
# [123]	validation_0-rmse:0.61002
# [124]	validation_0-rmse:0.60963
# [125]	validation_0-rmse:0.60953
# [126]	validation_0-rmse:0.60902
# [127]	validation_0-rmse:0.60875
# [128]	validation_0-rmse:0.60847
# [129]	validation_0-rmse:0.60858
# [130]	validation_0-rmse:0.60824
# [131]	validation_0-rmse:0.60815
# [132]	validation_0-rmse:0.60849
# [133]	validation_0-rmse:0.60774
# [134]	validation_0-rmse:0.60765
# [135]	validation_0-rmse:0.60781
# [136]	validation_0-rmse:0.60781
# [137]	validation_0-rmse:0.60793
# [138]	validation_0-rmse:0.60796
# [139]	validation_0-rmse:0.60758
# [140]	validation_0-rmse:0.60740
# [141]	validation_0-rmse:0.60743
# [142]	validation_0-rmse:0.60756
# [143]	validation_0-rmse:0.60739
# [144]	validation_0-rmse:0.60729
# [145]	validation_0-rmse:0.60708
# [146]	validation_0-rmse:0.60684
# [147]	validation_0-rmse:0.60710
# [148]	validation_0-rmse:0.60701
# [149]	validation_0-rmse:0.60706
# [150]	validation_0-rmse:0.60715
# [151]	validation_0-rmse:0.60690
# [152]	validation_0-rmse:0.60689
# [153]	validation_0-rmse:0.60669
# [154]	validation_0-rmse:0.60678
# [155]	validation_0-rmse:0.60679
# [156]	validation_0-rmse:0.60688
# [157]	validation_0-rmse:0.60691
# [158]	validation_0-rmse:0.60718
# [159]	validation_0-rmse:0.60708
# [160]	validation_0-rmse:0.60717
# [161]	validation_0-rmse:0.60694
# [162]	validation_0-rmse:0.60716
# [18:25:30] WARNING: ../src/learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [0]	validation_0-rmse:1.05051
# [1]	validation_0-rmse:1.03626
# [2]	validation_0-rmse:1.02234
# [3]	validation_0-rmse:1.00875
# [4]	validation_0-rmse:0.99547
# [5]	validation_0-rmse:0.98256
# [6]	validation_0-rmse:0.96991
# [7]	validation_0-rmse:0.95746
# [8]	validation_0-rmse:0.94549
# [9]	validation_0-rmse:0.93365
# [10]	validation_0-rmse:0.92237
# [11]	validation_0-rmse:0.91119
# [12]	validation_0-rmse:0.90054
# [13]	validation_0-rmse:0.88975
# [14]	validation_0-rmse:0.87962
# [15]	validation_0-rmse:0.86928
# [16]	validation_0-rmse:0.85915
# [17]	validation_0-rmse:0.84949
# [18]	validation_0-rmse:0.83987
# [19]	validation_0-rmse:0.83072
# [20]	validation_0-rmse:0.82183
# [21]	validation_0-rmse:0.81284
# [22]	validation_0-rmse:0.80424
# [23]	validation_0-rmse:0.79593
# [24]	validation_0-rmse:0.78765
# [25]	validation_0-rmse:0.77995
# [26]	validation_0-rmse:0.77232
# [27]	validation_0-rmse:0.76487
# [28]	validation_0-rmse:0.75727
# [29]	validation_0-rmse:0.75058
# [30]	validation_0-rmse:0.74396
# [31]	validation_0-rmse:0.73733
# [32]	validation_0-rmse:0.73063
# [33]	validation_0-rmse:0.72465
# [34]	validation_0-rmse:0.71881
# [35]	validation_0-rmse:0.71297
# [36]	validation_0-rmse:0.70754
# [37]	validation_0-rmse:0.70237
# [38]	validation_0-rmse:0.69705
# [39]	validation_0-rmse:0.69223
# [40]	validation_0-rmse:0.68711
# [41]	validation_0-rmse:0.68183
# [42]	validation_0-rmse:0.67766
# [43]	validation_0-rmse:0.67294
# [44]	validation_0-rmse:0.66890
# [45]	validation_0-rmse:0.66415
# [46]	validation_0-rmse:0.66046
# [47]	validation_0-rmse:0.65644
# [48]	validation_0-rmse:0.65331
# [49]	validation_0-rmse:0.64958
# [50]	validation_0-rmse:0.64620
# [51]	validation_0-rmse:0.64267
# [52]	validation_0-rmse:0.63927
# [53]	validation_0-rmse:0.63613
# [54]	validation_0-rmse:0.63296
# [55]	validation_0-rmse:0.62993
# [56]	validation_0-rmse:0.62737
# [57]	validation_0-rmse:0.62440
# [58]	validation_0-rmse:0.62156
# [59]	validation_0-rmse:0.61945
# [60]	validation_0-rmse:0.61661
# [61]	validation_0-rmse:0.61406
# [62]	validation_0-rmse:0.61169
# [63]	validation_0-rmse:0.60915
# [64]	validation_0-rmse:0.60668
# [65]	validation_0-rmse:0.60420
# [66]	validation_0-rmse:0.60196
# [67]	validation_0-rmse:0.59962
# [68]	validation_0-rmse:0.59730
# [69]	validation_0-rmse:0.59524
# [70]	validation_0-rmse:0.59319
# [71]	validation_0-rmse:0.59108
# [72]	validation_0-rmse:0.58925
# [73]	validation_0-rmse:0.58749
# [74]	validation_0-rmse:0.58558
# [75]	validation_0-rmse:0.58400
# [76]	validation_0-rmse:0.58189
# [77]	validation_0-rmse:0.58038
# [78]	validation_0-rmse:0.57890
# [79]	validation_0-rmse:0.57757
# [80]	validation_0-rmse:0.57618
# [81]	validation_0-rmse:0.57474
# [82]	validation_0-rmse:0.57356
# [83]	validation_0-rmse:0.57217
# [84]	validation_0-rmse:0.57111
# [85]	validation_0-rmse:0.56990
# [86]	validation_0-rmse:0.56879
# [87]	validation_0-rmse:0.56760
# [88]	validation_0-rmse:0.56694
# [89]	validation_0-rmse:0.56614
# [90]	validation_0-rmse:0.56508
# [91]	validation_0-rmse:0.56397
# [92]	validation_0-rmse:0.56316
# [93]	validation_0-rmse:0.56322
# [94]	validation_0-rmse:0.56190
# [95]	validation_0-rmse:0.56107
# [96]	validation_0-rmse:0.56001
# [97]	validation_0-rmse:0.55912
# [98]	validation_0-rmse:0.55801
# [99]	validation_0-rmse:0.55763
# [100]	validation_0-rmse:0.55675
# [101]	validation_0-rmse:0.55637
# [102]	validation_0-rmse:0.55606
# [103]	validation_0-rmse:0.55504
# [104]	validation_0-rmse:0.55451
# [105]	validation_0-rmse:0.55426
# [106]	validation_0-rmse:0.55438
# [107]	validation_0-rmse:0.55432
# [108]	validation_0-rmse:0.55369
# [109]	validation_0-rmse:0.55351
# [110]	validation_0-rmse:0.55336
# [111]	validation_0-rmse:0.55291
# [112]	validation_0-rmse:0.55278
# [113]	validation_0-rmse:0.55256
# [114]	validation_0-rmse:0.55184
# [115]	validation_0-rmse:0.55166
# [116]	validation_0-rmse:0.55119
# [117]	validation_0-rmse:0.55099
# [118]	validation_0-rmse:0.55051
# [119]	validation_0-rmse:0.54978
# [120]	validation_0-rmse:0.54975
# [121]	validation_0-rmse:0.54974
# [122]	validation_0-rmse:0.54917
# [123]	validation_0-rmse:0.54885
# [124]	validation_0-rmse:0.54906
# [125]	validation_0-rmse:0.54879
# [126]	validation_0-rmse:0.54861
# [127]	validation_0-rmse:0.54814
# [128]	validation_0-rmse:0.54822
# [129]	validation_0-rmse:0.54802
# [130]	validation_0-rmse:0.54805
# [131]	validation_0-rmse:0.54757
# [132]	validation_0-rmse:0.54768
# [133]	validation_0-rmse:0.54787
# [134]	validation_0-rmse:0.54790
# [135]	validation_0-rmse:0.54826
# [136]	validation_0-rmse:0.54840
# [137]	validation_0-rmse:0.54838
# [138]	validation_0-rmse:0.54850
# [139]	validation_0-rmse:0.54849
# [140]	validation_0-rmse:0.54889
# [141]	validation_0-rmse:0.54923
# [18:25:31] WARNING: ../src/learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [0]	validation_0-rmse:1.07322
# [1]	validation_0-rmse:1.06044
# [2]	validation_0-rmse:1.04800
# [3]	validation_0-rmse:1.03604
# [4]	validation_0-rmse:1.02425
# [5]	validation_0-rmse:1.01263
# [6]	validation_0-rmse:1.00152
# [7]	validation_0-rmse:0.99023
# [8]	validation_0-rmse:0.97900
# [9]	validation_0-rmse:0.96895
# [10]	validation_0-rmse:0.95882
# [11]	validation_0-rmse:0.94876
# [12]	validation_0-rmse:0.93889
# [13]	validation_0-rmse:0.92912
# [14]	validation_0-rmse:0.91951
# [15]	validation_0-rmse:0.91039
# [16]	validation_0-rmse:0.90159
# [17]	validation_0-rmse:0.89236
# [18]	validation_0-rmse:0.88402
# [19]	validation_0-rmse:0.87595
# [20]	validation_0-rmse:0.86759
# [21]	validation_0-rmse:0.85961
# [22]	validation_0-rmse:0.85194
# [23]	validation_0-rmse:0.84415
# [24]	validation_0-rmse:0.83709
# [25]	validation_0-rmse:0.83008
# [26]	validation_0-rmse:0.82320
# [27]	validation_0-rmse:0.81660
# [28]	validation_0-rmse:0.81044
# [29]	validation_0-rmse:0.80420
# [30]	validation_0-rmse:0.79801
# [31]	validation_0-rmse:0.79198
# [32]	validation_0-rmse:0.78619
# [33]	validation_0-rmse:0.78087
# [34]	validation_0-rmse:0.77543
# [35]	validation_0-rmse:0.77052
# [36]	validation_0-rmse:0.76566
# [37]	validation_0-rmse:0.76101
# [38]	validation_0-rmse:0.75651
# [39]	validation_0-rmse:0.75166
# [40]	validation_0-rmse:0.74743
# [41]	validation_0-rmse:0.74301
# [42]	validation_0-rmse:0.73863
# [43]	validation_0-rmse:0.73474
# [44]	validation_0-rmse:0.73081
# [45]	validation_0-rmse:0.72687
# [46]	validation_0-rmse:0.72315
# [47]	validation_0-rmse:0.71945
# [48]	validation_0-rmse:0.71601
# [49]	validation_0-rmse:0.71259
# [50]	validation_0-rmse:0.70903
# [51]	validation_0-rmse:0.70582
# [52]	validation_0-rmse:0.70285
# [53]	validation_0-rmse:0.70033
# [54]	validation_0-rmse:0.69732
# [55]	validation_0-rmse:0.69466
# [56]	validation_0-rmse:0.69210
# [57]	validation_0-rmse:0.68955
# [58]	validation_0-rmse:0.68653
# [59]	validation_0-rmse:0.68433
# [60]	validation_0-rmse:0.68220
# [61]	validation_0-rmse:0.68021
# [62]	validation_0-rmse:0.67733
# [63]	validation_0-rmse:0.67551
# [64]	validation_0-rmse:0.67383
# [65]	validation_0-rmse:0.67200
# [66]	validation_0-rmse:0.67028
# [67]	validation_0-rmse:0.66867
# [68]	validation_0-rmse:0.66709
# [69]	validation_0-rmse:0.66540
# [70]	validation_0-rmse:0.66400
# [71]	validation_0-rmse:0.66281
# [72]	validation_0-rmse:0.66145
# [73]	validation_0-rmse:0.65976
# [74]	validation_0-rmse:0.65862
# [75]	validation_0-rmse:0.65777
# [76]	validation_0-rmse:0.65614
# [77]	validation_0-rmse:0.65479
# [78]	validation_0-rmse:0.65315
# [79]	validation_0-rmse:0.65214
# [80]	validation_0-rmse:0.65113
# [81]	validation_0-rmse:0.64982
# [82]	validation_0-rmse:0.64879
# [83]	validation_0-rmse:0.64754
# [84]	validation_0-rmse:0.64603
# [85]	validation_0-rmse:0.64472
# [86]	validation_0-rmse:0.64358
# [87]	validation_0-rmse:0.64285
# [88]	validation_0-rmse:0.64167
# [89]	validation_0-rmse:0.64115
# [90]	validation_0-rmse:0.64005
# [91]	validation_0-rmse:0.63936
# [92]	validation_0-rmse:0.63892
# [93]	validation_0-rmse:0.63852
# [94]	validation_0-rmse:0.63762
# [95]	validation_0-rmse:0.63708
# [96]	validation_0-rmse:0.63632
# [97]	validation_0-rmse:0.63605
# [98]	validation_0-rmse:0.63519
# [99]	validation_0-rmse:0.63523
# [100]	validation_0-rmse:0.63448
# [101]	validation_0-rmse:0.63450
# [102]	validation_0-rmse:0.63391
# [103]	validation_0-rmse:0.63373
# [104]	validation_0-rmse:0.63330
# [105]	validation_0-rmse:0.63278
# [106]	validation_0-rmse:0.63238
# [107]	validation_0-rmse:0.63228
# [108]	validation_0-rmse:0.63194
# [109]	validation_0-rmse:0.63189
# [110]	validation_0-rmse:0.63114
# [111]	validation_0-rmse:0.63086
# [112]	validation_0-rmse:0.63062
# [113]	validation_0-rmse:0.63061
# [114]	validation_0-rmse:0.63045
# [115]	validation_0-rmse:0.63047
# [116]	validation_0-rmse:0.63025
# [117]	validation_0-rmse:0.63005
# [118]	validation_0-rmse:0.62980
# [119]	validation_0-rmse:0.62988
# [120]	validation_0-rmse:0.62972
# [121]	validation_0-rmse:0.62965
# [122]	validation_0-rmse:0.62947
# [123]	validation_0-rmse:0.62944
# [124]	validation_0-rmse:0.62942
# [125]	validation_0-rmse:0.62922
# [126]	validation_0-rmse:0.62893
# [127]	validation_0-rmse:0.62889
# [128]	validation_0-rmse:0.62867
# [129]	validation_0-rmse:0.62861
# [130]	validation_0-rmse:0.62831
# [131]	validation_0-rmse:0.62825
# [132]	validation_0-rmse:0.62812
# [133]	validation_0-rmse:0.62830
# [134]	validation_0-rmse:0.62850
# [135]	validation_0-rmse:0.62809
# [136]	validation_0-rmse:0.62800
# [137]	validation_0-rmse:0.62782
# [138]	validation_0-rmse:0.62768
# [139]	validation_0-rmse:0.62797
# [140]	validation_0-rmse:0.62761
# [141]	validation_0-rmse:0.62775
# [142]	validation_0-rmse:0.62794
# [143]	validation_0-rmse:0.62765
# [144]	validation_0-rmse:0.62770
# [145]	validation_0-rmse:0.62785
# [146]	validation_0-rmse:0.62810
# [147]	validation_0-rmse:0.62839
# [148]	validation_0-rmse:0.62826
# [149]	validation_0-rmse:0.62833
#           0         1     error       mae       mse        r2
# 0  0.823525  0.665169 -0.158356  0.147244  0.207317  0.906462
#           0         1     error       mae       mse        r2
# 0  0.551081  0.665169  0.114088  0.190552  0.277041  0.832966
#           0         1     error       mae       mse        r2
# 0  0.687303  0.665169 -0.022134  0.152641  0.223765  0.891031

# %% [markdown]
# # Make predictions and submit

# %%
# sub_preds = np.array(kfold_preds).mean(0)
# # sub_preds = model_full(xsub.to('cuda')).cpu().detach().numpy()
sub_preds = scaler_y_sub.inverse_transform(MakePredictions(sk_models_cat, xsub_enhanced, is_sklearn=True).reshape(-1, 1)).squeeze()

sub_preds
# Out:
# array([7285.8645614 , 5840.14410577, 6223.88753443, 7178.40571307,
#        5944.94582613, 7029.73905778, 6104.72822105, 6158.26731255,
#        7103.56271249, 7275.64044482, 6183.6382847 , 6156.06882262,
#        5947.30199159, 6086.68202273, 6070.87829764, 7220.27705278,
#        6086.68524635, 6117.51418513, 5904.6548221 , 7245.30159803,
#        7160.87656443, 5836.40485935, 7140.52817499, 5950.24841322,
#        7178.12786175, 7209.62115396, 7086.63627378, 6100.24255946,
#        5863.10923674, 6160.11064074, 5899.33333357, 5884.90428461,
#        7242.17896434, 7151.42018627, 7313.24319427, 7213.54347399,
#        5974.49721787, 5999.29387505, 6870.21269044, 6096.88968969,
#        7173.60665569, 5872.40804827, 5992.60013923, 7269.33766235,
#        5912.12525944, 6272.52818589, 6045.56930988, 7093.75212706,
#        6154.28887238, 6340.59416366, 7345.65323691, 7314.82306602,
#        5866.76729772, 7274.82704049, 7133.45447527, 7301.83995506,
#        7083.01028101, 7326.62055613, 5915.58887303, 6272.89515977,
#        6052.89764556, 7211.83713448, 6067.58922889, 5876.06811017,
#        7213.89417093, 7106.37847061, 6813.97541202, 7270.99514539,
#        7107.54915098, 5887.45977933, 5856.75503863, 7241.62851312,
#        5916.06538527, 6144.49105048, 7165.80363328, 5924.13416744,
#        7263.01944885, 5919.53385258, 7190.69322225, 7196.95884272,
#        5976.07186777, 7319.34987222, 7264.383297  , 6281.48421719,
#        7269.37446796, 5919.84419228, 7308.18971098, 7036.20118138,
#        5917.65478502, 7202.96638085, 7173.57733116, 7195.91830304,
#        5977.0173851 , 7123.47280596, 7096.48545129, 6056.69423928,
#        7270.06570445, 5998.82234256, 5965.13268182, 7123.61640846])

# %%
submission_df = pd.read_csv('Challenge_2_submission_template.csv')
submission_df['Predicted Rice Yield (kg/ha)'] = sub_preds
submission_df.head()
# Out:
#    ID No    District   Latitude   Longitude  \
# 0      1    Chau_Phu  10.542192  105.187920
# 1      2  Chau_Thanh  10.400189  105.331053
# 2      3    Chau_Phu  10.505489  105.203926
# 3      4    Chau_Phu  10.523520  105.138274
# 4      5   Thoai_Son  10.294660  105.248528
#
#   Season(SA = Summer Autumn, WS = Winter Spring)  \
# 0                                             WS
# 1                                             SA
# 2                                             SA
# 3                                             WS
# 4                                             SA
#
#   Rice Crop Intensity(D=Double, T=Triple) Date of Harvest  Field size (ha)  \
# 0                                       T      10-04-2022             1.40
# 1                                       T      15-07-2022             1.32
# 2                                       D      14-07-2022             1.40
# 3                                       D      10-04-2022             1.80
# 4                                       T      20-07-2022             2.20
#
#    Predicted Rice Yield (kg/ha)
# 0                   7285.864561
# 1                   5840.144106
# 2                   6223.887534
# 3                   7178.405713
# 4                   5944.945826

# %%
submission_df.to_csv('Version 17.2.csv', index=False)
